# %% [markdown]
# # Week 6 (Part 2): Supervised WSD
#
# In the first part of this week we will be looking at corpus-based methods for carrying out word sense disambiguation.  In particular, we will:
# * introduce SemCor, a sense-tagged subsection of the Brown Corpus.
# * build Naive Bayes classifiers to carry out sense disambiguation for words with two senses
#
# First some preliminary imports

# %%
#from google.colab import drive
#drive.mount('/content/drive')
import nltk
nltk.download('wordnet')
nltk.download('wordnet_ic')
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('semcor')

from nltk.corpus import wordnet as wn
from nltk.corpus import wordnet_ic as wn_ic
from nltk.corpus import semcor
from nltk.stem.wordnet import WordNetLemmatizer
import sys
import operator

#make sure that the path to your utils.py file is correct for your computer
#sys.path.append('/content/drive/My Drive/NLE Notebooks/Week4LabsSolutions/')
#from utils import *
#from sussex_nltk.corpus_readers import AmazonReviewCorpusReader
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]   Package wordnet_ic is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package semcor to /root/nltk_data...
# [nltk_data]   Package semcor is already up-to-date!

# %% [markdown]
# ## SemCor
# SemCor is a collection of 352 documents which have been annotated in various ways (annotations include POS tags and WordNet synsets for individual words
#
# `semcor.fileids()` returns a list of all of the individual document ids in SemCor

# %%
allfiles=semcor.fileids() #list of fileids
len(allfiles)
# Out:
# 352

# %% [markdown]
# `semcor.raw(fileid)` returns the raw text of the given file.  Note that this is marked-up using XML and is probably best avoided unless there is no other way to access the information you require from the file!

# %%
semcor.raw(allfiles[0])
# Out:
# '<contextfile concordance="brown">\n<context filename="br-a01" paras="yes">\n<p pnum="1">\n<s snum="1">\n<wf cmd="ignore" pos="DT">The</wf>\n<wf cmd="done" rdf="group" pos="NNP" lemma="group" wnsn="1" lexsn="1:03:00::" pn="group">Fulton_County_Grand_Jury</wf>\n<wf cmd="done" pos="VB" lemma="say" wnsn="1" lexsn="2:32:00::">said</wf>\n<wf cmd="done" pos="NN" lemma="friday" wnsn="1" lexsn="1:28:00::">Friday</wf>\n<wf cmd="ignore" pos="DT">an</wf>\n<wf cmd="done" pos="NN" lemma="investigation" wnsn="1" lexsn="1:09:00::">investigation</wf>\n<wf cmd="ignore" pos="IN">of</wf>\n<wf cmd="done" pos="NN" lemma="atlanta" wnsn="1" lexsn="1:15:00::">Atlanta</wf>\n<wf cmd="ignore" pos="POS">\'s</wf>\n<wf cmd="done" pos="JJ" lemma="recent" wnsn="2" lexsn="5:00:00:past:00">recent</wf>\n<wf cmd="done" pos="NN" lemma="primary_election" wnsn="1" lexsn="1:04:00::">primary_election</wf>\n<wf cmd="done" pos="VB" lemma="produce" wnsn="4" lexsn="2:39:01::">produced</wf>\n<punc>``</punc>\n<wf cmd="ignore" pos="DT">no</wf>\n<wf cmd="done" pos="NN" lemma="evidence" wnsn="1" lexsn="1:09:00::">evidence</wf>\n<punc>\'\'</punc>\n<wf cmd="ignore" pos="IN">that</wf>\n<wf cmd="ignore" pos="DT">any</wf>\n<wf cmd="done" pos="NN" lemma="irregularity" wnsn="1" lexsn="1:04:00::">irregularities</wf>\n<wf cmd="done" pos="VB" lemma="take_place" wnsn="1" lexsn="2:30:00::">took_place</wf>\n<punc>.</punc>\n</s>\n</p>\n<p pnum="2">\n<s snum="2">\n<wf cmd="ignore" pos="DT">The</wf>\n<wf cmd="done" pos="NN" lemma="jury" wnsn="1" lexsn="1:14:00::">jury</wf>\n<wf cmd="done" pos="RB" lemma="far" wnsn="2" lexsn="4:02:00::">further</wf>\n<wf cmd="done" pos="VB" lemma="say" wnsn="1" lexsn="2:32:00::">said</wf>\n<wf cmd="ignore" pos="IN">in</wf>\n<wf cmd="done" pos="NN" lemma="term" wnsn="2" lexsn="1:28:00::">term</wf>\n<wf cmd="done" pos="NN" lemma="end" wnsn="2" lexsn="1:28:00::">end</wf>\n<wf cmd="done" pos="NN" lemma="presentment" wnsn="1" lexsn="1:04:00::">presentments</wf>\n<wf cmd="ignore" pos="IN">that</wf>\n<wf cmd="ignore" pos="DT">the</wf>\n<wf cmd="done" rdf="group" pos="NNP" lemma="group" wnsn="1" lexsn="1:03:00::" pn="group">City_Executive_Committee</wf>\n<punc>,</punc>\n<wf cmd="ignore" pos="WDT">which</wf>\n<wf cmd="done" pos="VB" lemma="have" wnsn="4" lexsn="2:40:04::">had</wf>\n<wf cmd="done" pos="JJ" lemma="overall" wnsn="2" lexsn="5:00:00:gross:00">over-all</wf>\n<wf cmd="done" pos="NN" lemma="charge" wnsn="6" lexsn="1:04:03::">charge</wf>\n<wf cmd="ignore" pos="IN">of</wf>\n<wf cmd="ignore" pos="DT">the</wf>\n<wf cmd="done" pos="NN" lemma="election" wnsn="1" lexsn="1:04:01::">election</wf>\n<punc>,</punc>\n<punc>``</punc>\n<wf cmd="done" pos="VB" lemma="deserve" wnsn="1" lexsn="2:42:00::">deserves</wf>\n<wf cmd="ignore" pos="DT">the</wf>\n<wf cmd="done" pos="NN" lemma="praise" wnsn="1" lexsn="1:10:00::">praise</wf>\n<wf cmd="ignore" pos="CC">and</wf>\n<wf cmd="done" pos="NN" lemma="thanks" wnsn="1" lexsn="1:10:00::">thanks</wf>\n<wf cmd="ignore" pos="IN">of</wf>\n<wf cmd="ignore" pos="DT">the</wf>\n<wf cmd="done" rdf="location" pos="NNP" lemma="location" wnsn="1" lexsn="1:03:00::" pn="location">City_of_Atlanta</wf>\n<punc>\'\'</punc>\n<wf cmd="ignore" pos="IN">for</wf>\n<wf cmd="ignore" pos="DT">the</wf>\n<wf cmd="done" pos="NN" lemma="manner" wnsn="1" lexsn="1:07:02::">manner</wf>\n<wf cmd="done" pos="RB" ot="notag">in</wf>\n<wf cmd="done" pos="RB" ot="notag">which</wf>\n<wf cmd="ignore" pos="DT">the</wf>\n<wf cmd="done" pos="NN" lemma="election" wnsn="1" lexsn="1:04:01::">election</wf>\n<wf cmd="done" pos="VBD" ot="notag">was</wf>\n<wf cmd="done" pos="VB" lemma="conduct" wnsn="1" lexsn="2:41:00::">conducted</wf>\n<punc>.</punc>\n</s>\n</p>\n<p pnum="3">\n<s snum="3">\n<wf cmd="ignore" pos="DT">The</wf>\n<wf cmd="done" pos="NN" lemma="september" wnsn="1" lexsn="1:28:00::">September</wf>\n<wf cmd="done" pos="NN" lemma="october" wnsn="1" lexsn="1:28:00::">October</wf>\n<wf cmd="done" pos="NN" lemma="term" wnsn="2" lexsn="1:28:00::">term</wf>\n<wf cmd="done" pos= ...

# %% [markdown]
# Other potentially useful SemCor functions include:
#
# *`semcor.words(fileid)`: returns a list of tokens for each file
# *`semcor.chunks(fileid)`: returns a list of *chunks* for each file, where a chunk identifies multiword (generally non-compositional) phrases
# *`semcor.tagged_chunks(fileid,tagtype)`: returns the tagged chunks of the file where the tagtype can be *pos* or *sem*.  We are interested in the *sem* tags which are the WOrdNet synsets
# *`semcor.tagged_sentences(fileid,tagtype)`: maintains the sentence boundaries within the file and therefore returns a list of lists (one for each sentence)

# %%
semcor.words(allfiles[0])
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
len(semcor.words(allfiles[0]))
# Out:
# 2255

# %%
semcor.chunks(allfiles[0])
# Out:
# [['The'], ['Fulton', 'County', 'Grand', 'Jury'], ...]

# %%
semcor.tagged_chunks(allfiles[0],tag='sem')
# Out:
# [['The'], Tree(Lemma('group.n.01.group'), [Tree('NE', ['Fulton', 'County', 'Grand', 'Jury'])]), ...]

# %%
tagged_sentences=semcor.tagged_sents(allfiles[0],tag='sem')
tagged_sentences[0]
# Out:
# [['The'],
#  Tree(Lemma('group.n.01.group'), [Tree('NE', ['Fulton', 'County', 'Grand', 'Jury'])]),
#  Tree(Lemma('state.v.01.say'), ['said']),
#  Tree(Lemma('friday.n.01.Friday'), ['Friday']),
#  ['an'],
#  Tree(Lemma('probe.n.01.investigation'), ['investigation']),
#  ['of'],
#  Tree(Lemma('atlanta.n.01.Atlanta'), ['Atlanta']),
#  ["'s"],
#  Tree(Lemma('late.s.03.recent'), ['recent']),
#  Tree(Lemma('primary.n.01.primary_election'), ['primary', 'election']),
#  Tree(Lemma('produce.v.04.produce'), ['produced']),
#  ['``'],
#  ['no'],
#  Tree(Lemma('evidence.n.01.evidence'), ['evidence']),
#  ["''"],
#  ['that'],
#  ['any'],
#  Tree(Lemma('abnormality.n.04.irregularity'), ['irregularities']),
#  Tree(Lemma('happen.v.01.take_place'), ['took', 'place']),
#  ['.']]

# %% [markdown]
# For the purposes of this exercise, we are interested in single words which have been tagged with a WordNet Lemma or synset.  We now define a couple of functions to help us extract this information.

# %%
def extract_tags(taggedsentence):
    '''
    For a tagged sentence in SemCor, identify single words which have been tagged with a WN synset
    taggedsentence: a list of items, some of which are of type wordnet.tree.Tree
    :return: a list of pairs, (word,synset)
    
    '''
    alist=[]
    for item in taggedsentence:
        if isinstance(item,nltk.tree.Tree):   #check with this is a Tree
            if isinstance(item.label(),nltk.corpus.reader.wordnet.Lemma) and len(item.leaves())==1:
                #check whether the tree's label is Lemma and whether the tree has a single leaf
                #if so add the pair (lowercased leaf,synsetlabel) to output list
                alist.append((item.leaves()[0].lower(),item.label().synset()))
    return alist
            

def extract_senses(fileid_list):
    '''
    apply extract_tags to all sentences in all documents in a list of file ids
    fileid_list: list of ids
    :return: list of list of (token,tag) pairs, one for each sentence in corpus
    '''
    sentences=[]
    for fileid in fileid_list:
        print("Processing {}".format(fileid))
        sentences+=[extract_tags(taggedsentence) for taggedsentence in semcor.tagged_sents(fileid,tag='sem')]
    return sentences

# %% [markdown]
# Lets test this on the first document in the fileid list.  Notice that it takes a while to process a single file in this way.

# %%
some_sentences=extract_senses([allfiles[0]])
some_sentences
# Out:
# Processing brown1/tagfiles/br-a01.xml
# [[('said', Synset('state.v.01')),
#   ('friday', Synset('friday.n.01')),
#   ('investigation', Synset('probe.n.01')),
#   ('atlanta', Synset('atlanta.n.01')),
#   ('recent', Synset('late.s.03')),
#   ('produced', Synset('produce.v.04')),
#   ('evidence', Synset('evidence.n.01')),
#   ('irregularities', Synset('abnormality.n.04'))],
#  [('jury', Synset('jury.n.01')),
#   ('further', Synset('far.r.02')),
#   ('said', Synset('state.v.01')),
#   ('term', Synset('term.n.02')),
#   ('end', Synset('end.n.02')),
#   ('presentments', Synset('presentment.n.01')),
#   ('had', Synset('own.v.01')),
#   ('over-all', Synset('overall.s.02')),
#   ('charge', Synset('mission.n.03')),
#   ('election', Synset('election.n.01')),
#   ('deserves', Synset('deserve.v.01')),
#   ('praise', Synset('praise.n.01')),
#   ('thanks', Synset('thanks.n.01')),
#   ('manner', Synset('manner.n.01')),
#   ('election', Synset('election.n.01')),
#   ('conducted', Synset('conduct.v.01'))],
#  [('september', Synset('september.n.01')),
#   ('october', Synset('october.n.01')),
#   ('term', Synset('term.n.02')),
#   ('jury', Synset('jury.n.01')),
#   ('charged', Synset('appoint.v.02')),
#   ('fulton', Synset('location.n.01')),
#   ('investigate', Synset('investigate.v.02')),
#   ('reports', Synset('report.n.03')),
#   ('possible', Synset('potential.a.01')),
#   ('irregularities', Synset('abnormality.n.04')),
#   ('hard-fought', Synset('hard-fought.s.01')),
#   ('primary', Synset('primary.n.01')),
#   ('won', Synset('win.v.01'))],
#  [('only', Synset('merely.r.01')),
#   ('relative', Synset('relative.a.01')),
#   ('handful', Synset('handful.n.01')),
#   ('reports', Synset('report.n.03')),
#   ('received', Synset('receive.v.02')),
#   ('jury', Synset('jury.n.01')),
#   ('said', Synset('state.v.01')),
#   ('considering', Synset('consider.v.04')),
#   ('widespread', Synset('widespread.s.01')),
#   ('interest', Synset('interest.n.01')),
#   ('election', Synset('election.n.01')),
#   ('number', Synset('number.n.02')),
#   ('voters', Synset('voter.n.01')),
#   ('size', Synset('size.n.01')),
#   ('city', Synset('city.n.01'))],
#  [('jury', Synset('jury.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('find', Synset('rule.v.04')),
#   ('georgia', Synset('georgia.n.01')),
#   ('registration', Synset('registration.n.01')),
#   ('election', Synset('election.n.01')),
#   ('laws', Synset('law.n.02')),
#   ('are', Synset('be.v.01')),
#   ('outmoded', Synset('antique.s.02')),
#   ('inadequate', Synset('inadequate.a.01')),
#   ('often', Synset('frequently.r.01')),
#   ('ambiguous', Synset('ambiguous.a.02'))],
#  [('recommended', Synset('recommend.v.01')),
#   ('fulton', Synset('location.n.01')),
#   ('legislators', Synset('legislator.n.01')),
#   ('act', Synset('act.v.01')),
#   ('have', Synset('get.v.03')),
#   ('laws', Synset('law.n.02')),
#   ('studied', Synset('analyze.v.01')),
#   ('revised', Synset('revise.v.01')),
#   ('end', Synset('goal.n.01')),
#   ('modernizing', Synset('overhaul.v.02')),
#   ('improving', Synset('better.v.03'))],
#  [('commented', Synset('comment.v.01')),
#   ('number', Synset('number.n.01')),
#   ('other', Synset('other.a.01')),
#   ('topics', Synset('topic.n.02')),
#   ('atlanta', Synset('atlanta.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('are', Synset('be.v.01')),
#   ('well', Synset('well.r.01')),
#   ('operated', Synset('function.v.01')),
#   ('follow', Synset('adopt.v.01')),
#   ('generally', Synset('by_and_large.r.01')),
#   ('practices', Synset('practice.n.01')),
#   ('inure', Synset('inure.v.01')),
#   ('best', Synset('best.a.01')),
#   ('interest', Synset('sake.n.01')),
#   ('governments', Synset('government.n.01'))],
#  [('however', Synset('however.r.01')),
#   ('jury', Synset('jury.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('believes', Synset('believe.v.03')),
#   ('two', Synset('two.s.01')),
#   ('offices', Synset('agency.n.01')),
#   ('achieve', Synset('achieve.v.01')),
#   ('efficiency', Synset('efficiency.n.02')),
#   ('reduce', Synset('reduce.v.01')),
#   ('cost', Synset('cost.n.01')),
#   ('administration', Synset('administration.n.01'))],
#  [('jury', Synset('jury.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('is', Synset('be.v.01')),
#   ('lacking', Synset('deficient.s.01')),
#   ('experienced', Synset('experienced.a.01')),
#   ('clerical', Synset('clerical.a.01')),
#   ('personnel', Synset('force.n.04')),
#   ('result', Synset('consequence.n.01')),
#   ('city', Synset('city.n.02')),
#   ('personnel', Synset('force.n.04')),
#   ('policies', Synset('policy.n.01'))],
#  [('urged', Synset('urge.v.01')),
#   ('city', Synset('city.n.02')),
#   ('take', Synset('take.v.01')),
#   ('steps', Synset('measure.n.01')),
#   ('remedy', Synset('rectify.v.04')),
#   ('problem', Synset('problem.n.02'))],
#  [('implementation', Synset('execution.n.06')),
#   ('georgia', Synset('georgia.n.01')),
#   ('automobile', Synset('car.n.01')),
#   ('title', Synset('deed.n.01')),
#   ('law', Synset('law.n.02')),
#   ('also', Synset('besides.r.02')),
#   ('recommended', Synset('recommend.v.01')),
#   ('outgoing', Synset('outgoing.a.01')),
#   ('jury', Synset('jury.n.01'))],
#  [('urged', Synset('urge.v.01')),
#   ('next', Synset('future.s.03')),
#   ('legislature', Synset('legislature.n.01')),
#   ('provide', Synset('supply.v.01')),
#   ('enabling', Synset('enabling.a.01')),
#   ('funds', Synset('fund.n.01')),
#   ('re-set', Synset('reset.v.01')),
#   ('effective', Synset('effective.s.04')),
#   ('date', Synset('date.n.01')),
#   ('implementation', Synset('execution.n.06')),
#   ('law', Synset('law.n.02')),
#   ('effected', Synset('effect.v.01'))],
#  [('handling', Synset('handling.n.01')),
#   ('federal', Synset('federal.s.01')),
#   ('funds', Synset('fund.n.01'))],
#  [('is', Synset('be.v.02')),
#   ('one', Synset('one.s.01')),
#   ('major', Synset('major.a.01')),
#   ('items', Synset('detail.n.01')),
#   ('general', Synset('general.a.01')),
#   ('assistance', Synset('aid.n.02')),
#   ('program', Synset('plan.n.01')),
#   ('jury', Synset('jury.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('distribute', Synset('distribute.v.01')),
#   ('funds', Synset('fund.n.01')),
#   ('welfare', Synset('social_welfare.n.01')),
#   ('departments', Synset('department.n.01')),
#   ('all', Synset('all.a.01')),
#   ('counties', Synset('county.n.01')),
#   ('state', Synset('state.n.01')),
#   ('exception', Synset('exception.n.01')),
#   ('receives', Synset('receive.v.01')),
#   ('money', Synset('money.n.01'))],
#  [('jurors', Synset('juror.n.01')),
#   ('said', Synset('state.v.01')),
#   ('realize', Synset('recognize.v.02')),
#   ('proportionate', Synset('proportionate.s.02')),
#   ('distribution', Synset('distribution.n.02')),
#   ('funds', Synset('fund.n.01')),
#   ('disable', Synset('disable.v.01')),
#   ('program', Synset('plan.n.01')),
#   ('less', Synset('less.a.01')),
#   ('populous', Synset('populous.s.01')),
#   ('counties', Synset('county.n.01'))],
#  [('nevertheless', Synset('however.r.01')),
#   ('feel', Synset('find.v.05')),
#   ('receive', Synset('receive.v.01')),
#   ('some', Synset('some.a.01')),
#   ('portion', Synset('parcel.n.02')),
#   ('available', Synset('available.a.01')),
#   ('funds', Synset('fund.n.01')),
#   ('jurors', Synset('juror.n.01')),
#   ('said', Synset('allege.v.01'))],
#  [('failure', Synset('failure.n.01')),
#   ('do', Synset('make.v.01')),
#   ('continue', Synset('continue.v.01')),
#   ('place', Synset('put.v.01')),
#   ('disproportionate', Synset('disproportionate.a.01')),
#   ('burden', Synset('burden.n.01')),
#   ('fulton', Synset('location.n.01')),
#   ('taxpayers', Synset('taxpayer.n.01'))],
#  [('jury', Synset('jury.n.01')),
#   ('also', Synset('besides.r.02')),
#   ('commented', Synset('comment.v.01')),
#   ('fulton', Synset('location.n.01')),
#   ('ordinary', Synset('ordinary.n.02')),
#   ('court', Synset('court.n.01')),
#   ('practices', Synset('practice.n.01')),
#   ('appointment', Synset('appointment.n.01')),
#   ('appraisers', Synset('appraiser.n.01')),
#   ('guardians', Synset('defender.n.01')),
#   ('administrators', Synset('administrator.n.01')),
#   ('awarding', Synset('award.n.01')),
#   ('fees', Synset('fee.n.01')),
#   ('compensation', Synset('compensation.n.01'))],
#  [('jury', Synset('jury.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('found', Synset('determine.v.01')),
#   ('court', Synset('court.n.01')),
#   ('incorporated', Synset('integrate.v.01')),
#   ('recommendations', Synset('recommendation.n.01')),
#   ('two', Synset('two.s.01')),
#   ('interim', Synset('interim.s.01'))],
#  [('actions', Synset('action.n.01')),
#   ('serve', Synset('serve.v.03')),
#   ('protect', Synset('protect.v.01')),
#   ('court', Synset('court.n.01')),
#   ('wards', Synset('ward.n.01')),
#   ('undue', Synset('undue.a.01')),
#   ('costs', Synset('cost.n.01')),
#   ('appointed', Synset('appointive.a.02')),
#   ('elected', Synset('elective.a.01')),
#   ('servants', Synset('servant.n.01')),
#   ('unmeritorious', Synset('unmeritorious.s.01')),
#   ('criticisms', Synset('criticism.n.01')),
#   ('jury', Synset('jury.n.01')),
#   ('said', Synset('allege.v.01'))],
#  [('regarding', Synset('involve.v.01')),
#   ('atlanta', Synset('atlanta.n.01')),
#   ('new', Synset('new.a.01')),
#   ('million', Synset('million.s.01')),
#   ('dollar', Synset('dollar.n.01')),
#   ('airport', Synset('airport.n.01')),
#   ('jury', Synset('jury.n.01')),
#   ('recommended', Synset('recommend.v.01')),
#   ('new', Synset('new.a.01')),
#   ('management', Synset('management.n.02')),
#   ('jan.', Synset('january.n.01')),
#   ('airport', Synset('airport.n.01')),
#   ('operated', Synset('operate.v.01')),
#   ('manner', Synset('manner.n.01')),
#   ('eliminate', Synset('extinguish.v.04')),
#   ('political', Synset('political.a.01')),
#   ('influences', Synset('influence.n.01'))],
#  [('jury', Synset('jury.n.01')),
#   ('not', Synset('not.r.01')),
#   ('elaborate', Synset('elaborate.v.01')),
#   ('added', Synset('add.v.02')),
#   ('be', Synset('be.v.01')),
#   ('periodic', Synset('periodic.a.01')),
#   ('surveillance', Synset('surveillance.n.01')),
#   ('pricing', Synset('pricing.n.01')),
#   ('practices', Synset('practice.n.01')),
#   ('concessionaires', Synset('concessionaire.n.01')),
#   ('purpose', Synset('purpose.n.01')),
#   ('keeping', Synset('keep.v.01')),
#   ('prices', Synset('price.n.02')),
#   ('reasonable', Synset('fair.s.02'))],
#  [('other', Synset('other.a.01')),
#   ('matters', Synset('topic.n.02')),
#   ('jury', Synset('jury.n.01')),
#   ('recommended', Synset('recommend.v.01'))],
#  [('four', Synset('four.s.01')),
#   ('deputies', Synset('deputy.n.02')),
#   ('employed', Synset('hire.v.01')),
#   ('doctor', Synset('doctor.n.01')),
#   ('extern', Synset('extern.n.01')),
#   ('employed', Synset('hire.v.01')),
#   ('night', Synset('night.n.01')),
#   ('weekend', Synset('weekend.n.01')),
#   ('duty', Synset('duty.n.02')),
#   ('jail', Synset('jail.n.01'))],
#  [('fulton', Synset('location.n.01')),
#   ('legislators', Synset('legislator.n.01')),
#   ('city', Synset('city.n.02')),
#   ('officials', Synset('official.n.01')),
#   ('pass', Synset('legislate.v.01')),
#   ('permit', Synset('permit.v.01')),
#   ('establishment', Synset('constitution.n.02')),
#   ('equitable', Synset('equitable.a.01')),
#   ('pension', Synset('pension.n.01')),
#   ('plan', Synset('plan.n.01')),
#   ('city', Synset('city.n.02')),
#   ('employes', Synset('employee.n.01'))],
#  [('jury', Synset('jury.n.01')),
#   ('praised', Synset('praise.v.01')),
#   ('administration', Synset('administration.n.01')),
#   ('operation', Synset('operation.n.01')),
#   ('atlanta', Synset('atlanta.n.01')),
#   ('bellwood', Synset('location.n.01')),
#   ('alpharetta', Synset('location.n.01'))],
#  [('filed', Synset('file.v.01')),
#   ('suit', Synset('lawsuit.n.01')),
#   ('divorce', Synset('divorce.n.01')),
#   ('wife', Synset('wife.n.01')),
#   ('friday', Synset('friday.n.01'))],
#  [('petition', Synset('request.n.01')),
#   ('charged', Synset('charge.v.06')),
#   ('mental', Synset('mental.a.02')),
#   ('cruelty', Synset('cruelty.n.02'))],
#  [('couple', Synset('couple.n.02')),
#   ('married', Synset('marry.v.01')),
#   ('aug.', Synset('august.n.01'))],
#  [('have', Synset('have.v.01')),
#   ('son', Synset('son.n.01')),
#   ('daughter', Synset('daughter.n.01')),
#   ('griffin', Synset('location.n.01'))],
#  [('attorneys', Synset('lawyer.n.01')),
#   ('mayor', Synset('mayor.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('amicable', Synset('amicable.a.01'))],
#  [('petition', Synset('request.n.01')),
#   ('listed', Synset('list.v.01')),
#   ('mayor', Synset('mayor.n.01')),
#   ('occupation', Synset('occupation.n.01')),
#   ('attorney', Synset('lawyer.n.01')),
#   ('age', Synset('age.n.01'))],
#  [('listed', Synset('list.v.01')),
#   ('wife', Synset('wife.n.01')),
#   ('age', Synset('age.n.01'))],
#  [('petition', Synset('request.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('couple', Synset('couple.n.02')),
#   ('not', Synset('not.r.01')),
#   ('lived', Synset('populate.v.01')),
#   ('together', Synset('together.r.03')),
#   ('more', Synset('more.r.02')),
#   ('year', Synset('year.n.01'))],
#  [('hartsfield', Synset('person.n.01')),
#   ('home', Synset('dwelling.n.01')),
#   ('is', Synset('be.v.03'))],
#  [('listed', Synset('list.v.01')),
#   ('petition', Synset('request.n.01')),
#   ('mayor', Synset('mayor.n.01')),
#   ('attorney', Synset('lawyer.n.01'))],
#  [('hartsfield', Synset('person.n.01')),
#   ('been', Synset('be.v.08')),
#   ('mayor', Synset('mayor.n.01')),
#   ('atlanta', Synset('atlanta.n.01')),
#   ('exception', Synset('exception.n.01')),
#   ('one', Synset('one.s.01')),
#   ('brief', Synset('brief.s.01')),
#   ('interlude', Synset('interlude.n.01'))],
#  [('political', Synset('political.a.03')),
#   ('career', Synset('career.n.01')),
#   ('election', Synset('election.n.01'))],
#  [('mayor', Synset('mayor.n.01')),
#   ('present', Synset('present.a.01')),
#   ('expires', Synset('run_out.v.04')),
#   ('jan.', Synset('january.n.01'))],
#  [('succeeded', Synset('succeed.v.02')),
#   ('became', Synset('become.v.02')),
#   ('candidate', Synset('campaigner.n.01')),
#   ('sept.', Synset('september.n.01')),
#   ('primary', Synset('primary.n.01')),
#   ('announced', Synset('announce.v.01')),
#   ('not', Synset('not.r.01')),
#   ('run', Synset('campaign.v.01')),
#   ('reelection', Synset('reelection.n.01'))],
#  [('georgia', Synset('georgia.n.01')),
#   ('republicans', Synset('republican.n.01')),
#   ('getting', Synset('receive.v.02')),
#   ('strong', Synset('potent.s.02')),
#   ('encouragement', Synset('boost.n.01')),
#   ('enter', Synset('enroll.v.01')),
#   ('candidate', Synset('campaigner.n.01')),
#   ('official', Synset('official.n.01')),
#   ('said', Synset('state.v.01')),
#   ('wednesday', Synset('wednesday.n.01'))],
#  [('state', Synset('state.n.03')),
#   ('gop', Synset('republican_party.n.01')),
#   ('chairman', Synset('president.n.04')),
#   ('said', Synset('state.v.01')),
#   ('meeting', Synset('meeting.n.01')),
#   ('held', Synset('hold.v.03')),
#   ('tuesday', Synset('tuesday.n.01')),
#   ('night', Synset('night.n.01')),
#   ('brought', Synset('bring.v.03')),
#   ('enthusiastic', Synset('enthusiastic.a.01')),
#   ('responses', Synset('reception.n.01')),
#   ('audience', Synset('audience.n.01'))],
#  [('added', Synset('add.v.02')),
#   ('enthusiasm', Synset('enthusiasm.n.03')),
#   ('state', Synset('state.n.01')),
#   ('rally', Synset('rally.n.01')),
#   ('held', Synset('hold.v.03')),
#   ('sept.', Synset('september.n.01')),
#   ('savannah', Synset('savannah.n.01')),
#   ('newly', Synset('newly.r.01')),
#   ('elected', Synset('elective.a.01')),
#   ('texas', Synset('texas.n.01')),
#   ('be', Synset('be.v.02')),
#   ('featured', Synset('featured.s.01')),
#   ('speaker', Synset('speaker.n.01'))],
#  [('meeting', Synset('meeting.n.01')),
#   ('audience', Synset('audience.n.01')),
#   ('warned', Synset('warn.v.01')),
#   ('entering', Synset('enroll.v.01')),
#   ('candidate', Synset('campaigner.n.01')),
#   ('governor', Synset('governor.n.01')),
#   ('force', Synset('coerce.v.01')),
#   ('take', Synset('bring.v.01')),
#   ('petitions', Synset('request.n.01')),
#   ('obtain', Synset('obtain.v.01')),
#   ('signatures', Synset('signature.n.01')),
#   ('registered', Synset('register.v.03')),
#   ('voters', Synset('voter.n.01'))],
#  [('warning', Synset('admonition.n.01')),
#   ('was', Synset('be.v.05')),
#   ('unanimous', Synset('consentaneous.s.01')),
#   ('vote', Synset('vote.n.01')),
#   ('enter', Synset('enroll.v.01')),
#   ('candidate', Synset('campaigner.n.01')),
#   ('republicans', Synset('republican.n.01')),
#   ('attended', Synset('attend.v.01'))],
#  [('crowd', Synset('crowd.n.01')),
#   ('asked', Synset('ask.v.01')),
#   ('wanted', Synset('desire.v.01')),
#   ('wait', Synset('wait.v.02')),
#   ('one', Synset('one.s.01')),
#   ('term', Synset('term.n.02')),
#   ('make', Synset('cause.v.01')),
#   ('race', Synset('race.n.01')),
#   ('voted', Synset('vote.v.03')),
#   ('no', Synset('no.r.01')),
#   ('were', Synset('be.v.05')),
#   ('dissents', Synset('dissent.n.02'))],
#  [('hurdle', Synset('hurdle.n.01')),
#   ('republicans', Synset('republican.n.01')),
#   ('face', Synset('confront.v.01')),
#   ('is', Synset('be.v.02')),
#   ('state', Synset('state.n.04')),
#   ('law', Synset('law.n.02')),
#   ('says', Synset('allege.v.01')),
#   ('making', Synset('make.v.01')),
#   ('first', Synset('first.a.01')),
#   ('race', Synset('race.n.01')),
#   ('one', Synset('one.s.01')),
#   ('two', Synset('two.s.01')),
#   ('alternative', Synset('alternative.s.02')),
#   ('courses', Synset('course.n.03')),
#   ('taken', Synset('take.v.20'))],
#  [('five', Synset('five.s.01')),
#   ('voters', Synset('voter.n.01')),
#   ('county', Synset('county.n.01')),
#   ('sign', Synset('sign.v.03')),
#   ('petitions', Synset('request.n.01')),
#   ('requesting', Synset('request.v.02')),
#   ('republicans', Synset('republican.n.01')),
#   ('allowed', Synset('let.v.01')),
#   ('place', Synset('put.v.01')),
#   ('names', Synset('name.n.01')),
#   ('candidates', Synset('campaigner.n.01')),
#   ('ballot', Synset('vote.n.01')),
#   ('republicans', Synset('republican.n.01')),
#   ('hold', Synset('hold.v.03')),
#   ('primary', Synset('primary.n.01')),
#   ('county', Synset('county.n.01')),
#   ('unit', Synset('unit.n.03')),
#   ('system', Synset('system.n.04')),
#   ('system', Synset('system.n.04')),
#   ('party', Synset('party.n.01')),
#   ('opposes', Synset('oppose.v.01')),
#   ('platform', Synset('platform.n.02'))],
#  [('director', Synset('director.n.01')),
#   ('resigned', Synset('vacate.v.01')),
#   ('tuesday', Synset('tuesday.n.01')),
#   ('work', Synset('work.v.02')),
#   ('campaign', Synset('political_campaign.n.01'))],
#  [('caldwell', Synset('person.n.01')),
#   ('resignation', Synset('resignation.n.03')),
#   ('expected', Synset('expect.v.01')),
#   ('time', Synset('time.n.03'))],
#  [('succeeded', Synset('succeed.v.02')),
#   ('gainesville', Synset('location.n.01')),
#   ('been', Synset('constitute.v.01')),
#   ('assistant', Synset('assistant.n.01')),
#   ('more', Synset('more.r.02')),
#   ('three', Synset('three.s.01')),
#   ('years', Synset('year.n.01'))],
#  [('gubernatorial', Synset('gubernatorial.a.01')),
#   ('campaign', Synset('political_campaign.n.01')),
#   ('starts', Synset('get_down.v.07')),
#   ('caldwell', Synset('person.n.01')),
#   ('expected', Synset('expect.v.01')),
#   ('become', Synset('become.v.02')),
#   ('campaign', Synset('political_campaign.n.01')),
#   ('coordinator', Synset('coordinator.n.01')),
#   ('byrd', Synset('person.n.01'))],
#  [('session', Synset('school_term.n.01')),
#   ('monday', Synset('monday.n.01')),
#   ('head', Synset('head.v.01')),
#   ('home', Synset('home.r.01')),
#   ('highway', Synset('highway.n.01')),
#   ('bond', Synset('bond.n.02')),
#   ('money', Synset('money.n.01')),
#   ('approved', Synset('approve.v.01')),
#   ('follow', Synset('follow.v.01')),
#   ('shortly', Synset('soon.r.01'))],
#  [('adjournment', Synset('adjournment.n.01')),
#   ('monday', Synset('monday.n.01')),
#   ('afternoon', Synset('afternoon.n.01')),
#   ('senate', Synset('senate.n.01')),
#   ('expected', Synset('expect.v.01')),
#   ('approve', Synset('approve.v.01')),
#   ('study', Synset('survey.n.01')),
#   ('number', Synset('number.n.02')),
#   ('legislators', Synset('legislator.n.01')),
#   ('allotted', Synset('accord.v.02')),
#   ('rural', Synset('country.n.04')),
#   ('determine', Synset('determine.v.01')),
#   ('adjustments', Synset('adjustment.n.01')),
#   ('made', Synset('make.v.01'))],
#  [('expected', Synset('expect.v.01')),
#   ('make', Synset('make.v.01')),
#   ('traditional', Synset('traditional.a.01')),
#   ('visit', Synset('visit.n.01')),
#   ('chambers', Synset('chamber.n.03')),
#   ('work', Synset('work.v.01')),
#   ('adjournment', Synset('adjournment.n.01'))],
#  [('vandiver', Synset('person.n.01')),
#   ('likely', Synset('probably.r.01')),
#   ('mention', Synset('mention.v.01')),
#   ('100', Synset('hundred.s.01')),
#   ('million', Synset('million.n.01')),
#   ('highway', Synset('highway.n.01')),
#   ('bond', Synset('bond.n.02')),
#   ('issue', Synset('issue.n.01')),
#   ('approved', Synset('approve.v.01')),
#   ('session', Synset('school_term.n.01')),
#   ('first', Synset('first.a.01')),
#   ('priority', Synset('precedence.n.01')),
#   ('item', Synset('detail.n.01'))],
#  [('meanwhile', Synset('meanwhile.r.01')),
#   ('learned', Synset('learn.v.02')),
#   ('is', Synset('be.v.01')),
#   ('very', Synset('very.r.01')),
#   ('near', Synset('about.r.07')),
#   ('being', Synset('be.v.01')),
#   ('ready', Synset('ready.a.01')),
#   ('issue', Synset('publish.v.02')),
#   ('first', Synset('first.a.01')),
#   ('30', Synset('thirty.s.01')),
#   ('million', Synset('million.s.01')),
#   ('worth', Synset('worth.n.01')),
#   ('highway', Synset('highway.n.01')),
#   ('reconstruction', Synset('reconstruction.n.02')),
#   ('bonds', Synset('bond.n.02'))],
#  [('bond', Synset('bond.n.02')),
#   ('issue', Synset('issue.n.01')),
#   ('go', Synset('move.v.13')),
#   ('state', Synset('state.n.04')),
#   ('courts', Synset('court.n.01')),
#   ('friendly', Synset('friendly.s.02')),
#   ('test', Synset('test.v.01')),
#   ('validity', Synset('validity.n.02')),
#   ('act', Synset('act.n.01')),
#   ('sales', Synset('sale.n.01')),
#   ('begin', Synset('get_down.v.07')),
#   ('contracts', Synset('contract.n.02')),
#   ('let', Synset('let.v.01')),
#   ('repair', Synset('repair.n.01')),
#   ('work', Synset('work.n.01')),
#   ('georgia', Synset('georgia.n.01')),
#   ('most', Synset('most.r.01')),
#   ('heavily', Synset('heavily.r.01')),
#   ('traveled', Synset('traveled.a.01')),
#   ('highways', Synset('highway.n.01'))],
#  [('source', Synset('informant.n.01')),
#   ('said', Synset('allege.v.01')),
#   ('also', Synset('besides.r.02')),
#   ('is', Synset('exist.v.01')),
#   ('plan', Synset('plan.n.01')),
#   ('there', Synset('there.r.01')),
#   ('issue', Synset('write_out.v.02')),
#   ('some', Synset('approximately.r.01')),
#   ('3', Synset('three.s.01')),
#   ('million', Synset('million.n.01')),
#   ('4', Synset('four.s.01')),
#   ('million', Synset('million.n.01')),
#   ('worth', Synset('worth.n.02')),
#   ('bonds', Synset('bond.n.02')),
#   ('rural', Synset('rural.a.01')),
#   ('road', Synset('road.n.01')),
#   ('construction', Synset('construction.n.01')),
#   ('work', Synset('work.n.01'))],
#  [('department', Synset('department.n.01')),
#   ('apparently', Synset('apparently.r.01')),
#   ('intends', Synset('intend.v.01')),
#   ('make', Synset('make.v.02')),
#   ('new', Synset('new.a.01')),
#   ('bonds', Synset('bond.n.02')),
#   ('issued', Synset('publish.v.02')),
#   ('time', Synset('time.n.01')),
#   ('portion', Synset('parcel.n.02')),
#   ('old', Synset('old.a.02')),
#   ('tax', Synset('tax.n.01')),
#   ('authorities', Synset('government.n.01'))],
#  [('vandiver', Synset('person.n.01')),
#   ('opened', Synset('open.v.02')),
#   ('race', Synset('race.n.01')),
#   ('governor', Synset('governor.n.01')),
#   ('battle', Synset('struggle.n.01')),
#   ('legislature', Synset('legislature.n.01')),
#   ('issuance', Synset('issue.n.04')),
#   ('50', Synset('fifty.s.01')),
#   ('million', Synset('million.n.01')),
#   ('worth', Synset('worth.n.01')),
#   ('rural', Synset('rural.a.02')),
#   ('roads', Synset('road.n.01')),
#   ('bonds', Synset('bond.n.02')),
#   ('proposed', Synset('nominate.v.02')),
#   ('then', Synset('then.s.01'))],
#  [('source', Synset('informant.n.01')),
#   ('told', Synset('tell.v.02')),
#   ('however', Synset('however.r.01')),
#   ('vandiver', Synset('person.n.01')),
#   ('not', Synset('not.r.01')),
#   ('consulted', Synset('consult.v.01')),
#   ('yet', Synset('so_far.r.01')),
#   ('plans', Synset('plan.n.01')),
#   ('issue', Synset('publish.v.02')),
#   ('new', Synset('new.a.01')),
#   ('rural', Synset('rural.a.01')),
#   ('roads', Synset('road.n.01')),
#   ('bonds', Synset('bond.n.02'))],
#  [('offer', Synset('offer.v.02')),
#   ('resolution', Synset('resolution.n.01')),
#   ('monday', Synset('monday.n.01')),
#   ('house', Synset('group.n.01')),
#   ('rescind', Synset('revoke.v.02')),
#   ('body', Synset('body.n.02')),
#   ('action', Synset('action.n.01')),
#   ('friday', Synset('friday.n.01')),
#   ('voting', Synset('vote.n.01')),
#   ('10', Synset('ten.s.01')),
#   ('day', Synset('day.n.01')),
#   ('increase', Synset('increase.n.02')),
#   ('expense', Synset('expense.n.01')),
#   ('allowances', Synset('allowance.n.02'))],
#  [('pelham', Synset('person.n.01')),
#   ('said', Synset('state.v.01')),
#   ('sunday', Synset('sunday.n.01')),
#   ('night', Synset('night.n.01')),
#   ('was', Synset('be.v.02')),
#   ('research', Synset('research.n.01')),
#   ('done', Synset('make.v.01')),
#   ('quickie', Synset('band_aid.n.02')),
#   ('vote', Synset('vote.n.01')),
#   ('increase', Synset('increase.n.02')),
#   ('repealed', Synset('revoke.v.02')),
#   ('outright', Synset('outright.r.01')),
#   ('notice', Synset('notification.n.03')),
#   ('first', Synset('first.r.01')),
#   ('given', Synset('give.v.05')),
#   ('reconsideration', Synset('reconsideration.n.01')),
#   ('action', Synset('action.n.01')),
#   ('sought', Synset('search.v.01'))],
#  [('emphasizing', Synset('stress.v.01')),
#   ('technical', Synset('technical.a.01')),
#   ('details', Synset('detail.n.01')),
#   ('not', Synset('not.r.01')),
#   ('fully', Synset('fully.r.01')),
#   ('pelham', Synset('person.n.01')),
#   ('said', Synset('state.v.01')),
#   ('resolution', Synset('resolution.n.01')),
#   ('seek', Synset('search.v.01')),
#   ('privilege', Synset('prerogative.n.01')),
#   ('resolution', Synset('resolution.n.01')),
#   ('house', Synset('group.n.01')),
#   ('voted', Synset('vote.v.01'))],
#  [('similar', Synset('similar.a.01')),
#   ('resolution', Synset('resolution.n.01')),
#   ('passed', Synset('pass.v.09')),
#   ('senate', Synset('senate.n.01')),
#   ('vote', Synset('vote.n.01')),
#   ('29', Synset('twenty-nine.n.01')),
#   ('5', Synset('five.n.01'))],
#  [('sunday', Synset('sunday.n.01')),
#   ('night', Synset('night.n.01')),
#   ('was', Synset('exist.v.01')),
#   ('word', Synset('word.n.02')),
#   ('resolution', Synset('resolution.n.01')),
#   ('offered', Synset('offer.v.02')),
#   ('there', Synset('there.r.01')),
#   ('rescind', Synset('revoke.v.02')),
#   ('action', Synset('action.n.01'))],
#  [('pelham', Synset('person.n.01')),
#   ('georgia', Synset('georgia.n.01')),
#   ('voters', Synset('voter.n.01')),
#   ('last', Synset('last.r.01')),
#   ('november', Synset('november.n.01')),
#   ('rejected', Synset('refuse.v.02')),
#   ('amendment', Synset('amendment.n.01')),
#   ('allow', Synset('permit.v.01')),
#   ('legislators', Synset('legislator.n.01')),
#   ('vote', Synset('vote.n.01')),
#   ('pay', Synset('wage.n.01')),
#   ('raises', Synset('raise.n.01')),
#   ('future', Synset('future.a.01')),
#   ('legislature', Synset('legislature.n.01')),
#   ('sessions', Synset('school_term.n.01'))],
#  [('veteran', Synset('seasoned.s.02')),
#   ('legislator', Synset('legislator.n.01')),
#   ('ask', Synset('ask.v.02')),
#   ('monday', Synset('monday.n.01')),
#   ('back', Synset('back.v.01')),
#   ('federal', Synset('federal.s.01')),
#   ('aid', Synset('aid.n.03')),
#   ('education', Synset('education.n.04')),
#   ('consistently', Synset('systematically.r.01')),
#   ('opposed', Synset('oppose.v.01')),
#   ('past', Synset('past.n.01'))],
#  [('commerce', Synset('group.n.01')),
#   ('asking', Synset('ask.v.02')),
#   ('house', Synset('group.n.01')),
#   ('privilege', Synset('privilege.n.01')),
#   ('resolution', Synset('resolution.n.01')),
#   ('endorse', Synset('back.v.01')),
#   ('increased', Synset('increased.a.01')),
#   ('federal', Synset('federal.a.02')),
#   ('support', Synset('support.n.01')),
#   ('public', Synset('public.a.01')),
#   ('education', Synset('education.n.04')),
#   ('funds', Synset('fund.n.01')),
#   ('received', Synset('receive.v.01')),
#   ('expended', Synset('spend.v.02')),
#   ('state', Synset('state.n.04')),
#   ('funds', Synset('funds.n.01'))],
#  [('barber', Synset('person.n.01')),
#   ('is', Synset('be.v.03')),
#   ('13th', Synset('thirteenth.s.01')),
#   ('year', Synset('year.n.01')),
#   ('legislator', Synset('legislator.n.01')),
#   ('said', Synset('state.v.01')),
#   ('are', Synset('exist.v.01')),
#   ('some', Synset('some.a.01')),
#   ('members', Synset('member.n.01')),
#   ('congressional', Synset('congressional.a.01')),
#   ('delegation', Synset('deputation.n.01')),
#   ('washington', Synset('capital.n.06')),
#   ('see', Synset('witness.v.02')),
#   ('resolution', Synset('resolution.n.01')),
#   ('passed', Synset('pass.v.09'))],
#  [('added', Synset('add.v.02')),
#   ('georgia', Synset('georgia.n.01')),
#   ('congressmen', Synset('congressman.n.01')),
#   ('specifically', Synset('specifically.r.01')),
#   ('asked', Synset('ask.v.02')),
#   ('offer', Synset('offer.v.02')),
#   ('resolution', Synset('resolution.n.01'))],
#  [('resolution', Synset('resolution.n.01')),
#   ('barber', Synset('person.n.01')),
#   ('tossed', Synset('chuck.v.01')),
#   ('house', Synset('group.n.01')),
#   ('hopper', Synset('hopper.n.01')),
#   ('friday', Synset('friday.n.01')),
#   ('formally', Synset('formally.r.01')),
#   ('read', Synset('read.v.03')),
#   ('monday', Synset('monday.n.01'))],
#  [('says', Synset('allege.v.01')),
#   ('event', Synset('event.n.02')),
#   ('congress', Synset('group.n.01')),
#   ('provide', Synset('supply.v.01')),
#   ('increase', Synset('increase.n.02')),
#   ('federal', Synset('federal.s.01')),
#   ('funds', Synset('fund.n.01')),
#   ('directed', Synset('direct.v.01')),
#   ('give', Synset('give.v.10')),
#   ('priority', Synset('precedence.n.01')),
#   ('teacher', Synset('teacher.n.01')),
#   ('pay', Synset('wage.n.01')),
#   ('raises', Synset('raise.n.01'))],
#  [('long', Synset('long.a.01')),
#   ('hot', Synset('hot.a.03')),
#   ('controversy', Synset('controversy.n.01')),
#   ('has', Synset('own.v.01')),
#   ('new', Synset('new.a.01')),
#   ('elected', Synset('elect.v.01')),
#   ('policeman', Synset('policeman.n.01')),
#   ('put', Synset('frame.v.04')),
#   ('election', Synset('election.n.01')),
#   ('ever', Synset('ever.r.01')),
#   ('saw', Synset('witness.v.02')),
#   ('county', Synset('county.n.01'))],
#  [('new', Synset('new.a.01')),
#   ('is', Synset('be.v.02')),
#   ('veteran', Synset('seasoned.s.02')),
#   ('agriculture', Synset('agribusiness.n.01')),
#   ('teacher', Synset('teacher.n.01')),
#   ('defeated', Synset('get_the_better_of.v.01')),
#   ('chairman', Synset('president.n.04'))],
#  [('davis', Synset('person.n.01')),
#   ('received', Synset('receive.v.01')),
#   ('votes', Synset('vote.n.02')),
#   ('saturday', Synset('saturday.n.01')),
#   ('election', Synset('election.n.01')),
#   ('bush', Synset('person.n.01')),
#   ('got', Synset('receive.v.02'))],
#  [('ordinary', Synset('ordinary.n.01')),
#   ('armed', Synset('arm.v.01')),
#   ('pistol', Synset('pistol.n.01')),
#   ('polls', Synset('polls.n.01')),
#   ('insure', Synset('insure.v.04')),
#   ('order', Synset('order.n.03'))],
#  [('was', Synset('be.v.01')),
#   ('election', Synset('election.n.01')),
#   ('ever', Synset('ever.r.01')),
#   ('saw', Synset('witness.v.02')),
#   ('said', Synset('state.v.01'))],
#  [('being', Synset('be.v.03')),
#   ('polls', Synset('polls.n.01')),
#   ('was', Synset('be.v.01')),
#   ('just', Synset('precisely.r.01')),
#   ('being', Synset('be.v.03')),
#   ('church', Synset('church_service.n.01'))],
#  [('smell', Synset('smell.v.01')),
#   ('drop', Synset('drop.n.02')),
#   ('liquor', Synset('liquor.n.01')),
#   ('have', Synset('experience.v.03')),
#   ('trouble', Synset('fuss.n.02'))],
#  [('campaign', Synset('political_campaign.n.01')),
#   ('leading', Synset('lead_up.v.01')),
#   ('election', Synset('election.n.01')),
#   ('was', Synset('be.v.01')),
#   ('not', Synset('not.r.01')),
#   ('so', Synset('so.r.01')),
#   ('quiet', Synset('quiet.a.01')),
#   ('however', Synset('however.r.01'))],
#  [('marked', Synset('distinguish.v.03')),
#   ('controversy', Synset('controversy.n.01')),
#   ('anonymous', Synset('anonymous.a.01')),
#   ('midnight', Synset('midnight.n.01')),
#   ('veiled', Synset('veiled.a.01')),
#   ('threats', Synset('threat.n.03')),
#   ('violence', Synset('violence.n.01'))],
#  [('former', Synset('former.a.01')),
#   ('county', Synset('county.n.01')),
#   ('shot', Synset('shoot.v.02')),
#   ('death', Synset('death.n.03')),
#   ('march', Synset('march.n.01')),
#   ('four', Synset('four.s.01')),
#   ('days', Synset('day.n.01')),
#   ('resigned', Synset('vacate.v.01')),
#   ('post', Synset('position.n.06')),
#   ('dispute', Synset('dispute.n.01')),
#   ('county', Synset('county.n.01'))],
#  [('election', Synset('election.n.01')),
#   ('campaign', Synset('political_campaign.n.01')),
#   ('candidates', Synset('campaigner.n.01')),
#   ('davis', Synset('person.n.01')),
#   ('bush', Synset('person.n.01')),
#   ('reportedly', Synset('reportedly.r.01')),
#   ('received', Synset('receive.v.01')),
#   ('anonymous', Synset('anonymous.a.01'))],
#  [('ordinary', Synset('ordinary.n.01')),
#   ('williams', Synset('person.n.01')),
#   ('said', Synset('state.v.01')),
#   ('too', Synset('besides.r.02')),
#   ('subjected', Synset('subject.v.01')),
#   ('anonymous', Synset('anonymous.a.01')),
#   ('calls', Synset('call.n.01')),
#   ('soon', Synset('soon.r.01')),
#   ('scheduled', Synset('schedule.v.01')),
#   ('election', Synset('election.n.01'))],
#  [('many', Synset('many.a.01')),
#   ('citizens', Synset('citizen.n.01')),
#   ('feared', Synset('fear.v.01')),
#   ('be', Synset('be.v.02')),
#   ('irregularities', Synset('abnormality.n.04')),
#   ('polls', Synset('polls.n.01')),
#   ('williams', Synset('person.n.01')),
#   ('got', Synset('get.v.01')),
#   ('permit', Synset('license.n.01')),
#   ('carry', Synset('carry.v.02')),
#   ('gun', Synset('gun.n.01')),
#   ('promised', Synset('promise.v.02')),
#   ('orderly', Synset('orderly.a.01')),
#   ('election', Synset('election.n.01'))],
#  [('said', Synset('state.v.01')),
#   ('ordinary', Synset('ordinary.n.01')),
#   ('apparently', Synset('apparently.r.01')),
#   ('promise', Synset('promise.n.01'))],
#  [('went', Synset('proceed.v.04')),
#   ('real', Synset('very.r.01')),
#   ('smooth', Synset('smooth.a.01')),
#   ('sheriff', Synset('sheriff.n.01')),
#   ('said', Synset('state.v.01'))],
#  [('was', Synset('be.v.02')), ('trouble', Synset('fuss.n.02'))]]

# %% [markdown]
# ### Exercise 1.1
# Write a function `find_sense_distributions()` which finds the distribution of senses for every word in a list of sentences (in the format returned by `extract_senses()`).  Your output should be a dictionary of dictionaries.  The key to the outermost dictionary should be the word_form and the key to the inner dictionaries should be the sense tag.
#
# Test your function on `some_sentences`

# %%
def find_sense_distributions(some_sentences):
    allwords={}
    for sentence in some_sentences:
        for (word,sense) in sentence:
            thisword=allwords.get(word,{})
            thisword[sense]=thisword.get(sense,0)+1
            allwords[word]=thisword
    return allwords

# %%
sense_dists=find_sense_distributions(some_sentences)
sense_dists
# Out:
# {'10': {Synset('ten.s.01'): 1},
#  '100': {Synset('hundred.s.01'): 1},
#  '13th': {Synset('thirteenth.s.01'): 1},
#  '29': {Synset('twenty-nine.n.01'): 1},
#  '3': {Synset('three.s.01'): 1},
#  '30': {Synset('thirty.s.01'): 1},
#  '4': {Synset('four.s.01'): 1},
#  '5': {Synset('five.n.01'): 1},
#  '50': {Synset('fifty.s.01'): 1},
#  'achieve': {Synset('achieve.v.01'): 1},
#  'act': {Synset('act.n.01'): 1, Synset('act.v.01'): 1},
#  'action': {Synset('action.n.01'): 3},
#  'actions': {Synset('action.n.01'): 1},
#  'added': {Synset('add.v.02'): 3},
#  'adjournment': {Synset('adjournment.n.01'): 2},
#  'adjustments': {Synset('adjustment.n.01'): 1},
#  'administration': {Synset('administration.n.01'): 2},
#  'administrators': {Synset('administrator.n.01'): 1},
#  'afternoon': {Synset('afternoon.n.01'): 1},
#  'age': {Synset('age.n.01'): 2},
#  'agriculture': {Synset('agribusiness.n.01'): 1},
#  'aid': {Synset('aid.n.03'): 1},
#  'airport': {Synset('airport.n.01'): 2},
#  'all': {Synset('all.a.01'): 1},
#  'allotted': {Synset('accord.v.02'): 1},
#  'allow': {Synset('permit.v.01'): 1},
#  'allowances': {Synset('allowance.n.02'): 1},
#  'allowed': {Synset('let.v.01'): 1},
#  'alpharetta': {Synset('location.n.01'): 1},
#  'also': {Synset('besides.r.02'): 3},
#  'alternative': {Synset('alternative.s.02'): 1},
#  'ambiguous': {Synset('ambiguous.a.02'): 1},
#  'amendment': {Synset('amendment.n.01'): 1},
#  'amicable': {Synset('amicable.a.01'): 1},
#  'announced': {Synset('announce.v.01'): 1},
#  'anonymous': {Synset('anonymous.a.01'): 3},
#  'apparently': {Synset('apparently.r.01'): 2},
#  'appointed': {Synset('appointive.a.02'): 1},
#  'appointment': {Synset('appointment.n.01'): 1},
#  'appraisers': {Synset('appraiser.n.01'): 1},
#  'approve': {Synset('approve.v.01'): 1},
#  'approved': {Synset('approve.v.01'): 2},
#  'are': {Synset('be.v.01'): 2, Synset('exist.v.01'): 1},
#  'armed': {Synset('arm.v.01'): 1},
#  'ask': {Synset('ask.v.02'): 1},
#  'asked': {Synset('ask.v.01'): 1, Synset('ask.v.02'): 1},
#  'asking': {Synset('ask.v.02'): 1},
#  'assistance': {Synset('aid.n.02'): 1},
#  'assistant': {Synset('assistant.n.01'): 1},
#  'atlanta': {Synset('atlanta.n.01'): 5},
#  'attended': {Synset('attend.v.01'): 1},
#  'attorney': {Synset('lawyer.n.01'): 2},
#  'attorneys': {Synset('lawyer.n.01'): 1},
#  'audience': {Synset('audience.n.01'): 2},
#  'aug.': {Synset('august.n.01'): 1},
#  'authorities': {Synset('government.n.01'): 1},
#  'automobile': {Synset('car.n.01'): 1},
#  'available': {Synset('available.a.01'): 1},
#  'awarding': {Synset('award.n.01'): 1},
#  'back': {Synset('back.v.01'): 1},
#  'ballot': {Synset('vote.n.01'): 1},
#  'barber': {Synset('person.n.01'): 2},
#  'battle': {Synset('struggle.n.01'): 1},
#  'be': {Synset('be.v.01'): 1, Synset('be.v.02'): 2},
#  'became': {Synset('become.v.02'): 1},
#  'become': {Synset('become.v.02'): 1},
#  'been': {Synset('be.v.08'): 1, Synset('constitute.v.01'): 1},
#  'begin': {Synset('get_down.v.07'): 1},
#  'being': {Synset('be.v.01'): 1, Synset('be.v.03'): 2},
#  'believes': {Synset('believe.v.03'): 1},
#  'bellwood': {Synset('location.n.01'): 1},
#  'best': {Synset('best.a.01'): 1},
#  'body': {Synset('body.n.02'): 1},
#  'bond': {Synset('bond.n.02'): 3},
#  'bonds': {Synset('bond.n.02'): 5},
#  'brief': {Synset('brief.s.01'): 1},
#  'brought': {Synset('bring.v.03'): 1},
#  'burden': {Synset('burden.n.01'): 1},
#  'bush': {Synset('person.n.01'): 2},
#  'byrd': {Synset('person.n.01'): 1},
#  'caldwell': {Synset('person.n.01'): 2},
#  'calls': {Synset('call.n.01'): 1},
#  'campaign': {Synset('political_campaign.n.01'): 5},
#  'candidate': {Synset('campaigner.n.01'): 4},
#  'candidates': {Synset('campaigner.n.01'): 2},
#  'career': {Synset('career.n.01'): 1},
#  'carry': {Synset('carry.v.02'): 1},
#  'chairman': {Synset('president.n.04'): 2},
#  'chambers': {Synset('chamber.n.03'): 1},
#  'charge': {Synset('mission.n.03'): 1},
#  'charged': {Synset('appoint.v.02'): 1, Synset('charge.v.06'): 1},
#  'church': {Synset('church_service.n.01'): 1},
#  'citizens': {Synset('citizen.n.01'): 1},
#  'city': {Synset('city.n.01'): 1, Synset('city.n.02'): 4},
#  'clerical': {Synset('clerical.a.01'): 1},
#  'commented': {Synset('comment.v.01'): 2},
#  'commerce': {Synset('group.n.01'): 1},
#  'compensation': {Synset('compensation.n.01'): 1},
#  'concessionaires': {Synset('concessionaire.n.01'): 1},
#  'conducted': {Synset('conduct.v.01'): 1},
#  'congress': {Synset('group.n.01'): 1},
#  'congressional': {Synset('congressional.a.01'): 1},
#  'congressmen': {Synset('congressman.n.01'): 1},
#  'considering': {Synset('consider.v.04'): 1},
#  'consistently': {Synset('systematically.r.01'): 1},
#  'construction': {Synset('construction.n.01'): 1},
#  'consulted': {Synset('consult.v.01'): 1},
#  'continue': {Synset('continue.v.01'): 1},
#  'contracts': {Synset('contract.n.02'): 1},
#  'controversy': {Synset('controversy.n.01'): 2},
#  'coordinator': {Synset('coordinator.n.01'): 1},
#  'cost': {Synset('cost.n.01'): 1},
#  'costs': {Synset('cost.n.01'): 1},
#  'counties': {Synset('county.n.01'): 2},
#  'county': {Synset('county.n.01'): 5},
#  'couple': {Synset('couple.n.02'): 2},
#  'courses': {Synset('course.n.03'): 1},
#  'court': {Synset('court.n.01'): 3},
#  'courts': {Synset('court.n.01'): 1},
#  'criticisms': {Synset('criticism.n.01'): 1},
#  'crowd': {Synset('crowd.n.01'): 1},
#  'cruelty': {Synset('cruelty.n.02'): 1},
#  'date': {Synset('date.n.01'): 1},
#  'daughter': {Synset('daughter.n.01'): 1},
#  'davis': {Synset('person.n.01'): 2},
#  'day': {Synset('day.n.01'): 1},
#  'days': {Synset('day.n.01'): 1},
#  'death': {Synset('death.n.03'): 1},
#  'defeated': {Synset('get_the_better_of.v.01'): 1},
#  'delegation': {Synset('deputation.n.01'): 1},
#  'department': {Synset('department.n.01'): 1},
#  'departments': {Synset('department.n.01'): 1},
#  'deputies': {Synset('deputy.n.02'): 1},
#  'deserves': {Synset('deserve.v.01'): 1},
#  'details': {Synset('detail.n.01'): 1},
#  'determine': {Synset('determine.v.01'): 1},
#  'directed': {Synset('direct.v.01'): 1},
#  'director': {Synset('director.n.01'): 1},
#  'disable': {Synset('disable.v.01'): 1},
#  'disproportionate': {Synset('disproportionate.a.01'): 1},
#  'dispute': {Synset('dispute.n.01'): 1},
#  'dissents': {Synset('dissent.n.02'): 1},
#  'distribute': {Synset('distribute.v.01'): 1},
#  'distribution': {Synset('distribution.n.02'): 1},
#  'divorce': {Synset('divorce.n.01'): 1},
#  'do': {Synset('make.v.01'): 1},
#  'doctor': {Synset('doctor.n.01'): 1},
#  'dollar': {Synset('dollar.n.01'): 1},
#  'done': {Synset('make.v.01'): 1},
#  'drop': {Synset('drop.n.02'): 1},
#  'duty': {Synset('duty.n.02'): 1},
#  'education': {Synset('education.n.04'): 2},
#  'effected': {Synset('effect.v.01'): 1},
#  'effective': {Synset('effective.s.04'): 1},
#  'efficiency': {Synset('efficiency.n.02'): 1},
#  'elaborate': {Synset('elaborate.v.01'): 1},
#  'elected': {Synset('elect.v.01'): 1, Synset('elective.a.01'): 2},
#  'election': {Synset('election.n.01'): 12},
#  'eliminate': {Synset('extinguish.v.04'): 1},
#  'emphasizing': {Synset('stress.v.01'): 1},
#  'employed': {Synset('hire.v.01'): 2},
#  'employes': {Synset('employee.n.01'): 1},
#  'enabling': {Synset('enabling.a.01'): 1},
#  'encouragement': {Synset('boost.n.01'): 1},
#  'end': {Synset('end.n.02'): 1, Synset('goal.n.01'): 1},
#  'endorse': {Synset('back.v.01'): 1},
#  'enter': {Synset('enroll.v.01'): 2},
#  'entering': {Synset('enroll.v.01'): 1},
#  'enthusiasm': {Synset('enthusiasm.n.03'): 1},
#  'enthusiastic': {Synset('enthusiastic.a.01'): 1},
#  'equitable': {Synset('equitable.a.01'): 1},
#  'establishment': {Synset('constitution.n.02'): 1},
#  'event': {Synset('event.n.02'): 1},
#  'ever': {Synset('ever.r.01'): 2},
#  'evidence': {Synset('evidence.n.01'): 1},
#  'exception': {Synset('exception.n.01'): 2},
#  'expected': {Synset('expect.v.01'): 4},
#  'expended': {Synset('spend.v.02'): 1},
#  'expense': {Synset('expense.n.01'): 1},
#  'experienced': {Synset('experienced.a.01'): 1},
#  'expires': {Synset('run_out.v.04'): 1},
#  'extern': {Synset('extern.n.01'): 1},
#  'face': {Synset('confront.v.01'): 1},
#  'failure': {Synset('failure.n.01'): 1},
#  'feared': {Synset('fear.v.01'): 1},
#  'featured': {Synset('featured.s.01'): 1},
#  'federal': {Synset('federal.a.02'): 1, Synset('federal.s.01'): 3},
#  'feel': {Synset('find.v.05'): 1},
#  'fees': {Synset('fee.n.01'): 1},
#  'filed': {Synset('file.v.01'): 1},
#  'find': {Synset('rule.v.04'): 1},
#  'first': {Synset('first.a.01'): 3, Synset('first.r.01'): 1},
#  'five': {Synset('five.s.01'): 1},
#  'follow': {Synset('adopt.v.01'): 1, Synset('follow.v.01'): 1},
#  'force': {Synset('coerce.v.01'): 1},
#  'formally': {Synset('formally.r.01'): 1},
#  'former': {Synset('former.a.01'): 1},
#  'found': {Synset('determine.v.01'): 1},
#  'four': {Synset('four.s.01'): 2},
#  'friday': {Synset('friday.n.01'): 4},
#  'friendly': {Synset('friendly.s.02'): 1},
#  'fully': {Synset('fully.r.01'): 1},
#  'fulton': {Synset('location.n.01'): 5},
#  'funds': {Synset('fund.n.01'): 7, Synset('funds.n.01'): 1},
#  'further': {Synset('far.r.02'): 1},
#  'future': {Synset('future.a.01'): 1},
#  'gainesville': {Synset('location.n.01'): 1},
#  'general': {Synset('general.a.01'): 1},
#  'generally': {Synset('by_and_large.r.01'): 1},
#  'georgia': {Synset('georgia.n.01'): 6},
#  'getting': {Synset('receive.v.02'): 1},
#  'give': {Synset('give.v.10'): 1},
#  'given': {Synset('give.v.05'): 1},
#  'go': {Synset('move.v.13'): 1},
#  'gop': {Synset('republican_party.n.01'): 1},
#  'got': {Synset('get.v.01'): 1, Synset('receive.v.02'): 1},
#  'governments': {Synset('government.n.01'): 1},
#  'governor': {Synset('governor.n.01'): 2},
#  'griffin': {Synset('location.n.01'): 1},
#  'guardians': {Synset('defender.n.01'): 1},
#  'gubernatorial': {Synset('gubernatorial.a.01'): 1},
#  'gun': {Synset('gun.n.01'): 1},
#  'had': {Synset('own.v.01'): 1},
#  'handful': {Synset('handful.n.01'): 1},
#  'handling': {Synset('handling.n.01'): 1},
#  'hard-fought': {Synset('hard-fought.s.01'): 1},
#  'hartsfield': {Synset('person.n.01'): 2},
#  'has': {Synset('own.v.01'): 1},
#  'have': {Synset('experience.v.03'): 1,
#   Synset('get.v.03'): 1,
#   Synset('have.v.01'): 1},
#  'head': {Synset('head.v.01'): 1},
#  'heavily': {Synset('heavily.r.01'): 1},
#  'held': {Synset('hold.v.03'): 2},
#  'highway': {Synset('highway.n.01'): 3},
#  'highways': {Synset('highway.n.01'): 1},
#  'hold': {Synset('hold.v.03'): 1},
#  'home': {Synset('dwelling.n.01'): 1, Synset('home.r.01'): 1},
#  'hopper': {Synset('hopper.n.01'): 1},
#  'hot': {Synset('hot.a.03'): 1},
#  'house': {Synset('group.n.01'): 4},
#  'however': {Synset('however.r.01'): 3},
#  'hurdle': {Synset('hurdle.n.01'): 1},
#  'implementation': {Synset('execution.n.06'): 2},
#  'improving': {Synset('better.v.03'): 1},
#  'inadequate': {Synset('inadequate.a.01'): 1},
#  'incorporated': {Synset('integrate.v.01'): 1},
#  'increase': {Synset('increase.n.02'): 3},
#  'increased': {Synset('increased.a.01'): 1},
#  'influences': {Synset('influence.n.01'): 1},
#  'insure': {Synset('insure.v.04'): 1},
#  'intends': {Synset('intend.v.01'): 1},
#  'interest': {Synset('interest.n.01'): 1, Synset('sake.n.01'): 1},
#  'interim': {Synset('interim.s.01'): 1},
#  'interlude': {Synset('interlude.n.01'): 1},
#  'inure': {Synset('inure.v.01'): 1},
#  'investigate': {Synset('investigate.v.02'): 1},
#  'investigation': {Synset('probe.n.01'): 1},
#  'irregularities': {Synset('abnormality.n.04'): 3},
#  'is': {Synset('be.v.01'): 2,
#   Synset('be.v.02'): 3,
#   Synset('be.v.03'): 2,
#   Synset('exist.v.01'): 1},
#  'issuance': {Synset('issue.n.04'): 1},
#  'issue': {Synset('issue.n.01'): 2,
#   Synset('publish.v.02'): 2,
#   Synset('write_out.v.02'): 1},
#  'issued': {Synset('publish.v.02'): 1},
#  'item': {Synset('detail.n.01'): 1},
#  'items': {Synset('detail.n.01'): 1},
#  'jail': {Synset('jail.n.01'): 1},
#  'jan.': {Synset('january.n.01'): 2},
#  'jurors': {Synset('juror.n.01'): 2},
#  'jury': {Synset('jury.n.01'): 15},
#  'just': {Synset('precisely.r.01'): 1},
#  'keeping': {Synset('keep.v.01'): 1},
#  'lacking': {Synset('deficient.s.01'): 1},
#  'last': {Synset('last.r.01'): 1},
#  'law': {Synset('law.n.02'): 3},
#  'laws': {Synset('law.n.02'): 2},
#  'leading': {Synset('lead_up.v.01'): 1},
#  'learned': {Synset('learn.v.02'): 1},
#  'legislator': {Synset('legislator.n.01'): 2},
#  'legislators': {Synset('legislator.n.01'): 4},
#  'legislature': {Synset('legislature.n.01'): 3},
#  'less': {Synset('less.a.01'): 1},
#  'let': {Synset('let.v.01'): 1},
#  'likely': {Synset('probably.r.01'): 1},
#  'liquor': {Synset('liquor.n.01'): 1},
#  'listed': {Synset('list.v.01'): 3},
#  'lived': {Synset('populate.v.01'): 1},
#  'long': {Synset('long.a.01'): 1},
#  'made': {Synset('make.v.01'): 1},
#  'major': {Synset('major.a.01'): 1},
#  'make': {Synset('cause.v.01'): 1,
#   Synset('make.v.01'): 1,
#   Synset('make.v.02'): 1},
#  'making': {Synset('make.v.01'): 1},
#  'management': {Synset('management.n.02'): 1},
#  'manner': {Synset('manner.n.01'): 2},
#  'many': {Synset('many.a.01'): 1},
#  'march': {Synset('march.n.01'): 1},
#  'marked': {Synset('distinguish.v.03'): 1},
#  'married': {Synset('marry.v.01'): 1},
#  'matters': {Synset('topic.n.02'): 1},
#  'mayor': {Synset('mayor.n.01'): 5},
#  'meanwhile': {Synset('meanwhile.r.01'): 1},
#  'meeting': {Synset('meeting.n.01'): 2},
#  'members': {Synset('member.n.01'): 1},
#  'mental': {Synset('mental.a.02'): 1},
#  'mention': {Synset('mention.v.01'): 1},
#  'midnight': {Synset('midnight.n.01'): 1},
#  'million': {Synset('million.n.01'): 4, Synset('million.s.01'): 2},
#  'modernizing': {Synset('overhaul.v.02'): 1},
#  'monday': {Synset('monday.n.01'): 5},
#  'money': {Synset('money.n.01'): 2},
#  'more': {Synset('more.r.02'): 2},
#  'most': {Synset('most.r.01'): 1},
#  'names': {Synset('name.n.01'): 1},
#  'near': {Synset('about.r.07'): 1},
#  'nevertheless': {Synset('however.r.01'): 1},
#  'new': {Synset('new.a.01'): 6},
#  'newly': {Synset('newly.r.01'): 1},
#  'next': {Synset('future.s.03'): 1},
#  'night': {Synset('night.n.01'): 4},
#  'no': {Synset('no.r.01'): 1},
#  'not': {Synset('not.r.01'): 6},
#  'notice': {Synset('notification.n.03'): 1},
#  'november': {Synset('november.n.01'): 1},
#  'number': {Synset('number.n.01'): 1, Synset('number.n.02'): 2},
#  'obtain': {Synset('obtain.v.01'): 1},
#  'occupation': {Synset('occupation.n.01'): 1},
#  'october': {Synset('october.n.01'): 1},
#  'offer': {Synset('offer.v.02'): 2},
#  'offered': {Synset('offer.v.02'): 1},
#  'offices': {Synset('agency.n.01'): 1},
#  'official': {Synset('official.n.01'): 1},
#  'officials': {Synset('official.n.01'): 1},
#  'often': {Synset('frequently.r.01'): 1},
#  'old': {Synset('old.a.02'): 1},
#  'one': {Synset('one.s.01'): 4},
#  'only': {Synset('merely.r.01'): 1},
#  'opened': {Synset('open.v.02'): 1},
#  'operated': {Synset('function.v.01'): 1, Synset('operate.v.01'): 1},
#  'operation': {Synset('operation.n.01'): 1},
#  'opposed': {Synset('oppose.v.01'): 1},
#  'opposes': {Synset('oppose.v.01'): 1},
#  'order': {Synset('order.n.03'): 1},
#  'orderly': {Synset('orderly.a.01'): 1},
#  'ordinary': {Synset('ordinary.n.01'): 3, Synset('ordinary.n.02'): 1},
#  'other': {Synset('other.a.01'): 2},
#  'outgoing': {Synset('outgoing.a.01'): 1},
#  'outmoded': {Synset('antique.s.02'): 1},
#  'outright': {Synset('outright.r.01'): 1},
#  'over-all': {Synset('overall.s.02'): 1},
#  'party': {Synset('party.n.01'): 1},
#  'pass': {Synset('legislate.v.01'): 1},
#  'passed': {Synset('pass.v.09'): 2},
#  'past': {Synset('past.n.01'): 1},
#  'pay': {Synset('wage.n.01'): 2},
#  'pelham': {Synset('person.n.01'): 3},
#  'pension': {Synset('pension.n.01'): 1},
#  'periodic': {Synset('periodic.a.01'): 1},
#  'permit': {Synset('license.n.01'): 1, Synset('permit.v.01'): 1},
#  'personnel': {Synset('force.n.04'): 2},
#  'petition': {Synset('request.n.01'): 4},
#  'petitions': {Synset('request.n.01'): 2},
#  'pistol': {Synset('pistol.n.01'): 1},
#  'place': {Synset('put.v.01'): 2},
#  'plan': {Synset('plan.n.01'): 2},
#  'plans': {Synset('plan.n.01'): 1},
#  'platform': {Synset('platform.n.02'): 1},
#  'policeman': {Synset('policeman.n.01'): 1},
#  'policies': {Synset('policy.n.01'): 1},
#  'political': {Synset('political.a.01'): 1, Synset('political.a.03'): 1},
#  'polls': {Synset('polls.n.01'): 3},
#  'populous': {Synset('populous.s.01'): 1},
#  'portion': {Synset('parcel.n.02'): 2},
#  'possible': {Synset('potential.a.01'): 1},
#  'post': {Synset('position.n.06'): 1},
#  'practices': {Synset('practice.n.01'): 3},
#  'praise': {Synset('praise.n.01'): 1},
#  'praised': {Synset('praise.v.01'): 1},
#  'present': {Synset('present.a.01'): 1},
#  'presentments': {Synset('presentment.n.01'): 1},
#  'prices': {Synset('price.n.02'): 1},
#  'pricing': {Synset('pricing.n.01'): 1},
#  'primary': {Synset('primary.n.01'): 3},
#  'priority': {Synset('precedence.n.01'): 2},
#  'privilege': {Synset('prerogative.n.01'): 1, Synset('privilege.n.01'): 1},
#  'problem': {Synset('problem.n.02'): 1},
#  'produced': {Synset('produce.v.04'): 1},
#  'program': {Synset('plan.n.01'): 2},
#  'promise': {Synset('promise.n.01'): 1},
#  'promised': {Synset('promise.v.02'): 1},
#  'proportionate': {Synset('proportionate.s.02'): 1},
#  'proposed': {Synset('nominate.v.02'): 1},
#  'protect': {Synset('protect.v.01'): 1},
#  'provide': {Synset('supply.v.01'): 2},
#  'public': {Synset('public.a.01'): 1},
#  'purpose': {Synset('purpose.n.01'): 1},
#  'put': {Synset('frame.v.04'): 1},
#  'quickie': {Synset('band_aid.n.02'): 1},
#  'quiet': {Synset('quiet.a.01'): 1},
#  'race': {Synset('race.n.01'): 3},
#  'raises': {Synset('raise.n.01'): 2},
#  'rally': {Synset('rally.n.01'): 1},
#  're-set': {Synset('reset.v.01'): 1},
#  'read': {Synset('read.v.03'): 1},
#  'ready': {Synset('ready.a.01'): 1},
#  'real': {Synset('very.r.01'): 1},
#  'realize': {Synset('recognize.v.02'): 1},
#  'reasonable': {Synset('fair.s.02'): 1},
#  'receive': {Synset('receive.v.01'): 1},
#  'received': {Synset('receive.v.01'): 3, Synset('receive.v.02'): 1},
#  'receives': {Synset('receive.v.01'): 1},
#  'recent': {Synset('late.s.03'): 1},
#  'recommendations': {Synset('recommendation.n.01'): 1},
#  'recommended': {Synset('recommend.v.01'): 4},
#  'reconsideration': {Synset('reconsideration.n.01'): 1},
#  'reconstruction': {Synset('reconstruction.n.02'): 1},
#  'reduce': {Synset('reduce.v.01'): 1},
#  'reelection': {Synset('reelection.n.01'): 1},
#  'regarding': {Synset('involve.v.01'): 1},
#  'registered': {Synset('register.v.03'): 1},
#  'registration': {Synset('registration.n.01'): 1},
#  'rejected': {Synset('refuse.v.02'): 1},
#  'relative': {Synset('relative.a.01'): 1},
#  'remedy': {Synset('rectify.v.04'): 1},
#  'repair': {Synset('repair.n.01'): 1},
#  'repealed': {Synset('revoke.v.02'): 1},
#  'reportedly': {Synset('reportedly.r.01'): 1},
#  'reports': {Synset('report.n.03'): 2},
#  'republicans': {Synset('republican.n.01'): 5},
#  'requesting': {Synset('request.v.02'): 1},
#  'rescind': {Synset('revoke.v.02'): 2},
#  'research': {Synset('research.n.01'): 1},
#  'resignation': {Synset('resignation.n.03'): 1},
#  'resigned': {Synset('vacate.v.01'): 2},
#  'resolution': {Synset('resolution.n.01'): 9},
#  'responses': {Synset('reception.n.01'): 1},
#  'result': {Synset('consequence.n.01'): 1},
#  'revised': {Synset('revise.v.01'): 1},
#  'road': {Synset('road.n.01'): 1},
#  'roads': {Synset('road.n.01'): 2},
#  'run': {Synset('campaign.v.01'): 1},
#  'rural': {Synset('country.n.04'): 1,
#   Synset('rural.a.01'): 2,
#   Synset('rural.a.02'): 1},
#  'said': {Synset('allege.v.01'): 11, Synset('state.v.01'): 13},
#  'sales': {Synset('sale.n.01'): 1},
#  'saturday': {Synset('saturday.n.01'): 1},
#  'savannah': {Synset('savannah.n.01'): 1},
#  'saw': {Synset('witness.v.02'): 2},
#  'says': {Synset('allege.v.01'): 2},
#  'scheduled': {Synset('schedule.v.01'): 1},
#  'see': {Synset('witness.v.02'): 1},
#  'seek': {Synset('search.v.01'): 1},
#  'senate': {Synset('senate.n.01'): 2},
#  'sept.': {Synset('september.n.01'): 2},
#  'september': {Synset('september.n.01'): 1},
#  'servants': {Synset('servant.n.01'): 1},
#  'serve': {Synset('serve.v.03'): 1},
#  'session': {Synset('school_term.n.01'): 2},
#  'sessions': {Synset('school_term.n.01'): 1},
#  'sheriff': {Synset('sheriff.n.01'): 1},
#  'shortly': {Synset('soon.r.01'): 1},
#  'shot': {Synset('shoot.v.02'): 1},
#  'sign': {Synset('sign.v.03'): 1},
#  'signatures': {Synset('signature.n.01'): 1},
#  'similar': {Synset('similar.a.01'): 1},
#  'size': {Synset('size.n.01'): 1},
#  'smell': {Synset('smell.v.01'): 1},
#  'smooth': {Synset('smooth.a.01'): 1},
#  'so': {Synset('so.r.01'): 1},
#  'some': {Synset('approximately.r.01'): 1, Synset('some.a.01'): 2},
#  'son': {Synset('son.n.01'): 1},
#  'soon': {Synset('soon.r.01'): 1},
#  'sought': {Synset('search.v.01'): 1},
#  'source': {Synset('informant.n.01'): 2},
#  'speaker': {Synset('speaker.n.01'): 1},
#  'specifically': {Synset('specifically.r.01'): 1},
#  'starts': {Synset('get_down.v.07'): 1},
#  'state': {Synset('state.n.01'): 2,
#   Synset('state.n.03'): 1,
#   Synset('state.n.04'): 3},
#  'steps': {Synset('measure.n.01'): 1},
#  'strong': {Synset('potent.s.02'): 1},
#  'studied': {Synset('analyze.v.01'): 1},
#  'study': {Synset('survey.n.01'): 1},
#  'subjected': {Synset('subject.v.01'): 1},
#  'succeeded': {Synset('succeed.v.02'): 2},
#  'suit': {Synset('lawsuit.n.01'): 1},
#  'sunday': {Synset('sunday.n.01'): 2},
#  'support': {Synset('support.n.01'): 1},
#  'surveillance': {Synset('surveillance.n.01'): 1},
#  'system': {Synset('system.n.04'): 2},
#  'take': {Synset('bring.v.01'): 1, Synset('take.v.01'): 1},
#  'taken': {Synset('take.v.20'): 1},
#  'tax': {Synset('tax.n.01'): 1},
#  'taxpayers': {Synset('taxpayer.n.01'): 1},
#  'teacher': {Synset('teacher.n.01'): 2},
#  'technical': {Synset('technical.a.01'): 1},
#  'term': {Synset('term.n.02'): 3},
#  'test': {Synset('test.v.01'): 1},
#  'texas': {Synset('texas.n.01'): 1},
#  'thanks': {Synset('thanks.n.01'): 1},
#  'then': {Synset('then.s.01'): 1},
#  'there': {Synset('there.r.01'): 2},
#  'threats': {Synset('threat.n.03'): 1},
#  'three': {Synset('three.s.01'): 1},
#  'time': {Synset('time.n.01'): 1, Synset('time.n.03'): 1},
#  'title': {Synset('deed.n.01'): 1},
#  'together': {Synset('together.r.03'): 1},
#  'told': {Synset('tell.v.02'): 1},
#  'too': {Synset('besides.r.02'): 1},
#  'topics': {Synset('topic.n.02'): 1},
#  'tossed': {Synset('chuck.v.01'): 1},
#  'traditional': {Synset('traditional.a.01'): 1},
#  'traveled': {Synset('traveled.a.01'): 1},
#  'trouble': {Synset('fuss.n.02'): 2},
#  'tuesday': {Synset('tuesday.n.01'): 2},
#  'two': {Synset('two.s.01'): 3},
#  'unanimous': {Synset('consentaneous.s.01'): 1},
#  'undue': {Synset('undue.a.01'): 1},
#  'unit': {Synset('unit.n.03'): 1},
#  'unmeritorious': {Synset('unmeritorious.s.01'): 1},
#  'urged': {Synset('urge.v.01'): 2},
#  'validity': {Synset('validity.n.02'): 1},
#  'vandiver': {Synset('person.n.01'): 3},
#  'veiled': {Synset('veiled.a.01'): 1},
#  'very': {Synset('very.r.01'): 1},
#  'veteran': {Synset('seasoned.s.02'): 2},
#  'violence': {Synset('violence.n.01'): 1},
#  'visit': {Synset('visit.n.01'): 1},
#  'vote': {Synset('vote.n.01'): 4},
#  'voted': {Synset('vote.v.01'): 1, Synset('vote.v.03'): 1},
#  'voters': {Synset('voter.n.01'): 4},
#  'votes': {Synset('vote.n.02'): 1},
#  'voting': {Synset('vote.n.01'): 1},
#  'wait': {Synset('wait.v.02'): 1},
#  'wanted': {Synset('desire.v.01'): 1},
#  'wards': {Synset('ward.n.01'): 1},
#  'warned': {Synset('warn.v.01'): 1},
#  'warning': {Synset('admonition.n.01'): 1},
#  'was': {Synset('be.v.01'): 3,
#   Synset('be.v.02'): 2,
#   Synset('be.v.05'): 1,
#   Synset('exist.v.01'): 1},
#  'washington': {Synset('capital.n.06'): 1},
#  'wednesday': {Synset('wednesday.n.01'): 1},
#  'weekend': {Synset('weekend.n.01'): 1},
#  'welfare': {Synset('social_welfare.n.01'): 1},
#  'well': {Synset('well.r.01'): 1},
#  'went': {Synset('proceed.v.04'): 1},
#  'were': {Synset('be.v.05'): 1},
#  'widespread': {Synset('widespread.s.01'): 1},
#  'wife': {Synset('wife.n.01'): 2},
#  'williams': {Synset('person.n.01'): 2},
#  'won': {Synset('win.v.01'): 1},
#  'word': {Synset('word.n.02'): 1},
#  'work': {Synset('work.n.01'): 2,
#   Synset('work.v.01'): 1,
#   Synset('work.v.02'): 1},
#  'worth': {Synset('worth.n.01'): 2, Synset('worth.n.02'): 1},
#  'year': {Synset('year.n.01'): 2},
#  'years': {Synset('year.n.01'): 1},
#  'yet': {Synset('so_far.r.01'): 1}}

# %% [markdown]
# ### Exercise 1.2
# Write a function which returns a list of words which only occur with one sense in the corpus, ordered by frequency (most frequent first).
#
# Test your function on `some_sentences`.  You should find that the fourth most frequently occurring seemingly monosemous word is *georgia* which occurs 6 times in this sample.

# %%
def find_monosemous(sense_dists):
    mono=[]
    for key,worddict in sense_dists.items():
        if len(worddict.keys())==1:
            mono.append((key,sum(worddict.values())))
    return sorted(mono,key=operator.itemgetter(1),reverse=True)

find_monosemous(sense_dists)
# Out:
# [('jury', 15),
#  ('election', 12),
#  ('resolution', 9),
#  ('georgia', 6),
#  ('new', 6),
#  ('not', 6),
#  ('atlanta', 5),
#  ('fulton', 5),
#  ('mayor', 5),
#  ('republicans', 5),
#  ('county', 5),
#  ('campaign', 5),
#  ('monday', 5),
#  ('bonds', 5),
#  ('friday', 4),
#  ('voters', 4),
#  ('recommended', 4),
#  ('legislators', 4),
#  ('one', 4),
#  ('night', 4),
#  ('petition', 4),
#  ('candidate', 4),
#  ('vote', 4),
#  ('expected', 4),
#  ('house', 4),
#  ('irregularities', 3),
#  ('term', 3),
#  ('primary', 3),
#  ('practices', 3),
#  ('however', 3),
#  ('two', 3),
#  ('law', 3),
#  ('also', 3),
#  ('legislature', 3),
#  ('court', 3),
#  ('added', 3),
#  ('listed', 3),
#  ('race', 3),
#  ('highway', 3),
#  ('bond', 3),
#  ('vandiver', 3),
#  ('action', 3),
#  ('increase', 3),
#  ('pelham', 3),
#  ('polls', 3),
#  ('anonymous', 3),
#  ('manner', 2),
#  ('reports', 2),
#  ('laws', 2),
#  ('commented', 2),
#  ('other', 2),
#  ('administration', 2),
#  ('personnel', 2),
#  ('urged', 2),
#  ('implementation', 2),
#  ('provide', 2),
#  ('program', 2),
#  ('counties', 2),
#  ('exception', 2),
#  ('money', 2),
#  ('jurors', 2),
#  ('portion', 2),
#  ('place', 2),
#  ('airport', 2),
#  ('jan.', 2),
#  ('four', 2),
#  ('employed', 2),
#  ('plan', 2),
#  ('wife', 2),
#  ('couple', 2),
#  ('attorney', 2),
#  ('age', 2),
#  ('more', 2),
#  ('year', 2),
#  ('hartsfield', 2),
#  ('succeeded', 2),
#  ('sept.', 2),
#  ('enter', 2),
#  ('chairman', 2),
#  ('meeting', 2),
#  ('held', 2),
#  ('tuesday', 2),
#  ('audience', 2),
#  ('governor', 2),
#  ('petitions', 2),
#  ('says', 2),
#  ('candidates', 2),
#  ('system', 2),
#  ('resigned', 2),
#  ('caldwell', 2),
#  ('session', 2),
#  ('approved', 2),
#  ('adjournment', 2),
#  ('senate', 2),
#  ('priority', 2),
#  ('source', 2),
#  ('there', 2),
#  ('apparently', 2),
#  ('roads', 2),
#  ('offer', 2),
#  ('rescind', 2),
#  ('sunday', 2),
#  ('passed', 2),
#  ('pay', 2),
#  ('raises', 2),
#  ('veteran', 2),
#  ('legislator', 2),
#  ('education', 2),
#  ('barber', 2),
#  ('teacher', 2),
#  ('controversy', 2),
#  ('ever', 2),
#  ('saw', 2),
#  ('davis', 2),
#  ('bush', 2),
#  ('trouble', 2),
#  ('williams', 2),
#  ('investigation', 1),
#  ('recent', 1),
#  ('produced', 1),
#  ('evidence', 1),
#  ('further', 1),
#  ('presentments', 1),
#  ('had', 1),
#  ('over-all', 1),
#  ('charge', 1),
#  ('deserves', 1),
#  ('praise', 1),
#  ('thanks', 1),
#  ('conducted', 1),
#  ('september', 1),
#  ('october', 1),
#  ('investigate', 1),
#  ('possible', 1),
#  ('hard-fought', 1),
#  ('won', 1),
#  ('only', 1),
#  ('relative', 1),
#  ('handful', 1),
#  ('considering', 1),
#  ('widespread', 1),
#  ('size', 1),
#  ('find', 1),
#  ('registration', 1),
#  ('outmoded', 1),
#  ('inadequate', 1),
#  ('often', 1),
#  ('ambiguous', 1),
#  ('studied', 1),
#  ('revised', 1),
#  ('modernizing', 1),
#  ('improving', 1),
#  ('topics', 1),
#  ('well', 1),
#  ('generally', 1),
#  ('inure', 1),
#  ('best', 1),
#  ('governments', 1),
#  ('believes', 1),
#  ('offices', 1),
#  ('achieve', 1),
#  ('efficiency', 1),
#  ('reduce', 1),
#  ('cost', 1),
#  ('lacking', 1),
#  ('experienced', 1),
#  ('clerical', 1),
#  ('result', 1),
#  ('policies', 1),
#  ('steps', 1),
#  ('remedy', 1),
#  ('problem', 1),
#  ('automobile', 1),
#  ('title', 1),
#  ('outgoing', 1),
#  ('next', 1),
#  ('enabling', 1),
#  ('re-set', 1),
#  ('effective', 1),
#  ('date', 1),
#  ('effected', 1),
#  ('handling', 1),
#  ('major', 1),
#  ('items', 1),
#  ('general', 1),
#  ('assistance', 1),
#  ('distribute', 1),
#  ('welfare', 1),
#  ('departments', 1),
#  ('all', 1),
#  ('receives', 1),
#  ('realize', 1),
#  ('proportionate', 1),
#  ('distribution', 1),
#  ('disable', 1),
#  ('less', 1),
#  ('populous', 1),
#  ('nevertheless', 1),
#  ('feel', 1),
#  ('receive', 1),
#  ('available', 1),
#  ('failure', 1),
#  ('do', 1),
#  ('continue', 1),
#  ('disproportionate', 1),
#  ('burden', 1),
#  ('taxpayers', 1),
#  ('appointment', 1),
#  ('appraisers', 1),
#  ('guardians', 1),
#  ('administrators', 1),
#  ('awarding', 1),
#  ('fees', 1),
#  ('compensation', 1),
#  ('found', 1),
#  ('incorporated', 1),
#  ('recommendations', 1),
#  ('interim', 1),
#  ('actions', 1),
#  ('serve', 1),
#  ('protect', 1),
#  ('wards', 1),
#  ('undue', 1),
#  ('costs', 1),
#  ('appointed', 1),
#  ('servants', 1),
#  ('unmeritorious', 1),
#  ('criticisms', 1),
#  ('regarding', 1),
#  ('dollar', 1),
#  ('management', 1),
#  ('eliminate', 1),
#  ('influences', 1),
#  ('elaborate', 1),
#  ('periodic', 1),
#  ('surveillance', 1),
#  ('pricing', 1),
#  ('concessionaires', 1),
#  ('purpose', 1),
#  ('keeping', 1),
#  ('prices', 1),
#  ('reasonable', 1),
#  ('matters', 1),
#  ('deputies', 1),
#  ('doctor', 1),
#  ('extern', 1),
#  ('weekend', 1),
#  ('duty', 1),
#  ('jail', 1),
#  ('officials', 1),
#  ('pass', 1),
#  ('establishment', 1),
#  ('equitable', 1),
#  ('pension', 1),
#  ('employes', 1),
#  ('praised', 1),
#  ('operation', 1),
#  ('bellwood', 1),
#  ('alpharetta', 1),
#  ('filed', 1),
#  ('suit', 1),
#  ('divorce', 1),
#  ('mental', 1),
#  ('cruelty', 1),
#  ('married', 1),
#  ('aug.', 1),
#  ('son', 1),
#  ('daughter', 1),
#  ('griffin', 1),
#  ('attorneys', 1),
#  ('amicable', 1),
#  ('occupation', 1),
#  ('lived', 1),
#  ('together', 1),
#  ('brief', 1),
#  ('interlude', 1),
#  ('career', 1),
#  ('present', 1),
#  ('expires', 1),
#  ('became', 1),
#  ('announced', 1),
#  ('run', 1),
#  ('reelection', 1),
#  ('getting', 1),
#  ('strong', 1),
#  ('encouragement', 1),
#  ('official', 1),
#  ('wednesday', 1),
#  ('gop', 1),
#  ('brought', 1),
#  ('enthusiastic', 1),
#  ('responses', 1),
#  ('enthusiasm', 1),
#  ('rally', 1),
#  ('savannah', 1),
#  ('newly', 1),
#  ('texas', 1),
#  ('featured', 1),
#  ('speaker', 1),
#  ('warned', 1),
#  ('entering', 1),
#  ('force', 1),
#  ('obtain', 1),
#  ('signatures', 1),
#  ('registered', 1),
#  ('warning', 1),
#  ('unanimous', 1),
#  ('attended', 1),
#  ('crowd', 1),
#  ('wanted', 1),
#  ('wait', 1),
#  ('no', 1),
#  ('were', 1),
#  ('dissents', 1),
#  ('hurdle', 1),
#  ('face', 1),
#  ('making', 1),
#  ('alternative', 1),
#  ('courses', 1),
#  ('taken', 1),
#  ('five', 1),
#  ('sign', 1),
#  ('requesting', 1),
#  ('allowed', 1),
#  ('names', 1),
#  ('ballot', 1),
#  ('hold', 1),
#  ('unit', 1),
#  ('party', 1),
#  ('opposes', 1),
#  ('platform', 1),
#  ('director', 1),
#  ('resignation', 1),
#  ('gainesville', 1),
#  ('assistant', 1),
#  ('three', 1),
#  ('years', 1),
#  ('gubernatorial', 1),
#  ('starts', 1),
#  ('become', 1),
#  ('coordinator', 1),
#  ('byrd', 1),
#  ('head', 1),
#  ('shortly', 1),
#  ('afternoon', 1),
#  ('approve', 1),
#  ('study', 1),
#  ('allotted', 1),
#  ('determine', 1),
#  ('adjustments', 1),
#  ('made', 1),
#  ('traditional', 1),
#  ('visit', 1),
#  ('chambers', 1),
#  ('likely', 1),
#  ('mention', 1),
#  ('100', 1),
#  ('item', 1),
#  ('meanwhile', 1),
#  ('learned', 1),
#  ('very', 1),
#  ('near', 1),
#  ('ready', 1),
#  ('30', 1),
#  ('reconstruction', 1),
#  ('go', 1),
#  ('courts', 1),
#  ('friendly', 1),
#  ('test', 1),
#  ('validity', 1),
#  ('sales', 1),
#  ('begin', 1),
#  ('contracts', 1),
#  ('let', 1),
#  ('repair', 1),
#  ('most', 1),
#  ('heavily', 1),
#  ('traveled', 1),
#  ('highways', 1),
#  ('3', 1),
#  ('4', 1),
#  ('road', 1),
#  ('construction', 1),
#  ('department', 1),
#  ('intends', 1),
#  ('issued', 1),
#  ('old', 1),
#  ('tax', 1),
#  ('authorities', 1),
#  ('opened', 1),
#  ('battle', 1),
#  ('issuance', 1),
#  ('50', 1),
#  ('proposed', 1),
#  ('then', 1),
#  ('told', 1),
#  ('consulted', 1),
#  ('yet', 1),
#  ('plans', 1),
#  ('body', 1),
#  ('voting', 1),
#  ('10', 1),
#  ('day', 1),
#  ('expense', 1),
#  ('allowances', 1),
#  ('research', 1),
#  ('done', 1),
#  ('quickie', 1),
#  ('repealed', 1),
#  ('outright', 1),
#  ('notice', 1),
#  ('given', 1),
#  ('reconsideration', 1),
#  ('sought', 1),
#  ('emphasizing', 1),
#  ('technical', 1),
#  ('details', 1),
#  ('fully', 1),
#  ('seek', 1),
#  ('similar', 1),
#  ('29', 1),
#  ('5', 1),
#  ('word', 1),
#  ('offered', 1),
#  ('last', 1),
#  ('november', 1),
#  ('rejected', 1),
#  ('amendment', 1),
#  ('allow', 1),
#  ('future', 1),
#  ('sessions', 1),
#  ('ask', 1),
#  ('back', 1),
#  ('aid', 1),
#  ('consistently', 1),
#  ('opposed', 1),
#  ('past', 1),
#  ('commerce', 1),
#  ('asking', 1),
#  ('endorse', 1),
#  ('increased', 1),
#  ('support', 1),
#  ('public', 1),
#  ('expended', 1),
#  ('13th', 1),
#  ('members', 1),
#  ('congressional', 1),
#  ('delegation', 1),
#  ('washington', 1),
#  ('see', 1),
#  ('congressmen', 1),
#  ('specifically', 1),
#  ('tossed', 1),
#  ('hopper', 1),
#  ('formally', 1),
#  ('read', 1),
#  ('event', 1),
#  ('congress', 1),
#  ('directed', 1),
#  ('give', 1),
#  ('long', 1),
#  ('hot', 1),
#  ('has', 1),
#  ('policeman', 1),
#  ('put', 1),
#  ('agriculture', 1),
#  ('defeated', 1),
#  ('votes', 1),
#  ('saturday', 1),
#  ('armed', 1),
#  ('pistol', 1),
#  ('insure', 1),
#  ('order', 1),
#  ('just', 1),
#  ('church', 1),
#  ('smell', 1),
#  ('drop', 1),
#  ('liquor', 1),
#  ('leading', 1),
#  ('so', 1),
#  ('quiet', 1),
#  ('marked', 1),
#  ('midnight', 1),
#  ('veiled', 1),
#  ('threats', 1),
#  ('violence', 1),
#  ('former', 1),
#  ('shot', 1),
#  ('death', 1),
#  ('march', 1),
#  ('days', 1),
#  ('post', 1),
#  ('dispute', 1),
#  ('reportedly', 1),
#  ('too', 1),
#  ('subjected', 1),
#  ('calls', 1),
#  ('soon', 1),
#  ('scheduled', 1),
#  ('many', 1),
#  ('citizens', 1),
#  ('feared', 1),
#  ('carry', 1),
#  ('gun', 1),
#  ('promised', 1),
#  ('orderly', 1),
#  ('promise', 1),
#  ('went', 1),
#  ('real', 1),
#  ('smooth', 1),
#  ('sheriff', 1)]

# %% [markdown]
# ### Exercise 1.3
# Write a function `find_candidates()` which will find words which
# * have 2 senses in the sample,
# * occurrences are roughly balanced between the two classes (between 30% and 70%)
# * are as frequent as possible
#
# Test it on `some_sentences`

# %%
def find_candidates(sense_dists):
    cands=[]
    for key,worddict in sense_dists.items():
        if len(worddict.keys())==2:
            freq=sum(worddict.values())
            p=list(worddict.values())[0]/freq
            if p>0.3 and p<0.7:
                cands.append((key,freq,p))
    return sorted(cands,key=operator.itemgetter(1),reverse=True)

# %%
find_candidates(sense_dists)
# Out:
# [('said', 24, 0.5416666666666666),
#  ('million', 6, 0.3333333333333333),
#  ('number', 3, 0.6666666666666666),
#  ('are', 3, 0.6666666666666666),
#  ('some', 3, 0.6666666666666666),
#  ('elected', 3, 0.6666666666666666),
#  ('be', 3, 0.3333333333333333),
#  ('being', 3, 0.3333333333333333),
#  ('worth', 3, 0.6666666666666666),
#  ('end', 2, 0.5),
#  ('charged', 2, 0.5),
#  ('interest', 2, 0.5),
#  ('act', 2, 0.5),
#  ('operated', 2, 0.5),
#  ('follow', 2, 0.5),
#  ('take', 2, 0.5),
#  ('political', 2, 0.5),
#  ('permit', 2, 0.5),
#  ('home', 2, 0.5),
#  ('been', 2, 0.5),
#  ('asked', 2, 0.5),
#  ('voted', 2, 0.5),
#  ('time', 2, 0.5),
#  ('privilege', 2, 0.5),
#  ('got', 2, 0.5)]

# %% [markdown]
# We now need to apply our functions to larger samples.  Here we will define two sets of sentences `training_sentences` and `testing_sentences`.  We are going to a random sample of the documents for testing.  We can achieve this by randomly shuffling the fileids and then assigning documents in the first part of the list to training and documents in the second part of the list to testing.  By setting the random seed, we ensure reproducibility of our results (since the random shuffle will be the same each time we riun the cell)

# %%
import random
random.seed(37)
shuffled=list(allfiles)
random.shuffle(shuffled)
print(shuffled)
# Out:
# ['brownv/tagfiles/br-a29.xml', 'brownv/tagfiles/br-l06.xml', 'brown2/tagfiles/br-e31.xml', 'brownv/tagfiles/br-c06.xml', 'brown2/tagfiles/br-j34.xml', 'brownv/tagfiles/br-e11.xml', 'brownv/tagfiles/br-a21.xml', 'brown1/tagfiles/br-j01.xml', 'brownv/tagfiles/br-a17.xml', 'brown1/tagfiles/br-l12.xml', 'brownv/tagfiles/br-e09.xml', 'brown2/tagfiles/br-g17.xml', 'brown2/tagfiles/br-g18.xml', 'brownv/tagfiles/br-g09.xml', 'brownv/tagfiles/br-l04.xml', 'brownv/tagfiles/br-l05.xml', 'brown2/tagfiles/br-l18.xml', 'brownv/tagfiles/br-d08.xml', 'brown1/tagfiles/br-k16.xml', 'brown2/tagfiles/br-f21.xml', 'brown2/tagfiles/br-n11.xml', 'brown1/tagfiles/br-j04.xml', 'brownv/tagfiles/br-e16.xml', 'brownv/tagfiles/br-a25.xml', 'brown2/tagfiles/br-n17.xml', 'brownv/tagfiles/br-g06.xml', 'brownv/tagfiles/br-e06.xml', 'brownv/tagfiles/br-a42.xml', 'brown1/tagfiles/br-g01.xml', 'brown1/tagfiles/br-j19.xml', 'brown2/tagfiles/br-n15.xml', 'brown1/tagfiles/br-j05.xml', 'brownv/tagfiles/br-b16.xml', 'brown1/tagfiles/br-n05.xml', 'brown1/tagfiles/br-a11.xml', 'brownv/tagfiles/br-d05.xml', 'brown2/tagfiles/br-e27.xml', 'brown2/tagfiles/br-l17.xml', 'brown2/tagfiles/br-g21.xml', 'brownv/tagfiles/br-b03.xml', 'brown1/tagfiles/br-r05.xml', 'brownv/tagfiles/br-g07.xml', 'brownv/tagfiles/br-e14.xml', 'brownv/tagfiles/br-f11.xml', 'brownv/tagfiles/br-g05.xml', 'brown2/tagfiles/br-g20.xml', 'brown1/tagfiles/br-k15.xml', 'brown1/tagfiles/br-k25.xml', 'brown2/tagfiles/br-g31.xml', 'brownv/tagfiles/br-f09.xml', 'brown1/tagfiles/br-p01.xml', 'brown2/tagfiles/br-n09.xml', 'brownv/tagfiles/br-d16.xml', 'brownv/tagfiles/br-a26.xml', 'brown2/tagfiles/br-p09.xml', 'brownv/tagfiles/br-p03.xml', 'brownv/tagfiles/br-b21.xml', 'brown2/tagfiles/br-j33.xml', 'brownv/tagfiles/br-f05.xml', 'brownv/tagfiles/br-b17.xml', 'brown2/tagfiles/br-j41.xml', 'brownv/tagfiles/br-e18.xml', 'brown1/tagfiles/br-k24.xml', 'brownv/tagfiles/br-j24.xml', 'brown2/tagfiles/br-e22.xml', 'brown1/tagfiles/br-j53.xml', 'brown2/tagfiles/br-f22.xml', 'brown1/tagfiles/br-k20.xml', 'brown2/tagfiles/br-g16.xml', 'brown1/tagfiles/br-j12.xml', 'brownv/tagfiles/br-a09.xml', 'brown1/tagfiles/br-k02.xml', 'brownv/tagfiles/br-a44.xml', 'brown1/tagfiles/br-b20.xml', 'brownv/tagfiles/br-b19.xml', 'brown1/tagfiles/br-k28.xml', 'brown1/tagfiles/br-k03.xml', 'brown1/tagfiles/br-j23.xml', 'brown2/tagfiles/br-n16.xml', 'brownv/tagfiles/br-a37.xml', 'brown2/tagfiles/br-h18.xml', 'brown2/tagfiles/br-l16.xml', 'brownv/tagfiles/br-l03.xml', 'brownv/tagfiles/br-b09.xml', 'brown1/tagfiles/br-j70.xml', 'brownv/tagfiles/br-a19.xml', 'brownv/tagfiles/br-a23.xml', 'brown2/tagfiles/br-j42.xml', 'brownv/tagfiles/br-b12.xml', 'brownv/tagfiles/br-c13.xml', 'brownv/tagfiles/br-a07.xml', 'brown2/tagfiles/br-f25.xml', 'brown2/tagfiles/br-l10.xml', 'brown1/tagfiles/br-k05.xml', 'brown1/tagfiles/br-a14.xml', 'brownv/tagfiles/br-e03.xml', 'brownv/tagfiles/br-c16.xml', 'brownv/tagfiles/br-a30.xml', 'brownv/tagfiles/br-r02.xml', 'brownv/tagfiles/br-e13.xml', 'brown2/tagfiles/br-j32.xml', 'brown1/tagfiles/br-r06.xml', 'brownv/tagfiles/br-b15.xml', 'brownv/tagfiles/br-j26.xml', 'brownv/tagfiles/br-e19.xml', 'brown1/tagfiles/br-k21.xml', 'brownv/tagfiles/br-b10.xml', 'brown2/tagfiles/br-f20.xml', 'brownv/tagfiles/br-a18.xml', 'brown2/tagfiles/br-f23.xml', 'brown2/tagfiles/br-g23.xml', 'brown1/tagfiles/br-j60.xml', 'brown1/tagfiles/br-k27.xml', 'brownv/tagfiles/br-g03.xml', 'brownv/tagfiles/br-h05.xml', 'brownv/tagfiles/br-n03.xml', 'brown2/tagfiles/br-e25.xml', 'brown1/tagfiles/br-k12.xml', 'brown2/tagfiles/br-h15.xml', 'brown2/tagfiles/br-h09.xml', 'brown2/tagfiles/br-h14.xml', 'brown1/tagfiles/br-e24.xml', 'brown1/tagfiles/br-r08.xml', 'brown1/tagfiles/br-j02.xml', 'brown1/tagfiles/br-j18.xml', 'brownv/tagfiles/br-c05.xml', 'brown2/tagfiles/br-h11.xml', 'brown2/tagfiles/br-g12.xml', 'brown2/tagfiles/br-n14.xml', 'brown1/tagfiles/br-j10.xml', 'brown1/tagfiles/br-e01.xml', 'brownv/tagfiles/br-a22.xml', 'brown2/tagfiles/br-f18.xml', 'brownv/t ...

# %%
#this cell will take 1-5 minutes to run - avoid rerunning it unecessarily
training_sentences=extract_senses(shuffled[:300])
testing_sentences=extract_senses(shuffled[300:])
# Out:
# Processing brownv/tagfiles/br-a29.xml
# Processing brownv/tagfiles/br-l06.xml
# Processing brown2/tagfiles/br-e31.xml
# Processing brownv/tagfiles/br-c06.xml
# Processing brown2/tagfiles/br-j34.xml
# Processing brownv/tagfiles/br-e11.xml
# Processing brownv/tagfiles/br-a21.xml
# Processing brown1/tagfiles/br-j01.xml
# Processing brownv/tagfiles/br-a17.xml
# Processing brown1/tagfiles/br-l12.xml
# Processing brownv/tagfiles/br-e09.xml
# Processing brown2/tagfiles/br-g17.xml
# Processing brown2/tagfiles/br-g18.xml
# Processing brownv/tagfiles/br-g09.xml
# Processing brownv/tagfiles/br-l04.xml
# Processing brownv/tagfiles/br-l05.xml
# Processing brown2/tagfiles/br-l18.xml
# Processing brownv/tagfiles/br-d08.xml
# Processing brown1/tagfiles/br-k16.xml
# Processing brown2/tagfiles/br-f21.xml
# Processing brown2/tagfiles/br-n11.xml
# Processing brown1/tagfiles/br-j04.xml
# Processing brownv/tagfiles/br-e16.xml
# Processing brownv/tagfiles/br-a25.xml
# Processing brown2/tagfiles/br-n17.xml
# Processing brownv/tagfiles/br-g06.xml
# Processing brownv/tagfiles/br-e06.xml
# Processing brownv/tagfiles/br-a42.xml
# Processing brown1/tagfiles/br-g01.xml
# Processing brown1/tagfiles/br-j19.xml
# Processing brown2/tagfiles/br-n15.xml
# Processing brown1/tagfiles/br-j05.xml
# Processing brownv/tagfiles/br-b16.xml
# Processing brown1/tagfiles/br-n05.xml
# Processing brown1/tagfiles/br-a11.xml
# Processing brownv/tagfiles/br-d05.xml
# Processing brown2/tagfiles/br-e27.xml
# Processing brown2/tagfiles/br-l17.xml
# Processing brown2/tagfiles/br-g21.xml
# Processing brownv/tagfiles/br-b03.xml
# Processing brown1/tagfiles/br-r05.xml
# Processing brownv/tagfiles/br-g07.xml
# Processing brownv/tagfiles/br-e14.xml
# Processing brownv/tagfiles/br-f11.xml
# Processing brownv/tagfiles/br-g05.xml
# Processing brown2/tagfiles/br-g20.xml
# Processing brown1/tagfiles/br-k15.xml
# Processing brown1/tagfiles/br-k25.xml
# Processing brown2/tagfiles/br-g31.xml
# Processing brownv/tagfiles/br-f09.xml
# Processing brown1/tagfiles/br-p01.xml
# Processing brown2/tagfiles/br-n09.xml
# Processing brownv/tagfiles/br-d16.xml
# Processing brownv/tagfiles/br-a26.xml
# Processing brown2/tagfiles/br-p09.xml
# Processing brownv/tagfiles/br-p03.xml
# Processing brownv/tagfiles/br-b21.xml
# Processing brown2/tagfiles/br-j33.xml
# Processing brownv/tagfiles/br-f05.xml
# Processing brownv/tagfiles/br-b17.xml
# Processing brown2/tagfiles/br-j41.xml
# Processing brownv/tagfiles/br-e18.xml
# Processing brown1/tagfiles/br-k24.xml
# Processing brownv/tagfiles/br-j24.xml
# Processing brown2/tagfiles/br-e22.xml
# Processing brown1/tagfiles/br-j53.xml
# Processing brown2/tagfiles/br-f22.xml
# Processing brown1/tagfiles/br-k20.xml
# Processing brown2/tagfiles/br-g16.xml
# Processing brown1/tagfiles/br-j12.xml
# Processing brownv/tagfiles/br-a09.xml
# Processing brown1/tagfiles/br-k02.xml
# Processing brownv/tagfiles/br-a44.xml
# Processing brown1/tagfiles/br-b20.xml
# Processing brownv/tagfiles/br-b19.xml
# Processing brown1/tagfiles/br-k28.xml
# Processing brown1/tagfiles/br-k03.xml
# Processing brown1/tagfiles/br-j23.xml
# Processing brown2/tagfiles/br-n16.xml
# Processing brownv/tagfiles/br-a37.xml
# Processing brown2/tagfiles/br-h18.xml
# Processing brown2/tagfiles/br-l16.xml
# Processing brownv/tagfiles/br-l03.xml
# Processing brownv/tagfiles/br-b09.xml
# Processing brown1/tagfiles/br-j70.xml
# Processing brownv/tagfiles/br-a19.xml
# Processing brownv/tagfiles/br-a23.xml
# Processing brown2/tagfiles/br-j42.xml
# Processing brownv/tagfiles/br-b12.xml
# Processing brownv/tagfiles/br-c13.xml
# Processing brownv/tagfiles/br-a07.xml
# Processing brown2/tagfiles/br-f25.xml
# Processing brown2/tagfiles/br-l10.xml
# Processing brown1/tagfiles/br-k05.xml
# Processing brown1/tagfiles/br-a14.xml
# Processing brownv/tagfiles/br-e03.xml
# Processing brownv/tagfiles/br-c16.xml
# Processing brownv/tagfiles/br-a30.xml
# Processing brownv/tagfiles/br-r02.xml
# Processing brownv/tagfiles/br-e13.xml
# Processing brown2/tagfiles/br-j32.xml
# Processing brown1/tagfiles/br-r06.xml
# Processing brownv/tagfiles/br-b15.xml
# Processing brownv/tagfiles/br-j26.xml
# Processing brownv/tagfiles/br-e19.xml
# Processing brown1/tagfiles/br-k21.xml
# Processing brownv/tagfiles/br-b10.xml
# Processing brown2/tagfiles/br-f20.xml
# Processing brownv/tagfiles/br-a18.xml
# Processing brown2/tagfiles/br-f23.xml
# Processing brown2/tagfiles/br-g23.xml
# Processing brown1/tagfiles/br-j60.xml
# Processing brown1/tagfiles/br-k27.xml
# Processing brownv/tagfiles/br-g03.xml
# Processing brownv/tagfiles/br-h05.xml
# Processing brownv/tagfiles/br-n03.xml
# Processing brown2/tagfiles/br-e25.xml
# Processing brown1/tagfiles/br-k12.xml
# Processing brown2/tagfiles/br-h15.xml
# Processing brown2/tagfiles/br-h09.xml
# Processing brown2/tagfiles/br-h14.xml
# Processing brown1/tagfiles/br-e24.xml
# Processing brown1/tagfiles/br-r08.xml
# Processing brown1/tagfiles/br-j02.xml
# Processing brown1/tagfiles/br-j18.xml
# Processing brownv/tagfiles/br-c05.xml
# Processing brown2/tagfiles/br-h11.xml
# Processing brown2/tagfiles/br-g12.xml
# Processing brown2/tagfiles/br-n14.xml
# Processing brown1/tagfiles/br-j10.xml
# Processing brown1/tagfiles/br-e01.xml
# Processing brownv/tagfiles/br-a22.xml
# Processing brown2/tagfiles/br-f18.xml
# Processing brownv/tagfiles/br-a31.xml
# Processing brown2/tagfiles/br-g22.xml
# Processing brownv/tagfiles/br-a05.xml
# Processing brownv/tagfiles/br-a34.xml
# Processing brownv/tagfiles/br-b08.xml
# Processing brown2/tagfiles/br-e26.xml
# Processing brown1/tagfiles/br-d03.xml
# Processing brown1/tagfiles/br-k01.xml
# Processing brown1/tagfiles/br-r07.xml
# Processing brown1/tagfiles/br-j57.xml
# Processing brown1/tagfiles/br-k13.xml
# Processing brownv/tagfiles/br-a16.xml
# Processing brownv/tagfiles/br-p05.xml
# Processing brownv/tagfiles/br-c07.xml
# Processing brown2/tagfiles/br-g39.xml
# Processing brownv/tagfiles/br-a08.xml
# Processing brownv/tagfiles/br-d11.xml
# Processing brownv/tagfiles/br-a03.xml
# Processing brown1/tagfiles/br-a01.xml
# Processing brownv/tagfiles/br-m04.xml
# Processing brownv/tagfiles/br-a20.xml
# Processing brown1/tagfiles/br-g15.xml
# Processing brownv/tagfiles/br-c12.xml
# Processing brownv/tagfiles/br-l07.xml
# Processing brownv/tagfiles/br-a27.xml
# Processing brownv/tagfiles/br-e08.xml
# Processing brownv/tagfiles/br-c10.xml
# Processing brown1/tagfiles/br-g11.xml
# Processing brownv/tagfiles/br-f07.xml
# Processing brownv/tagfiles/br-b27.xml
# Processing brown1/tagfiles/br-e21.xml
# Processing brownv/tagfiles/br-c11.xml
# Processing brown1/tagfiles/br-j58.xml
# Processing brown1/tagfiles/br-j11.xml
# Processing brownv/tagfiles/br-n08.xml
# Processing brownv/tagfiles/br-a40.xml
# Processing brown1/tagfiles/br-m01.xml
# Processing brown1/tagfiles/br-j08.xml
# Processing brown1/tagfiles/br-j15.xml
# Processing brownv/tagfiles/br-b14.xml
# Processing brown2/tagfiles/br-r04.xml
# Processing brownv/tagfiles/br-j25.xml
# Processing brown2/tagfiles/br-j29.xml
# Processing brownv/tagfiles/br-n02.xml
# Processing brownv/tagfiles/br-b24.xml
# Processing brownv/tagfiles/br-b18.xml
# Processing brown1/tagfiles/br-j07.xml
# Processing brownv/tagfiles/br-d10.xml
# Processing brown1/tagfiles/br-c01.xml
# Processing brownv/tagfiles/br-g02.xml
# Processing brown2/tagfiles/br-l14.xml
# Processing brown1/tagfiles/br-k10.xml
# Processing brown1/tagfiles/br-f03.xml
# Processing brown2/tagfiles/br-p12.xml
# Processing brownv/tagfiles/br-d09.xml
# Processing brown2/tagfiles/br-l15.xml
# Processing brown1/tagfiles/br-j13.xml
# Processing brown2/tagfiles/br-h12.xml
# Processing brownv/tagfiles/br-a24.xml
# Processing brownv/tagfiles/br-f04.xml
# Processing brownv/tagfiles/br-b25.xml
# Processing brownv/tagfiles/br-b23.xml
# Processing brown2/tagfiles/br-f33.xml
# Processing brown1/tagfiles/br-m02.xml
# Processing brown1/tagfiles/br-h01.xml
# Processing brownv/tagfiles/br-p04.xml
# Processing brown2/tagfiles/br-l08.xml
# Processing brown1/tagfiles/br-j37.xml
# Processing brown1/tagfiles/br-k29.xml
# Processing brown2/tagfiles/br-j35.xml
# Processing brownv/tagfiles/br-b06.xml
# Processing brown1/tagfiles/br-k23.xml
# Processing brown1/tagfiles/br-j55.xml
# Processing brown2/tagfiles/br-f14.xml
# Processing brown2/tagfiles/br-h24.xml
# Processing brownv/tagfiles/br-e05.xml
# Processing brown1/tagfiles/br-b13.xml
# Processing brown2/tagfiles/br-g19.xml
# Processing brown2/tagfiles/br-h17.xml
# Processing brown1/tagfiles/br-k06.xml
# Processing brownv/tagfiles/br-e10.xml
# Processing brown2/tagfiles/br-l09.xml
# Processing brownv/tagfiles/br-d14.xml
# Processing brownv/tagfiles/br-b01.xml
# Processing brownv/tagfiles/br-g10.xml
# Processing brownv/tagfiles/br-d15.xml
# Processing brownv/tagfiles/br-a28.xml
# Processing brown2/tagfiles/br-n10.xml
# Processing brownv/tagfiles/br-e20.xml
# Processing brownv/tagfiles/br-a39.xml
# Processing brownv/tagfiles/br-m05.xml
# Processing brown1/tagfiles/br-c02.xml
# Processing brown2/tagfiles/br-j30.xml
# Processing brown1/tagfiles/br-k09.xml
# Processing brown2/tagfiles/br-g44.xml
# Processing brownv/tagfiles/br-c03.xml
# Processing brown1/tagfiles/br-k26.xml
# Processing brown2/tagfiles/br-g14.xml
# Processing brownv/tagfiles/br-d17.xml
# Processing brownv/tagfiles/br-c08.xml
# Processing brownv/tagfiles/br-e12.xml
# Processing brown2/tagfiles/br-f13.xml
# Processing brownv/tagfiles/br-g04.xml
# Processing brown1/tagfiles/br-j59.xml
# Processing brownv/tagfiles/br-a32.xml
# Processing brownv/tagfiles/br-n04.xml
# Processing brownv/tagfiles/br-p02.xml
# Processing brown1/tagfiles/br-k17.xml
# Processing brown1/tagfiles/br-f10.xml
# Processing brown1/tagfiles/br-j20.xml
# Processing brownv/tagfiles/br-c09.xml
# Processing brownv/tagfiles/br-h10.xml
# Processing brown2/tagfiles/br-f15.xml
# Processing brown1/tagfiles/br-r09.xml
# Processing brown1/tagfiles/br-j14.xml
# Processing brownv/tagfiles/br-m06.xml
# Processing brownv/tagfiles/br-c15.xml
# Processing brownv/tagfiles/br-d07.xml
# Processing brownv/tagfiles/br-a36.xml
# Processing brownv/tagfiles/br-f01.xml
# Processing brownv/tagfiles/br-j21.xml
# Processing brown1/tagfiles/br-k08.xml
# Processing brown2/tagfiles/br-p10.xml
# Processing brownv/tagfiles/br-h03.xml
# Processing brownv/tagfiles/br-a41.xml
# Processing brown1/tagfiles/br-k22.xml
# Processing brown1/tagfiles/br-j56.xml
# Processing brown2/tagfiles/br-e28.xml
# Processing brown1/tagfiles/br-k07.xml
# Processing brown2/tagfiles/br-h21.xml
# Processing brown1/tagfiles/br-l11.xml
# Processing brown1/tagfiles/br-d02.xml
# Processing brownv/tagfiles/br-b22.xml
# Processing brownv/tagfiles/br-l02.xml
# Processing brown2/tagfiles/br-f44.xml
# Processing brownv/tagfiles/br-h06.xml
# Processing brown1/tagfiles/br-k18.xml
# Processing brownv/tagfiles/br-h04.xml
# Processing brown1/tagfiles/br-k14.xml
# Processing brown1/tagfiles/br-j22.xml
# Processing brown1/tagfiles/br-d04.xml
# Processing brown2/tagfiles/br-n20.xml
# Processing brown2/tagfiles/br-n12.xml
# Processing brown1/tagfiles/br-k04.xml
# Processing brownv/tagfiles/br-b04.xml
# Processing brown1/tagfiles/br-j16.xml
# Processing brown2/tagfiles/br-f24.xml
# Processing brownv/tagfiles/br-e15.xml
# Processing brown1/tagfiles/br-a02.xml
# Processing brown1/tagfiles/br-j52.xml
# Processing brownv/tagfiles/br-b07.xml
# Processing brownv/tagfiles/br-n07.xml
# Processing brown1/tagfiles/br-f19.xml
# Processing brown2/tagfiles/br-g28.xml
# Processing brownv/tagfiles/br-p08.xml
# Processing brownv/tagfiles/br-m03.xml
# Processing brownv/tagfiles/br-b26.xml
# Processing brown2/tagfiles/br-e23.xml
# Processing brown2/tagfiles/br-g43.xml
# Processing brownv/tagfiles/br-n01.xml
# Processing brown1/tagfiles/br-e29.xml
# Processing brown2/tagfiles/br-j31.xml
# Processing brownv/tagfiles/br-g13.xml
# Processing brown2/tagfiles/br-f17.xml
# Processing brown2/tagfiles/br-j38.xml
# Processing brown2/tagfiles/br-f08.xml
# Processing brown1/tagfiles/br-a15.xml
# Processing brown1/tagfiles/br-c04.xml
# Processing brown1/tagfiles/br-k19.xml
# Processing brownv/tagfiles/br-p06.xml
# Processing brown2/tagfiles/br-p07.xml
# Processing brown2/tagfiles/br-l13.xml
# Processing brown1/tagfiles/br-d01.xml
# Processing brown2/tagfiles/br-f16.xml
# Processing brownv/tagfiles/br-f06.xml
# Processing brown1/tagfiles/br-j06.xml
# Processing brownv/tagfiles/br-l01.xml
# Processing brownv/tagfiles/br-c17.xml
# Processing brown1/tagfiles/br-a12.xml
# Processing brown1/tagfiles/br-a13.xml
# Processing brown1/tagfiles/br-j03.xml
# Processing brownv/tagfiles/br-a35.xml
# Processing brownv/tagfiles/br-c14.xml
# Processing brown2/tagfiles/br-e30.xml
# Processing brownv/tagfiles/br-h08.xml
# Processing brownv/tagfiles/br-d12.xml
# Processing brown1/tagfiles/br-e02.xml
# Processing brownv/tagfiles/br-f02.xml
# Processing brownv/tagfiles/br-a04.xml
# Processing brownv/tagfiles/br-e17.xml
# Processing brownv/tagfiles/br-f12.xml
# Processing brownv/tagfiles/br-a43.xml
# Processing brown2/tagfiles/br-p24.xml
# Processing brown2/tagfiles/br-h16.xml
# Processing brownv/tagfiles/br-e07.xml
# Processing brown1/tagfiles/br-j09.xml
# Processing brownv/tagfiles/br-a33.xml
# Processing brownv/tagfiles/br-r03.xml
# Processing brown1/tagfiles/br-f43.xml
# Processing brown1/tagfiles/br-k11.xml
# Processing brownv/tagfiles/br-b05.xml
# Processing brownv/tagfiles/br-a38.xml
# Processing brownv/tagfiles/br-a10.xml
# Processing brown2/tagfiles/br-h13.xml
# Processing brownv/tagfiles/br-g08.xml
# Processing brownv/tagfiles/br-b11.xml
# Processing brown1/tagfiles/br-j54.xml
# Processing brownv/tagfiles/br-d13.xml
# Processing brownv/tagfiles/br-b02.xml
# Processing brownv/tagfiles/br-a06.xml
# Processing brownv/tagfiles/br-j27.xml
# Processing brown1/tagfiles/br-e04.xml
# Processing brownv/tagfiles/br-d06.xml
# Processing brownv/tagfiles/br-j28.xml
# Processing brownv/tagfiles/br-n06.xml
# Processing brownv/tagfiles/br-h07.xml
# Processing brown1/tagfiles/br-j17.xml
# Processing brownv/tagfiles/br-h02.xml
# Processing brownv/tagfiles/br-r01.xml

# %% [markdown]
# ### Exercise 1.4
# Use the functionality you have already developed to identify:
# * the ten most frequent monosemous words in the data
# * the ten best candidates for evaluating binary classification algorithms for WSD

# %%
training_dist=find_sense_distributions(training_sentences)

# %%
find_monosemous(training_dist)
# Out:
# [('not', 1550),
#  ('also', 366),
#  ('many', 279),
#  ('never', 202),
#  ('again', 181),
#  ('always', 152),
#  ('almost', 149),
#  ('nothing', 119),
#  ('wife', 105),
#  ('probably', 95),
#  ('already', 92),
#  ('perhaps', 90),
#  ('usually', 84),
#  ('available', 83),
#  ('therefore', 83),
#  ('sometimes', 74),
#  ('ago', 73),
#  ('few', 72),
#  ('ideas', 68),
#  ('anode', 65),
#  ('merely', 64),
#  ('before', 58),
#  ('indeed', 58),
#  ('husband', 58),
#  ('especially', 57),
#  ('difficult', 56),
#  ('person', 56),
#  ('century', 55),
#  ('normal', 55),
#  ('died', 54),
#  ('car', 54),
#  ('particularly', 52),
#  ('dictionary', 52),
#  ('jewish', 51),
#  ('text', 51),
#  ('summer', 50),
#  ('soon', 50),
#  ('certainly', 49),
#  ('dominant', 49),
#  ('hair', 49),
#  ('vocational', 49),
#  ('nearly', 48),
#  ('maybe', 48),
#  ('existence', 46),
#  ('jess', 46),
#  ('attitude', 45),
#  ('kate', 45),
#  ('income', 44),
#  ('achieved', 43),
#  ('trees', 42),
#  ('elections', 42),
#  ('equipment', 41),
#  ('killed', 41),
#  ('latter', 41),
#  ('smiled', 41),
#  ('college', 41),
#  ('scotty', 40),
#  ('method', 39),
#  ('knowledge', 38),
#  ('america', 38),
#  ('wilson', 38),
#  ('watson', 38),
#  ('curt', 38),
#  ('methods', 37),
#  ('coffee', 37),
#  ('onset', 37),
#  ('apparently', 36),
#  ('obviously', 36),
#  ('slowly', 36),
#  ('stared', 36),
#  ('kitchen', 36),
#  ('friends', 36),
#  ('another', 36),
#  ('winston', 36),
#  ('alex', 36),
#  ('clothes', 35),
#  ('exist', 35),
#  ('hotel', 34),
#  ('frequently', 34),
#  ('relatively', 33),
#  ('andy', 33),
#  ('oxygen', 33),
#  ('persons', 33),
#  ('opportunity', 33),
#  ('successful', 32),
#  ('lips', 32),
#  ('prokofieff', 32),
#  ('facilities', 31),
#  ('river', 31),
#  ('cities', 31),
#  ('rapidly', 30),
#  ('evening', 30),
#  ('laughed', 30),
#  ('petitioner', 30),
#  ('aware', 29),
#  ('main', 29),
#  ('police', 29),
#  ('moreover', 29),
#  ('apartment', 29),
#  ('mg', 29),
#  ('achievement', 29),
#  ('weeks', 28),
#  ('songs', 28),
#  ('eight', 28),
#  ('leg', 28),
#  ('thyroid', 28),
#  ('personnel', 27),
#  ('considerable', 27),
#  ('arrived', 27),
#  ('sky', 27),
#  ('somewhere', 27),
#  ('practically', 27),
#  ('chest', 27),
#  ('parents', 27),
#  ('literary', 27),
#  ('polynomial', 27),
#  ('recently', 26),
#  ('achieve', 26),
#  ('as', 26),
#  ('disappeared', 26),
#  ('neck', 26),
#  ('rachel', 26),
#  ('hans', 26),
#  ('folklore', 26),
#  ('visual', 26),
#  ('stanley', 26),
#  ('eileen', 26),
#  ('primarily', 25),
#  ('possibly', 25),
#  ('soldiers', 25),
#  ('muscle', 25),
#  ('cattle', 25),
#  ('detective', 25),
#  ('obtain', 25),
#  ('slightly', 25),
#  ('essentially', 25),
#  ('arlene', 25),
#  ('teach', 24),
#  ('hence', 24),
#  ('fingers', 24),
#  ('vast', 24),
#  ('soldier', 24),
#  ('brannon', 24),
#  ('felix', 24),
#  ('concept', 23),
#  ('may', 23),
#  ('sufficient', 23),
#  ('authors', 23),
#  ('concerning', 23),
#  ('citizens', 23),
#  ('hundred', 23),
#  ('shoulders', 23),
#  ('replied', 23),
#  ('opportunities', 23),
#  ('sunday', 23),
#  ('dog', 23),
#  ('such', 23),
#  ('artist', 23),
#  ('nevertheless', 23),
#  ('fig.', 23),
#  ('hoag', 23),
#  ('minimal', 23),
#  ('recreation', 22),
#  ('obvious', 22),
#  ('largely', 22),
#  ('june', 22),
#  ('george', 22),
#  ('buildings', 22),
#  ('tsunami', 22),
#  ('november', 22),
#  ('grass', 22),
#  ('henrietta', 22),
#  ('johnson', 22),
#  ('suburban', 22),
#  ('anti-semitism', 22),
#  ('commercial', 21),
#  ('interesting', 21),
#  ('food', 21),
#  ('thermal', 21),
#  ('description', 21),
#  ('goal', 21),
#  ('fifty', 21),
#  ('killpath', 21),
#  ('hill', 21),
#  ('holder', 21),
#  ('christ', 21),
#  ('catholics', 21),
#  ('congregation', 21),
#  ('madden', 21),
#  ('maude', 21),
#  ('rifle', 20),
#  ('writers', 20),
#  ('normally', 20),
#  ('occasionally', 20),
#  ('approximately', 20),
#  ('tend', 20),
#  ('milligrams', 20),
#  ('disease', 20),
#  ('animals', 20),
#  ('page', 20),
#  ('soviet', 20),
#  ('eichmann', 20),
#  ('russ', 20),
#  ('oersted', 20),
#  ('hal', 20),
#  ('sufficiently', 19),
#  ('forgive', 19),
#  ('health', 19),
#  ('tends', 19),
#  ('bedroom', 19),
#  ('slept', 19),
#  ('60', 19),
#  ('april', 19),
#  ('county', 19),
#  ('prior', 19),
#  ('truck', 19),
#  ('porch', 19),
#  ('desk', 19),
#  ('remarked', 19),
#  ('similarly', 19),
#  ('emotion', 19),
#  ('composer', 19),
#  ('oxidation', 19),
#  ('sewage', 19),
#  ('pond', 19),
#  ('centuries', 19),
#  ('expenditures', 19),
#  ('pursuant', 19),
#  ('sarah', 19),
#  ('andrei', 19),
#  ('tsh', 19),
#  ('nonspecific', 19),
#  ('financial', 18),
#  ('trip', 18),
#  ('handed', 18),
#  ('considerably', 18),
#  ('previously', 18),
#  ('cm', 18),
#  ('horses', 18),
#  ('famous', 18),
#  ('casey', 18),
#  ('hat', 18),
#  ('district', 18),
#  ('tall', 18),
#  ('everywhere', 18),
#  ('grams', 18),
#  ('inch', 18),
#  ('consciousness', 18),
#  ('organic', 18),
#  ('victory', 18),
#  ('effluent', 18),
#  ('universal', 18),
#  ('cobb', 18),
#  ('eugene', 18),
#  ('part-time', 18),
#  ('tangent', 18),
#  ('michelangelo', 18),
#  ('faulkner', 18),
#  ('properly', 17),
#  ('hundreds', 17),
#  ('protect', 17),
#  ('arrested', 17),
#  ('beautiful', 17),
#  ('daughter', 17),
#  ('greatly', 17),
#  ('whisky', 17),
#  ('beer', 17),
#  ('computed', 17),
#  ('pounds', 17),
#  ('prevention', 17),
#  ('environment', 17),
#  ('initial', 17),
#  ('employees', 17),
#  ('hr', 17),
#  ('kitti', 17),
#  ('iodine', 17),
#  ('angie', 17),
#  ('kinds', 16),
#  ('weather', 16),
#  ('enable', 16),
#  ('simultaneously', 16),
#  ('automatically', 16),
#  ('numerous', 16),
#  ('purchased', 16),
#  ('presumably', 16),
#  ('apparatus', 16),
#  ('rapid', 16),
#  ('someone', 16),
#  ('gradually', 16),
#  ('liberals', 16),
#  ('fifteen', 16),
#  ('velocity', 16),
#  ('neighbors', 16),
#  ('recall', 16),
#  ('periods', 16),
#  ('doctrine', 16),
#  ('insist', 16),
#  ('readily', 16),
#  ('emotions', 16),
#  ('winter', 16),
#  ('farmers', 16),
#  ('mahzeer', 16),
#  ('corporation', 16),
#  ('jew', 16),
#  ('moreland', 16),
#  ('basement', 16),
#  ('electric', 16),
#  ('provisions', 16),
#  ('garth', 16),
#  ('roleplaying', 16),
#  ('thyroglobulin', 16),
#  ('thousands', 15),
#  ('teachers', 15),
#  ('pistol', 15),
#  ('fled', 15),
#  ('complained', 15),
#  ('electrical', 15),
#  ('temperatures', 15),
#  ('rarely', 15),
#  ('southerners', 15),
#  ('strongly', 15),
#  ('letting', 15),
#  ('guests', 15),
#  ('wooden', 15),
#  ('yes', 15),
#  ('huge', 15),
#  ('plato', 15),
#  ('1000', 15),
#  ('alaska', 15),
#  ('september', 15),
#  ('relation', 15),
#  ('increasingly', 15),
#  ('joyce', 15),
#  ('objectives', 15),
#  ('partly', 15),
#  ('probability', 15),
#  ('enormous', 15),
#  ('aircraft', 15),
#  ('solve', 15),
#  ('sir', 15),
#  ('stairs', 15),
#  ('saturday', 15),
#  ('juanita', 15),
#  ('lungs', 15),
#  ('conceived', 15),
#  ('regiment', 15),
#  ('theological', 15),
#  ('blanche', 15),
#  ('i.e.', 15),
#  ('helium', 15),
#  ('corporations', 15),
#  ('utopia', 15),
#  ('dallas', 15),
#  ('districts', 15),
#  ('abel', 15),
#  ('collage', 15),
#  ('styka', 15),
#  ('irenaeus', 15),
#  ('excellent', 14),
#  ('desirable', 14),
#  ('measurements', 14),
#  ('anyway', 14),
#  ('while', 14),
#  ('studio', 14),
#  ('immortality', 14),
#  ('wonderful', 14),
#  ('grinned', 14),
#  ('station', 14),
#  ('counties', 14),
#  ('associated', 14),
#  ('spectra', 14),
#  ('quoted', 14),
#  ('grabbed', 14),
#  ('intense', 14),
#  ('convenient', 14),
#  ('respectively', 14),
#  ('guns', 14),
#  ('advice', 14),
#  ('bacterial', 14),
#  ('thereby', 14),
#  ('nineteenth', 14),
#  ('lung', 14),
#  ('steel', 14),
#  ('tree', 14),
#  ('truly', 14),
#  ('laughter', 14),
#  ('constitute', 14),
#  ('ma', 14),
#  ('claire', 14),
#  ('administrative', 14),
#  ('cancer', 14),
#  ('diagonalizable', 14),
#  ('theorem', 14),
#  ('harold', 14),
#  ('anaconda', 14),
#  ('graph', 14),
#  ('carla', 14),
#  ('athabascan', 14),
#  ('salesmen', 14),
#  ('opium', 14),
#  ('glendora', 14),
#  ('lublin', 14),
#  ('successfully', 13),
#  ('specifically', 13),
#  ('scope', 13),
#  ('devices', 13),
#  ('antenna', 13),
#  ('ratio', 13),
#  ('byron', 13),
#  ('roads', 13),
#  ('ships', 13),
#  ('laughing', 13),
#  ('cow', 13),
#  ('august', 13),
#  ('paramagnetic', 13),
#  ('c', 13),
#  ('examination', 13),
#  ('probabilities', 13),
#  ('friday', 13),
#  ('mud', 13),
#  ('cloth', 13),
#  ('forty', 13),
#  ('uneasy', 13),
#  ('snakes', 13),
#  ('customers', 13),
#  ('drugs', 13),
#  ('respiratory', 13),
#  ('peered', 13),
#  ('essay', 13),
#  ('utopian', 13),
#  ('joel', 13),
#  ('supper', 13),
#  ('barn', 13),
#  ('december', 13),
#  ('sister', 13),
#  ('tiny', 13),
#  ('lady', 13),
#  ('conversation', 13),
#  ('garryowen', 13),
#  ('permanent', 13),
#  ('shelley', 13),
#  ('mystery', 13),
#  ('whispered', 13),
#  ('agencies', 13),
#  ('upper', 13),
#  ('gilborn', 13),
#  ('metropolitan', 13),
#  ('professor', 13),
#  ('february', 13),
#  ('middle-class', 13),
#  ('skeletal', 13),
#  ('sam', 13),
#  ('jessica', 13),
#  ('ludie', 13),
#  ('rev', 13),
#  ('howard', 13),
#  ('braque', 13),
#  ('vertex', 13),
#  ('argiento', 13),
#  ('practices', 12),
#  ('phenomena', 12),
#  ('interaction', 12),
#  ('european', 12),
#  ('planets', 12),
#  ('useful', 12),
#  ('boston', 12),
#  ('artists', 12),
#  ('perfect', 12),
#  ('burton', 12),
#  ('shore', 12),
#  ('myth', 12),
#  ('coast', 12),
#  ('curiosity', 12),
#  ('interior', 12),
#  ('atoms', 12),
#  ('laboratory', 12),
#  ('disclosed', 12),
#  ('editor', 12),
#  ('illustrate', 12),
#  ('mountains', 12),
#  ('advantage', 12),
#  ('unfortunately', 12),
#  ('so-called', 12),
#  ('definite', 12),
#  ('purely', 12),
#  ('sidewalk', 12),
#  ('machines', 12),
#  ('furthermore', 12),
#  ('compete', 12),
#  ('thursday', 12),
#  ('laura', 12),
#  ('finger', 12),
#  ('participate', 12),
#  ('mythological', 12),
#  ('october', 12),
#  ('january', 12),
#  ('muller', 12),
#  ('solids', 12),
#  ('protestants', 12),
#  ('payne', 12),
#  ('nigger', 12),
#  ('torrio', 12),
#  ('laos', 12),
#  ('mcfeeley', 12),
#  ('unadjusted', 12),
#  ('nilpotent', 12),
#  ('wives', 12),
#  ('jubal', 12),
#  ('structured', 12),
#  ('unstructured', 12),
#  ('arrow', 12),
#  ('mexicans', 12),
#  ('deduct', 12),
#  ('conjugates', 12),
#  ('spotted', 11),
#  ('wise', 11),
#  ('automobile', 11),
#  ('entertain', 11),
#  ('eleven', 11),
#  ('continually', 11),
#  ('painter', 11),
#  ('orders', 11),
#  ('civilization', 11),
#  ('wednesday', 11),
#  ('openly', 11),
#  ('invariably', 11),
#  ('aqueous', 11),
#  ('percent', 11),
#  ('mode', 11),
#  ('bees', 11),
#  ('hatred', 11),
#  ('elsewhere', 11),
#  ('driver', 11),
#  ('todman', 11),
#  ('emphasized', 11),
#  ('competitive', 11),
#  ('sheep', 11),
#  ('furnish', 11),
#  ('firms', 11),
#  ('selecting', 11),
#  ('cents', 11),
#  ('socialism', 11),
#  ('nearest', 11),
#  ('productivity', 11),
#  ('inadequate', 11),
#  ('colonel', 11),
#  ('nights', 11),
#  ('yesterday', 11),
#  ('farmer', 11),
#  ('lawyer', 11),
#  ('breakfast', 11),
#  ('cat', 11),
#  ('secondary', 11),
#  ('pedersen', 11),
#  ('beauty', 11),
#  ('absolutely', 11),
#  ('tables', 11),
#  ('worthy', 11),
#  ('mimesis', 11),
#  ('trig', 11),
#  ('germany', 11),
#  ('aerator', 11),
#  ('municipal', 11),
#  ('prestige', 11),
#  ('bible', 11),
#  ('communities', 11),
#  ('july', 11),
#  ('subsection', 11),
#  ('gymnastics', 11),
#  ('decades', 11),
#  ('finite', 11),
#  ('henri', 11),
#  ('congregations', 11),
#  ('monday', 11),
#  ('electoral', 11),
#  ('bultmann', 11),
#  ('fluorescence', 11),
#  ('antigen', 11),
#  ('attributed', 10),
#  ('realistic', 10),
#  ('experts', 10),
#  ('accused', 10),
#  ('brightness', 10),
#  ('previous', 10),
#  ('viewpoint', 10),
#  ('historian', 10),
#  ('africa', 10),
#  ('lovely', 10),
#  ('surely', 10),
#  ('quote', 10),
#  ('factories', 10),
#  ('leather', 10),
#  ('wholly', 10),
#  ('mainly', 10),
#  ('devised', 10),
#  ('publicly', 10),
#  ('boots', 10),
#  ('texas', 10),
#  ('chiefly', 10),
#  ('bastards', 10),
#  ('repeatedly', 10),
#  ('coach', 10),
#  ('expensive', 10),
#  ('attract', 10),
#  ('specialists', 10),
#  ('equivalent', 10),
#  ('plainly', 10),
#  ('furniture', 10),
#  ('kissed', 10),
#  ('maid', 10),
#  ('intermediate', 10),
#  ('pennsylvania', 10),
#  ('eager', 10),
#  ('vaguely', 10),
#  ('wanting', 10),
#  ('goals', 10),
#  ('eventually', 10),
#  ('impressive', 10),
#  ('journey', 10),
#  ('tray', 10),
#  ('griffith', 10),
#  ('lagoon', 10),
#  ('patients', 10),
#  ('hospital', 10),
#  ('sites', 10),
#  ('electronics', 10),
#  ('fallout', 10),
#  ('guam', 10),
#  ('vector', 10),
#  ('commute', 10),
#  ('physics', 10),
#  ('bumblebees', 10),
#  ('pollen', 10),
#  ('negotiate', 10),
#  ('tales', 10),
#  ('biological', 10),
#  ('mg.', 10),
#  ('gm.', 10),
#  ('fibers', 10),
#  ('compulsivity', 10),
#  ('johnston', 10),
#  ('loans', 10),
#  ('swadesh', 10),
#  ('russell', 10),
#  ('lucien', 10),
#  ('secede', 10),
#  ('tumor', 10),
#  ('majdanek', 10),
#  ('trends', 10),
#  ('conjugate', 10),
#  ('pbs', 10),
#  ('retrieved', 9),
#  ('ammunition', 9),
#  ('cooperate', 9),
#  ('detroit', 9),
#  ('expansion', 9),
#  ('computing', 9),
#  ('phonologic', 9),
#  ('fewer', 9),
#  ('syllables', 9),
#  ('morphophonemics', 9),
#  ('deserves', 9),
#  ('relevant', 9),
#  ('lacked', 9),
#  ('combination', 9),
#  ('either', 9),
#  ('crime', 9),
#  ('bastard', 9),
#  ('corridor', 9),
#  ('applause', 9),
#  ('murmured', 9),
#  ('legend', 9),
#  ('poet', 9),
#  ('sweden', 9),
#  ('tries', 9),
#  ('swiftly', 9),
#  ('musicians', 9),
#  ('steeple', 9),
#  ('raced', 9),
#  ('pacific', 9),
#  ('earthquakes', 9),
#  ('preliminary', 9),
#  ('full-time', 9),
#  ('hay', 9),
#  ('tom', 9),
#  ('salary', 9),
#  ('electron', 9),
#  ('commented', 9),
#  ('consequences', 9),
#  ('vertical', 9),
#  ('removal', 9),
#  ('regardless', 9),
#  ('players', 9),
#  ('stating', 9),
#  ('drug', 9),
#  ('doorway', 9),
#  ('customer', 9),
#  ('loan', 9),
#  ('decade', 9),
#  ('printed', 9),
#  ('wit', 9),
#  ('joe', 9),
#  ('guest', 9),
#  ('radar', 9),
#  ('surprising', 9),
#  ('seldom', 9),
#  ('scarcely', 9),
#  ('pages', 9),
#  ('amy', 9),
#  ('fences', 9),
#  ('stupid', 9),
#  ('flung', 9),
#  ('mayor', 9),
#  ('governor', 9),
#  ('erected', 9),
#  ('boat', 9),
#  ('tuesday', 9),
#  ('opera', 9),
#  ('figs.', 9),
#  ('distal', 9),
#  ('bronchioles', 9),
#  ('poorly', 9),
#  ('chronic', 9),
#  ('pray', 9),
#  ('punishment', 9),
#  ('universe', 9),
#  ('denominations', 9),
#  ('lb', 9),
#  ('acre', 9),
#  ('aerated', 9),
#  ('capitalism', 9),
#  ('teen-agers', 9),
#  ('survival', 9),
#  ('husbands', 9),
#  ('mothers', 9),
#  ('newly', 9),
#  ('conrad', 9),
#  ('skorich', 9),
#  ('shea', 9),
#  ('psychologist', 9),
#  ('murderer', 9),
#  ('namely', 9),
#  ('taxed', 9),
#  ('transducer', 9),
#  ('projects', 9),
#  ('thereof', 9),
#  ('startling', 9),
#  ('porous', 9),
#  ('canada', 9),
#  ('teaches', 9),
#  ('pseudo', 9),
#  ('pastor', 9),
#  ('christianity', 9),
#  ('nov.', 9),
#  ('dec.', 9),
#  ('cellar', 9),
#  ('larkin', 9),
#  ('lolotte', 9),
#  ('lee', 9),
#  ('quacks', 9),
#  ('thyroxine', 9),
#  ('brenner', 9),
#  ('mason', 9),
#  ('therapist', 9),
#  ('manufacturers', 8),
#  ('saami', 8),
#  ('initially', 8),
#  ('campers', 8),
#  ('meals', 8),
#  ('convicted', 8),
#  ('linguists', 8),
#  ('commonly', 8),
#  ('linguist', 8),
#  ('present-day', 8),
#  ('intonation', 8),
#  ('occurrences', 8),
#  ('deserve', 8),
#  ('arrive', 8),
#  ('nearing', 8),
#  ('comprehensive', 8),
#  ('lunar', 8),
#  ('planetary', 8),
#  ('mm', 8),
#  ('decides', 8),
#  ('reporters', 8),
#  ('sensed', 8),
#  ('scheme', 8),
#  ('fist', 8),
#  ('entertained', 8),
#  ('uniforms', 8),
#  ('guards', 8),
#  ('equipped', 8),
#  ('anywhere', 8),
#  ('heidenstam', 8),
#  ('humorous', 8),
#  ('patience', 8),
#  ('charles', 8),
#  ('fiction', 8),
#  ('weep', 8),
#  ('bullets', 8),
#  ('cigarettes', 8),
#  ('telephoned', 8),
#  ('sudden', 8),
#  ('david', 8),
#  ('soap', 8),
#  ('surgeon', 8),
#  ('earthquake', 8),
#  ('500', 8),
#  ('ocean', 8),
#  ('combinations', 8),
#  ('testified', 8),
#  ('employers', 8),
#  ('settlers', 8),
#  ('willow', 8),
#  ('killer', 8),
#  ('evidently', 8),
#  ('douglass', 8),
#  ('occurring', 8),
#  ('seventeen', 8),
#  ('financed', 8),
#  ('concepts', 8),
#  ('persistent', 8),
#  ('slavery', 8),
#  ('false', 8),
#  ('marksman', 8),
#  ('mice', 8),
#  ('dice', 8),
#  ('choosing', 8),
#  ('prayed', 8),
#  ('actives', 8),
#  ('evaluated', 8),
#  ('substances', 8),
#  ('guilty', 8),
#  ('orioles', 8),
#  ('fence', 8),
#  ('baltimore', 8),
#  ('hansen', 8),
#  ('engage', 8),
#  ('apprentice', 8),
#  ('ohio', 8),
#  ('bloat', 8),
#  ('ton', 8),
#  ('massive', 8),
#  ('predict', 8),
#  ('termed', 8),
#  ('criticized', 8),
#  ('sentences', 8),
#  ('dilemma', 8),
#  ('suburbs', 8),
#  ('clergyman', 8),
#  ('leader', 8),
#  ('factory', 8),
#  ('precision', 8),
#  ('minister', 8),
#  ('chaos', 8),
#  ('trips', 8),
#  ('praised', 8),
#  ('piano', 8),
#  ('lawrence', 8),
#  ('lawn', 8),
#  ('twenty-five', 8),
#  ('shirt', 8),
#  ('guys', 8),
#  ('highway', 8),
#  ('instruments', 8),
#  ('ordinarily', 8),
#  ('incredible', 8),
#  ('appropriated', 8),
#  ('gnp', 8),
#  ('spontaneous', 8),
#  ('stature', 8),
#  ('spatial', 8),
#  ('suburb', 8),
#  ('chandler', 8),
#  ('philosopher', 8),
#  ('alveolar', 8),
#  ('interlobular', 8),
#  ('papa-san', 8),
#  ('weapons', 8),
#  ('prevot', 8),
#  ('pen', 8),
#  ('helpful', 8),
#  ('strengthen', 8),
#  ('religions', 8),
#  ('presidential', 8),
#  ('marble', 8),
#  ('policeman', 8),
#  ('ai', 8),
#  ('substantially', 8),
#  ('golf', 8),
#  ('arnold', 8),
#  ('lookup', 8),
#  ('bee', 8),
#  ('martyr', 8),
#  ('clothing', 8),
#  ('egg', 8),
#  ('ultrasonic', 8),
#  ('cm.', 8),
#  ('andrus', 8),
#  ('enacted', 8),
#  ('saline', 8),
#  ('deemed', 8),
#  ('duly', 8),
#  ('allotments', 8),
#  ('arcs', 8),
#  ('cathode', 8),
#  ('polynomials', 8),
#  ('beckett', 8),
#  ('carmer', 8),
#  ('stevens', 8),
#  ('no.', 8),
#  ('taxes', 8),
#  ('continuity', 8),
#  ('lightning', 8),
#  ('anglican', 8),
#  ('radish', 8),
#  ('arlen', 8),
#  ('controversy', 8),
#  ('cyclist', 8),
#  ('aerosol', 8),
#  ('workbench', 8),
#  ('preacher', 8),
#  ('incurred', 8),
#  ('procurement', 8),
#  ('yokuts', 8),
#  ('posse', 8),
#  ('deductions', 8),
#  ('livestock', 8),
#  ('flatness', 8),
#  ('tumors', 8),
#  ('voltaire', 8),
#  ('modernization', 8),
#  ('co-optation', 8),
#  ('buckskin', 8),
#  ('adc', 8),
#  ('badness', 8),
#  ('panting', 7),
#  ('doubted', 7),
#  ('era', 7),
#  ('accurate', 7),
#  ('participated', 7),
#  ('fun', 7),
#  ('enthusiastic', 7),
#  ('beach', 7),
#  ('achieving', 7),
#  ('breathe', 7),
#  ('analyses', 7),
#  ('typically', 7),
#  ('similarity', 7),
#  ('meaningful', 7),
#  ('explicit', 7),
#  ('recommendations', 7),
#  ('consistent', 7),
#  ('jupiter', 7),
#  ('definitely', 7),
#  ('partially', 7),
#  ('detect', 7),
#  ('grateful', 7),
#  ('sake', 7),
#  ("o'clock", 7),
#  ('clutched', 7),
#  ('eighteen', 7),
#  ('mid', 7),
#  ('slave', 7),
#  ('historians', 7),
#  ('homogeneous', 7),
#  ('objected', 7),
#  ('poem', 7),
#  ('poems', 7),
#  ('novels', 7),
#  ('collaborated', 7),
#  ('frowning', 7),
#  ('aloud', 7),
#  ('snatched', 7),
#  ('wheels', 7),
#  ('sand', 7),
#  ('rifles', 7),
#  ('bullet', 7),
#  ('underground', 7),
#  ('lewis', 7),
#  ('creek', 7),
#  ('theoretical', 7),
#  ('symmetric', 7),
#  ('undoubtedly', 7),
#  ('enabled', 7),
#  ('abolish', 7),
#  ('cheeks', 7),
#  ('tub', 7),
#  ('displayed', 7),
#  ('arbitrary', 7),
#  ('prize', 7),
#  ('bombs', 7),
#  ('donovan', 7),
#  ('bombers', 7),
#  ('usage', 7),
#  ('synthetic', 7),
#  ('greasy', 7),
#  ('thank', 7),
#  ('quirt', 7),
#  ('wrist', 7),
#  ...]

# %%
find_candidates(training_dist)
# Out:
# [('too', 232, 0.6379310344827587),
#  ('thus', 119, 0.6974789915966386),
#  ('really', 88, 0.5795454545454546),
#  ('described', 60, 0.5333333333333333),
#  ('basis', 57, 0.42105263157894735),
#  ('months', 56, 0.5535714285714286),
#  ('caused', 49, 0.6530612244897959),
#  ('instead', 47, 0.3829787234042553),
#  ('radiation', 46, 0.32608695652173914),
#  ('cells', 43, 0.37209302325581395),
#  ('won', 41, 0.34146341463414637),
#  ('labor', 38, 0.5263157894736842),
#  ('agreed', 37, 0.5675675675675675),
#  ('becoming', 37, 0.6756756756756757),
#  ('discussion', 36, 0.4722222222222222),
#  ('asking', 36, 0.6666666666666666),
#  ('department', 34, 0.5882352941176471),
#  ('particles', 34, 0.6764705882352942),
#  ('churches', 34, 0.5882352941176471),
#  ('destroy', 33, 0.6363636363636364),
#  ('spend', 32, 0.6875),
#  ('extent', 32, 0.625),
#  ('funds', 32, 0.59375),
#  ('quickly', 30, 0.4),
#  ('wondered', 29, 0.3103448275862069),
#  ('neighborhood', 28, 0.6785714285714286),
#  ('objective', 26, 0.6923076923076923),
#  ('sleep', 26, 0.34615384615384615),
#  ('procedure', 26, 0.3076923076923077),
#  ('containing', 24, 0.6666666666666666),
#  ('university', 24, 0.5416666666666666),
#  ('downtown', 24, 0.4583333333333333),
#  ('listen', 24, 0.5416666666666666),
#  ('minimum', 24, 0.375),
#  ('concrete', 24, 0.6666666666666666),
#  ('payment', 24, 0.5833333333333334),
#  ('flowers', 23, 0.6956521739130435),
#  ('leaders', 22, 0.5909090909090909),
#  ('intensity', 22, 0.5454545454545454),
#  ('skill', 22, 0.3181818181818182),
#  ('resulted', 22, 0.4090909090909091),
#  ('sing', 21, 0.3333333333333333),
#  ('reasonable', 21, 0.5714285714285714),
#  ('democratic', 21, 0.38095238095238093),
#  ('situations', 21, 0.47619047619047616),
#  ('plants', 21, 0.6190476190476191),
#  ('scientific', 21, 0.5238095238095238),
#  ('exception', 20, 0.6),
#  ('task', 20, 0.55),
#  ('curve', 20, 0.45),
#  ('paused', 19, 0.5789473684210527),
#  ('philosophy', 19, 0.5789473684210527),
#  ('satisfactory', 19, 0.3684210526315789),
#  ('revealed', 19, 0.3684210526315789),
#  ('somehow', 19, 0.3157894736842105),
#  ('12', 19, 0.6842105263157895),
#  ('rousseau', 19, 0.6842105263157895),
#  ('apparent', 18, 0.3333333333333333),
#  ('prominent', 18, 0.3888888888888889),
#  ('curious', 18, 0.5),
#  ('prefer', 18, 0.6111111111111112),
#  ('author', 18, 0.6666666666666666),
#  ('glance', 18, 0.6111111111111112),
#  ('identical', 18, 0.5555555555555556),
#  ('dirt', 18, 0.5555555555555556),
#  ('efficiency', 18, 0.6111111111111112),
#  ('procedures', 17, 0.35294117647058826),
#  ('briefly', 17, 0.47058823529411764),
#  ('instant', 17, 0.4117647058823529),
#  ('liquor', 17, 0.5882352941176471),
#  ('definition', 17, 0.47058823529411764),
#  ('eggs', 17, 0.6470588235294118),
#  ('concluded', 17, 0.6470588235294118),
#  ('membership', 17, 0.5294117647058824),
#  ('phenomenon', 16, 0.6875),
#  ('please', 16, 0.625),
#  ('german', 16, 0.625),
#  ('listened', 16, 0.375),
#  ('meanings', 16, 0.5625),
#  ('hesitated', 15, 0.4),
#  ('cure', 15, 0.4666666666666667),
#  ('succeeded', 15, 0.6),
#  ('flesh', 15, 0.4666666666666667),
#  ('extremely', 15, 0.6),
#  ('quantity', 15, 0.3333333333333333),
#  ('frequencies', 15, 0.4),
#  ('surplus', 14, 0.5),
#  ('thoroughly', 14, 0.5714285714285714),
#  ('standards', 14, 0.5714285714285714),
#  ('proof', 14, 0.42857142857142855),
#  ('summers', 14, 0.5),
#  ('theme', 14, 0.35714285714285715),
#  ('wondering', 14, 0.5),
#  ('nearby', 14, 0.42857142857142855),
#  ('encountered', 14, 0.42857142857142855),
#  ('justify', 14, 0.5714285714285714),
#  ('reminded', 14, 0.5),
#  ('exact', 14, 0.5),
#  ('confidence', 14, 0.5714285714285714),
#  ('stored', 14, 0.6428571428571429),
#  ('newspapers', 13, 0.5384615384615384),
#  ('oil', 13, 0.6153846153846154),
#  ('prevented', 13, 0.6923076923076923),
#  ('conscious', 13, 0.5384615384615384),
#  ('novel', 13, 0.5384615384615384),
#  ('implications', 13, 0.38461538461538464),
#  ('advertising', 13, 0.5384615384615384),
#  ('reply', 13, 0.46153846153846156),
#  ('asserted', 13, 0.5384615384615384),
#  ('laugh', 13, 0.6923076923076923),
#  ('mines', 13, 0.6153846153846154),
#  ('accomplish', 13, 0.6923076923076923),
#  ('morality', 13, 0.6153846153846154),
#  ('dollar', 12, 0.4166666666666667),
#  ('feature', 12, 0.6666666666666666),
#  ('admired', 12, 0.6666666666666666),
#  ('peculiar', 12, 0.5),
#  ('instructed', 12, 0.5),
#  ('negroes', 12, 0.6666666666666666),
#  ('owner', 12, 0.3333333333333333),
#  ('sketches', 12, 0.3333333333333333),
#  ('readers', 12, 0.3333333333333333),
#  ('authentic', 12, 0.5),
#  ('allows', 12, 0.5),
#  ('element', 12, 0.5),
#  ('attracted', 12, 0.6666666666666666),
#  ('horizon', 12, 0.4166666666666667),
#  ('judgments', 12, 0.5),
#  ('classification', 12, 0.4166666666666667),
#  ('interval', 11, 0.45454545454545453),
#  ('owners', 11, 0.36363636363636365),
#  ('produces', 11, 0.5454545454545454),
#  ('earn', 11, 0.45454545454545453),
#  ('seeming', 11, 0.6363636363636364),
#  ('planes', 11, 0.6363636363636364),
#  ('over-all', 11, 0.5454545454545454),
#  ('pretending', 11, 0.5454545454545454),
#  ('mood', 11, 0.6363636363636364),
#  ('manufacturer', 11, 0.6363636363636364),
#  ('characterized', 11, 0.45454545454545453),
#  ('monitoring', 11, 0.36363636363636365),
#  ('communications', 11, 0.5454545454545454),
#  ('pressures', 11, 0.6363636363636364),
#  ('forbidden', 11, 0.6363636363636364),
#  ('neighborhoods', 11, 0.6363636363636364),
#  ('educational', 10, 0.6),
#  ('games', 10, 0.6),
#  ('29', 10, 0.6),
#  ('observers', 10, 0.6),
#  ('badly', 10, 0.4),
#  ('mississippi', 10, 0.5),
#  ('continuously', 10, 0.4),
#  ('devote', 10, 0.6),
#  ('tube', 10, 0.5),
#  ('reads', 10, 0.4),
#  ('satisfy', 10, 0.6),
#  ('discrimination', 10, 0.5),
#  ('acres', 10, 0.4),
#  ('controlling', 10, 0.4),
#  ('outlook', 10, 0.6),
#  ('asks', 10, 0.5),
#  ('net', 10, 0.4),
#  ('souls', 10, 0.5),
#  ('kiss', 10, 0.4),
#  ('chicken', 10, 0.4),
#  ('chickens', 10, 0.4),
#  ('alert', 10, 0.6),
#  ('priest', 10, 0.5),
#  ('scholarship', 10, 0.4),
#  ('reflecting', 9, 0.5555555555555556),
#  ('slammed', 9, 0.6666666666666666),
#  ('pittsburgh', 9, 0.5555555555555556),
#  ('struggling', 9, 0.6666666666666666),
#  ('assumptions', 9, 0.6666666666666666),
#  ('phone', 9, 0.6666666666666666),
#  ('prevents', 9, 0.4444444444444444),
#  ('fatal', 9, 0.4444444444444444),
#  ('breathing', 9, 0.4444444444444444),
#  ('dragged', 9, 0.5555555555555556),
#  ('unlikely', 9, 0.4444444444444444),
#  ('refers', 9, 0.5555555555555556),
#  ('stages', 9, 0.3333333333333333),
#  ('managers', 9, 0.5555555555555556),
#  ('logical', 9, 0.4444444444444444),
#  ('reviewed', 9, 0.4444444444444444),
#  ('notions', 9, 0.6666666666666666),
#  ('talents', 9, 0.3333333333333333),
#  ('technological', 9, 0.6666666666666666),
#  ('hidden', 9, 0.5555555555555556),
#  ('wheel', 9, 0.4444444444444444),
#  ('startled', 9, 0.4444444444444444),
#  ('texture', 9, 0.3333333333333333),
#  ('sober', 9, 0.5555555555555556),
#  ('communicate', 9, 0.5555555555555556),
#  ('automatic', 9, 0.6666666666666666),
#  ('initiative', 9, 0.5555555555555556),
#  ('protested', 9, 0.3333333333333333),
#  ('nationalism', 9, 0.3333333333333333),
#  ('literally', 9, 0.4444444444444444),
#  ('profession', 9, 0.4444444444444444),
#  ('investment', 9, 0.5555555555555556),
#  ('necessities', 9, 0.6666666666666666),
#  ('rice', 9, 0.5555555555555556),
#  ('quack', 9, 0.4444444444444444),
#  ('watercolor', 9, 0.3333333333333333),
#  ('failing', 8, 0.5),
#  ('collapsed', 8, 0.5),
#  ('adults', 8, 0.375),
#  ('derive', 8, 0.5),
#  ('suggestions', 8, 0.625),
#  ('presently', 8, 0.625),
#  ('blanket', 8, 0.5),
#  ('ancient', 8, 0.625),
#  ('japan', 8, 0.625),
#  ('amazing', 8, 0.5),
#  ('disaster', 8, 0.5),
#  ('slope', 8, 0.5),
#  ('partner', 8, 0.375),
#  ('accident', 8, 0.625),
#  ('feared', 8, 0.625),
#  ('crew', 8, 0.5),
#  ('articles', 8, 0.5),
#  ('verbal', 8, 0.375),
#  ('swiss', 8, 0.625),
#  ('drawings', 8, 0.625),
#  ('stare', 8, 0.375),
#  ('gaze', 8, 0.5),
#  ('sensing', 8, 0.375),
#  ('ambitious', 8, 0.5),
#  ('substituted', 8, 0.375),
#  ('assistant', 8, 0.5),
#  ('dreaming', 8, 0.5),
#  ('substitute', 8, 0.625),
#  ('industries', 8, 0.625),
#  ('china', 8, 0.375),
#  ('unite', 8, 0.5),
#  ('rescue', 8, 0.375),
#  ('legislative', 8, 0.375),
#  ('convey', 8, 0.5),
#  ('virtually', 8, 0.5),
#  ('crisis', 8, 0.375),
#  ('span', 8, 0.5),
#  ('sacrifice', 8, 0.375),
#  ('lonely', 8, 0.5),
#  ('transportation', 7, 0.42857142857142855),
#  ('inclined', 7, 0.5714285714285714),
#  ('agency', 7, 0.42857142857142855),
#  ('halfway', 7, 0.42857142857142855),
#  ('suited', 7, 0.42857142857142855),
#  ('exclaimed', 7, 0.5714285714285714),
#  ('staggered', 7, 0.42857142857142855),
#  ('instantly', 7, 0.5714285714285714),
#  ('reveals', 7, 0.42857142857142855),
#  ('destruction', 7, 0.42857142857142855),
#  ('linear', 7, 0.5714285714285714),
#  ('imply', 7, 0.42857142857142855),
#  ('scream', 7, 0.5714285714285714),
#  ('squeezed', 7, 0.5714285714285714),
#  ('requested', 7, 0.42857142857142855),
#  ('habits', 7, 0.5714285714285714),
#  ('assemble', 7, 0.5714285714285714),
#  ('bore', 7, 0.5714285714285714),
#  ('bureau', 7, 0.5714285714285714),
#  ('puzzled', 7, 0.5714285714285714),
#  ('verbs', 7, 0.42857142857142855),
#  ('grasp', 7, 0.42857142857142855),
#  ('underlying', 7, 0.42857142857142855),
#  ('knife', 7, 0.5714285714285714),
#  ('motivated', 7, 0.42857142857142855),
#  ('communion', 7, 0.5714285714285714),
#  ('uncertainty', 7, 0.42857142857142855),
#  ('ordering', 7, 0.5714285714285714),
#  ('outstanding', 7, 0.5714285714285714),
#  ('budget', 7, 0.5714285714285714),
#  ('tasks', 7, 0.42857142857142855),
#  ('bills', 7, 0.5714285714285714),
#  ('enterprises', 7, 0.42857142857142855),
#  ('savings', 7, 0.5714285714285714),
#  ('spinning', 7, 0.42857142857142855),
#  ('positivist', 7, 0.42857142857142855),
#  ('searched', 6, 0.5),
#  ('magazines', 6, 0.6666666666666666),
#  ('promoted', 6, 0.3333333333333333),
#  ('sings', 6, 0.5),
#  ('spends', 6, 0.5),
#  ('marginal', 6, 0.6666666666666666),
#  ('linguistic', 6, 0.5),
#  ('hypothesis', 6, 0.3333333333333333),
#  ('graduates', 6, 0.5),
#  ('tragic', 6, 0.6666666666666666),
#  ('admire', 6, 0.5),
#  ('bunch', 6, 0.5),
#  ('paced', 6, 0.5),
#  ('trotted', 6, 0.3333333333333333),
#  ('mills', 6, 0.3333333333333333),
#  ('palestine', 6, 0.6666666666666666),
#  ('disappointed', 6, 0.6666666666666666),
#  ('napoleon', 6, 0.6666666666666666),
#  ('reactions', 6, 0.6666666666666666),
#  ('winked', 6, 0.6666666666666666),
#  ('partners', 6, 0.5),
#  ('harbor', 6, 0.6666666666666666),
#  ('circled', 6, 0.3333333333333333),
#  ('proportions', 6, 0.3333333333333333),
#  ('hauled', 6, 0.6666666666666666),
#  ('barge', 6, 0.6666666666666666),
#  ('efficient', 6, 0.3333333333333333),
#  ('pretended', 6, 0.6666666666666666),
#  ('threats', 6, 0.6666666666666666),
#  ('mighty', 6, 0.6666666666666666),
#  ('heating', 6, 0.3333333333333333),
#  ('detected', 6, 0.6666666666666666),
#  ('progressive', 6, 0.5),
#  ('shoved', 6, 0.3333333333333333),
#  ('conducting', 6, 0.3333333333333333),
#  ('uphold', 6, 0.6666666666666666),
#  ('alabama', 6, 0.5),
#  ('psychological', 6, 0.6666666666666666),
#  ('climate', 6, 0.5),
#  ('28', 6, 0.3333333333333333),
#  ('sticky', 6, 0.6666666666666666),
#  ('exhibition', 6, 0.5),
#  ('symptoms', 6, 0.6666666666666666),
#  ('ribs', 6, 0.6666666666666666),
#  ('gesture', 6, 0.6666666666666666),
#  ('duties', 6, 0.5),
#  ('glasses', 6, 0.6666666666666666),
#  ('heels', 6, 0.3333333333333333),
#  ('revolution', 6, 0.3333333333333333),
#  ('irony', 6, 0.3333333333333333),
#  ('enterprise', 6, 0.6666666666666666),
#  ('uncertain', 6, 0.5),
#  ('compounded', 6, 0.6666666666666666),
#  ('specimen', 6, 0.5),
#  ('delighted', 6, 0.6666666666666666),
#  ('depicted', 6, 0.3333333333333333),
#  ('enters', 6, 0.6666666666666666),
#  ('conveyed', 6, 0.6666666666666666),
#  ('terminate', 6, 0.3333333333333333),
#  ('convention', 6, 0.6666666666666666),
#  ('nineteen', 6, 0.3333333333333333),
#  ('accustomed', 6, 0.6666666666666666),
#  ('surveyed', 6, 0.3333333333333333),
#  ('preach', 6, 0.6666666666666666),
#  ('caring', 6, 0.5),
#  ('realization', 6, 0.5),
#  ('detached', 6, 0.6666666666666666),
#  ('sensory', 6, 0.5),
#  ('distinctive', 6, 0.5),
#  ('magic', 6, 0.6666666666666666),
#  ('threaten', 6, 0.6666666666666666),
#  ('applications', 6, 0.5),
#  ('behalf', 6, 0.3333333333333333),
#  ('attractive', 6, 0.3333333333333333),
#  ('glittering', 6, 0.5),
#  ('relationships', 6, 0.3333333333333333),
#  ('execution', 6, 0.6666666666666666),
#  ('filter', 6, 0.5),
#  ('dilution', 6, 0.6666666666666666),
#  ('orthodox', 6, 0.5),
#  ('males', 6, 0.3333333333333333),
#  ('bothering', 6, 0.6666666666666666),
#  ('manipulate', 6, 0.3333333333333333),
#  ('erect', 6, 0.5),
#  ('whisper', 6, 0.6666666666666666),
#  ('merits', 6, 0.5),
#  ('artificial', 6, 0.6666666666666666),
#  ('circuit', 6, 0.5),
#  ('limitations', 6, 0.5),
#  ('adjacent', 6, 0.3333333333333333),
#  ('dimensional', 6, 0.5),
#  ('discrepancy', 6, 0.5),
#  ('noting', 6, 0.6666666666666666),
#  ('guilt', 6, 0.3333333333333333),
#  ('owed', 6, 0.3333333333333333),
#  ('ritual', 6, 0.3333333333333333),
#  ('ambush', 6, 0.3333333333333333),
#  ('unfortunate', 6, 0.5),
#  ('victims', 6, 0.3333333333333333),
#  ('charcoal', 6, 0.3333333333333333),
#  ('treatments', 6, 0.3333333333333333),
#  ('inscribed', 6, 0.3333333333333333),
#  ('reactionary', 6, 0.5),
#  ('fitting', 6, 0.6666666666666666),
#  ('graduated', 5, 0.6),
#  ('comprise', 5, 0.6),
#  ('dimension', 5, 0.6),
#  ('wider', 5, 0.4),
#  ('departing', 5, 0.6),
#  ('detection', 5, 0.4),
#  ('absorption', 5, 0.6),
#  ('exceptional', 5, 0.6),
#  ('scan', 5, 0.4),
#  ('awaken', 5, 0.6),
#  ('cameras', 5, 0.4),
#  ('fragile', 5, 0.6),
#  ('strict', 5, 0.6),
#  ('embarrassing', 5, 0.6),
#  ('dedicated', 5, 0.6),
#  ('segregated', 5, 0.6),
#  ('glory', 5, 0.6),
#  ('reputation', 5, 0.4),
#  ('daylight', 5, 0.6),
#  ('misfortune', 5, 0.4),
#  ('supernatural', 5, 0.4),
#  ('bone', 5, 0.6),
#  ('patch', 5, 0.6),
#  ('berry', 5, 0.6),
#  ('anchored', 5, 0.4),
#  ('provincial', 5, 0.6),
#  ('shaving', 5, 0.4),
#  ('dim', 5, 0.4),
#  ('continent', 5, 0.6),
#  ('calculations', 5, 0.4),
#  ('scars', 5, 0.6),
#  ('centered', 5, 0.4),
#  ('m', 5, 0.4),
#  ('impurities', 5, 0.6),
#  ('sizes', 5, 0.6),
#  ('corresponds', 5, 0.4),
#  ('bending', 5, 0.6),
#  ('pry', 5, 0.4),
#  ('addition', 5, 0.6),
#  ('concealed', 5, 0.4),
#  ('smiles', 5, 0.6),
#  ('preached', 5, 0.4),
#  ('tastes', 5, 0.6),
#  ('leyte', 5, 0.6),
#  ('attraction', 5, 0.6),
#  ('shipping', 5, 0.4),
#  ('appreciated', 5, 0.4),
#  ('gentile', 5, 0.4),
#  ('crushed', 5, 0.6),
#  ('descended', 5, 0.4),
#  ('assumes', 5, 0.6),
#  ('dose', 5, 0.6),
#  ('commander', 5, 0.4),
#  ('lousy', 5, 0.6),
#  ('margin', 5, 0.6),
#  ('politicians', 5, 0.6),
#  ('theater', 5, 0.6),
#  ('comic', 5, 0.6),
#  ('tail', 5, 0.6),
#  ('lemon', 5, 0.6),
#  ('hears', 5, 0.6),
#  ('bluff', 5, 0.6),
#  ('bathed', 5, 0.6),
#  ('veiled', 5, 0.4),
#  ('commit', 5, 0.6),
#  ('cruising', 5, 0.6),
#  ('breast', 5, 0.4),
#  ('unlocked', 5, 0.6),
#  ('begged', 5, 0.6),
#  ('toilet', 5, 0.6),
#  ('robbed', 5, 0.6),
#  ('certify', 5, 0.4),
#  ('row', 5, 0.4),
#  ('limiting', 5, 0.6),
#  ('entail', 5, 0.6),
#  ('carving', 5, 0.4),
#  ('twenties', 5, 0.6),
#  ('skeptical', 5, 0.4),
#  ('loving', 5, 0.6),
#  ('melody', 5, 0.6),
#  ('experimentation', 5, 0.6),
#  ('injuries', 5, 0.6),
#  ('guarding', 5, 0.4),
#  ('danced', 5, 0.6),
#  ('abstraction', 5, 0.4),
#  ('vain', 5, 0.4),
#  ('fulfillment', 5, 0.6),
#  ('justification', 5, 0.4),
#  ('kick', 5, 0.6),
#  ('vicious', 5, 0.6),
#  ('slowing', 5, 0.4),
#  ('blew', 5, 0.4),
#  ('elect', 5, 0.6),
#  ('customs', 5, 0.6),
#  ('corporate', 5, 0.4),
#  ('enact', 5, 0.6),
#  ('happiness', 5, 0.6),
#  ('announcement', 5, 0.4),
#  ('succeeds', 5, 0.6),
#  ('frank', 5, 0.6),
#  ('ignorant', 5, 0.6),
#  ('earliest', 5, 0.6),
#  ('edged', 5, 0.4),
#  ('shield', 5, 0.4),
#  ('prospect', 5, 0.4),
#  ('transmission', 5, 0.4),
#  ('shielding', 5, 0.6),
#  ('improvements', 5, 0.4),
#  ('broadway', 5, 0.6),
#  ('depends', 5, 0.4),
#  ('michigan', 5, 0.6),
#  ('intimated', 5, 0.6),
#  ('attaining', 5, 0.6),
#  ('danish', 5, 0.6),
#  ('lazy', 5, 0.4),
#  ('debt', 5, 0.6),
#  ('remembers', 5, 0.6),
#  ('films', 5, 0.6),
#  ('condemnation', 5, 0.4),
#  ('thread', 5, 0.6),
#  ('administrator', 5, 0.6),
#  ('plowing', 5, 0.6),
#  ('earnings', 5, 0.6),
#  ('thoughtfully', 5, 0.6),
#  ('granny', 5, 0.6),
#  ('invested', 5, 0.6),
#  ('pasted', 5, 0.6),
#  ('forks', 5, 0.6),
#  ('frames', 4, 0.5),
#  ('lodging', 4, 0.5),
#  ('performs', 4, 0.5),
#  ('threatens', 4, 0.5),
#  ('parameters', 4, 0.5),
#  ('puzzling', 4, 0.5),
#  ('designing', 4, 0.5),
#  ('distinctions', 4, 0.5),
#  ('disagreement', 4, 0.5),
#  ('plotted', 4, 0.5),
#  ('speakers', 4, 0.5),
#  ('exploitation', 4, 0.5),
#  ('conspicuously', 4, 0.5),
#  ('integrate', 4, 0.5),
#  ('deliberate', 4, 0.5),
#  ('accumulated', 4, 0.5),
#  ('coherent', 4, 0.5),
#  ('utter', 4, 0.5),
#  ('scared', 4, 0.5),
#  ('can', 4, 0.5),
#  ('albany', 4, 0.5),
#  ('haunches', 4, 0.5),
#  ('cocked', 4, 0.5),
#  ('flapped', 4, 0.5),
#  ('swells', 4, 0.5),
#  ('nested', 4, 0.5),
#  ('explosive', 4, 0.5),
#  ('carriage', 4, 0.5),
#  ('retreat', 4, 0.5),
#  ('stimulation', 4, 0.5),
#  ('reckon', 4, 0.5),
#  ('tool', 4, 0.5),
#  ('herds', 4, 0.5),
#  ('modulation', 4, 0.5),
#  ('breadth', 4, 0.5),
#  ('swirled', 4, 0.5),
#  ('tons', 4, 0.5),
#  ('nude', 4, 0.5),
#  ('drowned', 4, 0.5),
#  ('depend', 4, 0.5),
#  ('dock', 4, 0.5),
#  ('volunteer', 4, 0.5),
#  ('immoral', 4, 0.5),
#  ('laissez-faire', 4, 0.5),
#  ('minority', 4, 0.5),
#  ('harsh', 4, 0.5),
#  ('departures', 4, 0.5),
#  ('perfume', 4, 0.5),
#  ('engulfed', 4, 0.5),
#  ('blows', 4, 0.5),
#  ('completes', 4, 0.5),
#  ('assisting', 4, 0.5),
#  ('shoving', 4, 0.5),
#  ('thieving', 4, 0.5),
#  ('lamps', 4, 0.5),
#  ('uncomfortable', 4, 0.5),
#  ('rationalize', 4, 0.5),
#  ('revelation', 4, 0.5),
#  ('invoked', 4, 0.5),
#  ('gushed', 4, 0.5),
#  ('chase', 4, 0.5),
#  ('twitched', 4, 0.5),
#  ('severed', 4, 0.5),
#  ('impatient', 4, 0.5),
#  ('blackness', 4, 0.5),
#  ('rail', 4, 0.5),
#  ('furiously', 4, 0.5),
#  ('chill', 4, 0.5),
#  ('emotionally', 4, 0.5),
#  ('restraint', 4, 0.5),
#  ('musician', 4, 0.5),
#  ('compass', 4, 0.5),
#  ('faculty', 4, 0.5),
#  ('recognizable', 4, 0.5),
#  ('tactics', 4, 0.5),
#  ('corps', 4, 0.5),
#  ('mock', 4, 0.5),
#  ('defiance', 4, 0.5),
#  ('sensibilities', 4, 0.5),
#  ('abstractions', 4, 0.5),
#  ('speculate', 4, 0.5),
#  ('muzzle', 4, 0.5),
#  ('cups', 4, 0.5),
#  ('rockets', 4, 0.5),
#  ('dug', 4, 0.5),
#  ('ambition', 4, 0.5),
#  ('tensions', 4, 0.5),
#  ('logic', 4, 0.5),
#  ('prevails', 4, 0.5),
#  ('obstacle', 4, 0.5),
#  ('poignant', 4, 0.5),
#  ('squeezing', 4, 0.5),
#  ('monopoly', 4, 0.5),
#  ('interfere', 4, 0.5),
#  ('glinting', 4, 0.5),
#  ('rains', 4, 0.5),
#  ('austin', 4, 0.5),
#  ('judges', 4, 0.5),
#  ('confronting', 4, 0.5),
#  ('portrait', 4, 0.5),
#  ('cage', 4, 0.5),
#  ('strings', 4, 0.5),
#  ('explore', 4, 0.5),
#  ('filtering', 4, 0.5),
#  ('reminder', 4, 0.5),
#  ('prosecuted', 4, 0.5),
#  ('antique', 4, 0.5),
#  ('discontinued', 4, 0.5),
#  ('ultraviolet', 4, 0.5),
#  ('marvelous', 4, 0.5),
#  ('correspondent', 4, 0.5),
#  ('handful', 4, 0.5),
#  ('shielded', 4, 0.5),
#  ('commonwealth', 4, 0.5),
#  ('surveys', 4, 0.5),
#  ('foster', 4, 0.5),
#  ('disabled', 4, 0.5),
#  ('haunting', 4, 0.5),
#  ('fluxes', 4, 0.5),
#  ('denotes', 4, 0.5),
#  ('numbering', 4, 0.5),
#  ('specialization', 4, 0.5),
#  ('criterion', 4, 0.5),
#  ('plagued', 4, 0.5),
#  ('illiterate', 4, 0.5),
#  ('abilities', 4, 0.5),
#  ('genius', 4, 0.5),
#  ('shocked', 4, 0.5),
#  ('bush', 4, 0.5),
#  ('figuring', 4, 0.5),
#  ('multiplied', 4, 0.5),
#  ('coupling', 4, 0.5),
#  ('paradise', 4, 0.5),
#  ('deserts', 3, 0.6666666666666666),
#  ('signing', 3, 0.6666666666666666),
#  ('flourishes', 3, 0.6666666666666666),
#  ('keynote', 3, 0.6666666666666666),
#  ('hurtling', 3, 0.6666666666666666),
#  ('dulled', 3, 0.3333333333333333),
#  ('sagged', 3, 0.6666666666666666),
#  ('ached', 3, 0.3333333333333333),
#  ('conservation', 3, 0.3333333333333333),
#  ('sown', 3, 0.6666666666666666),
#  ('bags', 3, 0.6666666666666666),
#  ('launch', 3, 0.6666666666666666),
#  ('adult', 3, 0.3333333333333333),
#  ('workshops', 3, 0.6666666666666666),
#  ('nationally', 3, 0.6666666666666666),
#  ('trap', 3, 0.3333333333333333),
#  ('dealer', 3, 0.6666666666666666),
#  ('benefited', 3, 0.6666666666666666),
#  ('exterior', 3, 0.6666666666666666),
#  ('holiday', 3, 0.3333333333333333),
#  ('forests', 3, 0.3333333333333333),
#  ('lasting', 3, 0.6666666666666666),
#  ('retirement', 3, 0.3333333333333333),
#  ('expenditure', 3, 0.6666666666666666),
#  ('spaces', 3, 0.6666666666666666),
#  ('impeded', 3, 0.6666666666666666),
#  ('impress', 3, 0.6666666666666666),
#  ('exhibits', 3, 0.6666666666666666),
#  ('fumbling', 3, 0.3333333333333333),
#  ('neglecting', 3, 0.6666666666666666),
#  ('straightforward', 3, 0.3333333333333333),
#  ('criticisms', 3, 0.6666666666666666),
#  ('hissing', 3, 0.3333333333333333),
#  ('fortified', 3, 0.6666666666666666),
#  ('boiled', 3, 0.6666666666666666),
#  ('congratulated', 3, 0.6666666666666666),
#  ('layer', 3, 0.3333333333333333),
#  ('polarized', 3, 0.6666666666666666),
#  ('outbursts', 3, 0.6666666666666666),
#  ('antennae', 3, 0.3333333333333333),
#  ('mountainous', 3, 0.3333333333333333),
#  ('precede', 3, 0.3333333333333333),
#  ('boast', 3, 0.6666666666666666),
#  ('honeymoon', 3, 0.3333333333333333),
#  ('card', 3, 0.3333333333333333),
#  ('peru', 3, 0.3333333333333333),
#  ('framework', 3, 0.6666666666666666),
#  ('decency', 3, 0.6666666666666666),
#  ('polite', 3, 0.6666666666666666),
#  ('renewal', 3, 0.3333333333333333),
#  ('harvest', 3, 0.3333333333333333),
#  ('purified', 3, 0.3333333333333333),
#  ('transcendental', 3, 0.3333333333333333),
#  ('clause', 3, 0.3333333333333333),
#  ('prosperous', 3, 0.6666666666666666),
#  ('careless', 3, 0.3333333333333333),
#  ('grouped', 3, 0.3333333333333333),
#  ('epic', 3, 0.3333333333333333),
#  ('gardens', 3, 0.6666666666666666),
#  ('episodes', 3, 0.3333333333333333),
#  ('canvases', 3, 0.3333333333333333),
#  ('spectacular', 3, 0.3333333333333333),
#  ('ruin', 3, 0.6666666666666666),
#  ('echo', 3, 0.6666666666666666),
#  ('twirling', 3, 0.3333333333333333),
#  ('smelt', 3, 0.6666666666666666),
#  ('intercept', 3, 0.6666666666666666),
#  ('slot', 3, 0.3333333333333333),
#  ('grill', 3, 0.6666666666666666),
#  ('disgusted', 3, 0.6666666666666666),
#  ('stillness', 3, 0.6666666666666666),
#  ('blake', 3, 0.3333333333333333),
#  ('logically', 3, 0.6666666666666666),
#  ('rounded', 3, 0.3333333333333333),
#  ('snoring', 3, 0.6666666666666666),
#  ('sulky', 3, 0.6666666666666666),
#  ('shaded', 3, 0.6666666666666666),
#  ('sore', 3, 0.6666666666666666),
#  ('merging', 3, 0.3333333333333333),
#  ('bushes', 3, 0.3333333333333333),
#  ('estates', 3, 0.3333333333333333),
#  ('hawk', 3, 0.6666666666666666),
#  ('fringe', 3, 0.6666666666666666),
#  ('overboard', 3, 0.6666666666666666),
#  ('fort', 3, 0.6666666666666666),
#  ('paths', 3, 0.3333333333333333),
#  ('revived', 3, 0.3333333333333333),
#  ('dwarf', 3, 0.6666666666666666),
#  ('atlantic', 3, 0.6666666666666666),
#  ('gravity', 3, 0.6666666666666666),
#  ('trough', 3, 0.6666666666666666),
#  ('flattening', 3, 0.6666666666666666),
#  ('villages', 3, 0.3333333333333333),
#  ('fearing', 3, 0.6666666666666666),
#  ('marine', 3, 0.6666666666666666),
#  ('onrush', 3, 0.6666666666666666),
#  ('prompt', 3, 0.3333333333333333),
#  ('charts', 3, 0.3333333333333333),
#  ('accumulation', 3, 0.6666666666666666),
#  ('tracks', 3, 0.6666666666666666),
#  ('fires', 3, 0.3333333333333333),
#  ('shrink', 3, 0.6666666666666666),
#  ('weeds', 3, 0.6666666666666666),
#  ('wailing', 3, 0.6666666666666666),
#  ('kingdom', 3, 0.6666666666666666),
#  ('lowest', 3, 0.6666666666666666),
#  ('broadening', 3, 0.6666666666666666),
#  ('decreasing', 3, 0.3333333333333333),
#  ('investigations', 3, 0.6666666666666666),
#  ('contaminated', 3, 0.6666666666666666),
#  ('domains', 3, 0.3333333333333333),
#  ('orientation', 3, 0.6666666666666666),
#  ('saturation', 3, 0.6666666666666666),
#  ('evacuation', 3, 0.6666666666666666),
#  ('butted', 3, 0.6666666666666666),
#  ('drilled', 3, 0.6666666666666666),
#  ('endangering', 3, 0.6666666666666666),
#  ('halt', 3, 0.6666666666666666),
#  ('streaked', 3, 0.6666666666666666),
#  ('endorsed', 3, 0.6666666666666666),
#  ('filmed', 3, 0.6666666666666666),
#  ('soared', 3, 0.3333333333333333),
#  ('harness', 3, 0.6666666666666666),
#  ('itch', 3, 0.6666666666666666),
#  ('curb', 3, 0.6666666666666666),
#  ('secrecy', 3, 0.6666666666666666),
#  ('strangled', 3, 0.6666666666666666),
#  ('numbered', 3, 0.3333333333333333),
#  ('labeling', 3, 0.3333333333333333),
#  ('withdrawing', 3, 0.6666666666666666),
#  ('conspired', 3, 0.6666666666666666),
#  ('invoking', 3, 0.3333333333333333),
#  ('flattened', 3, 0.6666666666666666),
#  ('favoring', 3, 0.3333333333333333),
#  ('constitution', 3, 0.6666666666666666),
#  ('ruined', 3, 0.6666666666666666),
#  ('flowering', 3, 0.3333333333333333),
#  ('meddling', 3, 0.3333333333333333),
#  ('reconstruction', 3, 0.6666666666666666),
#  ('anglo-saxon', 3, 0.6666666666666666),
#  ('confederate', 3, 0.6666666666666666),
#  ('inferior', 3, 0.6666666666666666),
#  ('repetitions', 3, 0.6666666666666666),
#  ('aces', 3, 0.6666666666666666),
#  ('licensed', 3, 0.6666666666666666),
#  ('labels', 3, 0.6666666666666666),
#  ('lowering', 3, 0.3333333333333333),
#  ('placid', 3, 0.6666666666666666),
#  ('dive', 3, 0.3333333333333333),
#  ('shuddered', 3, 0.3333333333333333),
#  ('dwindling', 3, 0.6666666666666666),
#  ('harris', 3, 0.6666666666666666),
#  ('finely', 3, 0.6666666666666666),
#  ('residue', 3, 0.6666666666666666),
#  ('theoretically', 3, 0.3333333333333333),
#  ('intensified', 3, 0.6666666666666666),
#  ('coated', 3, 0.3333333333333333),
#  ('equilibrium', 3, 0.3333333333333333),
#  ('repelled', 3, 0.6666666666666666),
#  ('congratulate', 3, 0.6666666666666666),
#  ('enforce', 3, 0.6666666666666666),
#  ('tightening', 3, 0.6666666666666666),
#  ('clearing', 3, 0.3333333333333333),
#  ('softened', 3, 0.6666666666666666),
#  ('pleasantly', 3, 0.6666666666666666),
#  ('pan', 3, 0.6666666666666666),
#  ('athletics', 3, 0.6666666666666666),
#  ('mound', 3, 0.6666666666666666),
#  ('escaping', 3, 0.6666666666666666),
#  ('n.y.', 3, 0.3333333333333333),
#  ('expired', 3, 0.6666666666666666),
#  ('ga.', 3, 0.3333333333333333),
#  ('swelling', 3, 0.6666666666666666),
#  ('diffusing', 3, 0.3333333333333333),
#  ('suppress', 3, 0.6666666666666666),
#  ('solace', 3, 0.3333333333333333),
#  ('daring', 3, 0.6666666666666666),
#  ('mobilized', 3, 0.6666666666666666),
#  ('contradict', 3, 0.3333333333333333),
#  ('officially', 3, 0.3333333333333333),
#  ('merchandising', 3, 0.3333333333333333),
#  ('stimulates', 3, 0.3333333333333333),
#  ('slaughtered', 3, 0.3333333333333333),
#  ('stack', 3, 0.6666666666666666),
#  ('clinging', 3, 0.3333333333333333),
#  ('pulls', 3, 0.3333333333333333),
#  ('intoned', 3, 0.6666666666666666),
#  ('ass', 3, 0.6666666666666666),
#  ('tour', 3, 0.3333333333333333),
#  ('foundations', 3, 0.3333333333333333),
#  ('roosevelt', 3, 0.3333333333333333),
#  ('indecent', 3, 0.6666666666666666),
#  ('campaigned', 3, 0.6666666666666666),
#  ('pains', 3, 0.6666666666666666),
#  ('commanding', 3, 0.3333333333333333),
#  ('invade', 3, 0.3333333333333333),
#  ('comprises', 3, 0.6666666666666666),
#  ('dearly', 3, 0.6666666666666666),
#  ('replies', 3, 0.6666666666666666),
#  ('requests', 3, 0.6666666666666666),
#  ('aching', 3, 0.6666666666666666),
#  ('founding', 3, 0.3333333333333333),
#  ('viewing', 3, 0.6666666666666666),
#  ('upholding', 3, 0.6666666666666666),
#  ('straightening', 3, 0.3333333333333333),
#  ('straighten', 3, 0.6666666666666666),
#  ('flowed', 3, 0.6666666666666666),
#  ('ridicule', 3, 0.6666666666666666),
#  ('chaotic', 3, 0.6666666666666666),
#  ('hazards', 3, 0.3333333333333333),
#  ('signaling', 3, 0.3333333333333333),
#  ('adhered', 3, 0.6666666666666666),
#  ('conflicts', 3, 0.6666666666666666),
#  ('indians', 3, 0.6666666666666666),
#  ('anguish', 3, 0.6666666666666666),
#  ('haunted', 3, 0.3333333333333333),
#  ('pump', 3, 0.6666666666666666),
#  ('blackened', 3, 0.6666666666666666),
#  ('humiliation', 3, 0.6666666666666666),
#  ('mouths', 3, 0.6666666666666666),
#  ('dangling', 3, 0.6666666666666666),
#  ('wicked', 3, 0.6666666666666666),
#  ('organizing', 3, 0.6666666666666666),
#  ('bleak', 3, 0.6666666666666666),
#  ('lecturing', 3, 0.3333333333333333),
#  ('brazil', 3, 0.6666666666666666),
#  ('ransacked', 3, 0.3333333333333333),
#  ('suspend', 3, 0.6666666666666666),
#  ('stove', 3, 0.6666666666666666),
#  ('illuminating', 3, 0.3333333333333333),
#  ('wove', 3, 0.6666666666666666),
#  ('arguments', 3, 0.6666666666666666),
#  ('channel', 3, 0.6666666666666666),
#  ('purity', 3, 0.6666666666666666),
#  ('generous', 3, 0.6666666666666666),
#  ('gifts', 3, 0.6666666666666666),
#  ('buzzing', 3, 0.3333333333333333),
#  ('bats', 3, 0.6666666666666666),
#  ('amber', 3, 0.6666666666666666),
#  ('thinner', 3, 0.6666666666666666),
#  ('trains', 3, 0.6666666666666666),
#  ('squatted', 3, 0.3333333333333333),
#  ('privacy', 3, 0.6666666666666666),
#  ('gossip', 3, 0.6666666666666666),
#  ('sinister', 3, 0.3333333333333333),
#  ('wrinkled', 3, 0.3333333333333333),
#  ('hateful', 3, 0.6666666666666666),
#  ('boot', 3, 0.6666666666666666),
#  ('wildcat', 3, 0.6666666666666666),
#  ('scraping', 3, 0.6666666666666666),
#  ('highlands', 3, 0.6666666666666666),
#  ('restraining', 3, 0.3333333333333333),
#  ('redoubled', 3, 0.6666666666666666),
#  ('compromising', 3, 0.6666666666666666),
#  ('diverted', 3, 0.3333333333333333),
#  ('recovering', 3, 0.3333333333333333),
#  ('diamond', 3, 0.3333333333333333),
#  ('miserable', 3, 0.6666666666666666),
#  ('fans', 3, 0.6666666666666666),
#  ('relish', 3, 0.3333333333333333),
#  ('centering', 3, 0.3333333333333333),
#  ('alike', 3, 0.6666666666666666),
#  ('modifying', 3, 0.3333333333333333),
#  ('reassuring', 3, 0.6666666666666666),
#  ('aggregate', 3, 0.6666666666666666),
#  ('variables', 3, 0.3333333333333333),
#  ('unchanged', 3, 0.6666666666666666),
#  ('praying', 3, 0.3333333333333333),
#  ('plaster', 3, 0.6666666666666666),
#  ('slamming', 3, 0.6666666666666666),
#  ('cheated', 3, 0.3333333333333333),
#  ('hunted', 3, 0.6666666666666666),
#  ('thaw', 3, 0.6666666666666666),
#  ('poked', 3, 0.3333333333333333),
#  ('toe', 3, 0.6666666666666666),
#  ('bolster', 3, 0.6666666666666666),
#  ('cushion', 3, 0.6666666666666666),
#  ('personifies', 3, 0.6666666666666666),
#  ('aristocracy', 3, 0.6666666666666666),
#  ('challenged', 3, 0.3333333333333333),
#  ('beset', 3, 0.6666666666666666),
#  ('emerges', 3, 0.6666666666666666),
#  ('flair', 3, 0.6666666666666666),
#  ('surviving', 3, 0.6666666666666666),
#  ('scenes', 3, 0.3333333333333333),
#  ('interpret', 3, 0.3333333333333333),
#  ('disposed', 3, 0.6666666666666666),
#  ('joints', 3, 0.6666666666666666),
#  ('jumbled', 3, 0.6666666666666666),
#  ('curved', 3, 0.6666666666666666),
#  ('clues', 3, 0.6666666666666666),
#  ('wielded', 3, 0.3333333333333333),
#  ('chuckle', 3, 0.3333333333333333),
#  ('abandoning', 3, 0.3333333333333333),
#  ('recovered', 3, 0.6666666666666666),
#  ('imitations', 3, 0.3333333333333333),
#  ('dialectic', 3, 0.6666666666666666),
#  ('penetrating', 3, 0.3333333333333333),
#  ('incapable', 3, 0.3333333333333333),
#  ('attractions', 3, 0.3333333333333333),
#  ('drifts', 3, 0.6666666666666666),
#  ('extracting', 3, 0.6666666666666666),
#  ('channels', 3, 0.3333333333333333),
#  ('sized', 3, 0.6666666666666666),
#  ('violated', 3, 0.6666666666666666),
#  ('compensated', 3, 0.3333333333333333),
#  ('violating', 3, 0.3333333333333333),
#  ('dividing', 3, 0.6666666666666666),
#  ('turmoil', 3, 0.6666666666666666),
#  ('caliber', 3, 0.3333333333333333),
#  ('mortar', 3, 0.3333333333333333),
#  ('boxes', 3, 0.6666666666666666),
#  ('upstream', 3, 0.6666666666666666),
#  ('vest', 3, 0.6666666666666666),
#  ('insistent', 3, 0.6666666666666666),
#  ('stumps', 3, 0.3333333333333333),
#  ('broaden', 3, 0.6666666666666666),
#  ('saves', 3, 0.3333333333333333),
#  ('discriminating', 3, 0.6666666666666666),
#  ('diplomatic', 3, 0.6666666666666666),
#  ('urbanized', 3, 0.6666666666666666),
#  ('morale', 3, 0.6666666666666666),
#  ('kremlin', 3, 0.3333333333333333),
#  ('veto', 3, 0.6666666666666666),
#  ('secretaries', 3, 0.6666666666666666),
#  ('qualification', 3, 0.6666666666666666),
#  ('interim', 3, 0.6666666666666666),
#  ('bestowed', 3, 0.6666666666666666),
#  ('plates', 3, 0.3333333333333333),
#  ('stacked', 3, 0.6666666666666666),
#  ('fuss', 3, 0.6666666666666666),
#  ('wailed', 3, 0.3333333333333333),
#  ('barefoot', 3, 0.6666666666666666),
#  ('buds', 3, 0.3333333333333333),
#  ('wrap', 3, 0.6666666666666666),
#  ('noticing', 3, 0.6666666666666666),
#  ('imposes', 3, 0.6666666666666666),
#  ('sympathize', 3, 0.6666666666666666),
#  ('loneliness', 3, 0.3333333333333333),
#  ('decorator', 3, 0.3333333333333333),
#  ('crises', 3, 0.6666666666666666),
#  ('undertakes', 3, 0.3333333333333333),
#  ('prayers', 3, 0.6666666666666666),
#  ('sentiments', 3, 0.6666666666666666),
#  ('functioned', 3, 0.6666666666666666),
#  ('blonde', 3, 0.3333333333333333),
#  ('fragments', 3, 0.3333333333333333),
#  ('glistening', 3, 0.6666666666666666),
#  ('gleaming', 3, 0.6666666666666666),
#  ('sooner', 3, 0.6666666666666666),
#  ('astonished', 3, 0.6666666666666666),
#  ('seize', 3, 0.6666666666666666),
#  ('appointees', 3, 0.6666666666666666),
#  ('compassion', 3, 0.6666666666666666),
#  ('commitments', 3, 0.6666666666666666),
#  ...]

# %% [markdown]
# ## Building Naive Bayes Classifiers for WSD
# We are going to train and use a NB classifier to identify the correct sense of a word.
#
# The functions below will get all of the sentences containing a word of choice and generate a Bernouilli bag-of-words representation suitable for a Naive Bayes classifier.
#
# Try it out on one of the words you identified above.

# %%
def contains(sentence,astring):
    '''
    check whether sentence contains astring
    '''
    if len(sentence)>0:
        tokens,tags=zip(*sentence)
        return astring in tokens
    else:
        return False
    
def get_label(sentence,word):
    '''
    get the synset label for the word in this sentence
    '''
    count=0
    label="none"
    for token,tag in sentence:
        if token==word:
            count+=1
            label=str(tag)
    if count !=1:
        #print("Warning: {} occurs {} times in {}".format(word,count,sentence))
        pass
    return label
    
def get_word_data(sentences,word):
    '''
    select sentences containing words and construct labelled data set where each sentence is represented using Bernouilli event model
    '''
    selected_sentences=[sentence for sentence in sentences if contains(sentence,word)]
    word_data=[({token:True for (token,tag) in sentence},get_label(sentence,word)) for sentence in selected_sentences] 
    return word_data

# %%
get_word_data(training_sentences,"radiation")
# Out:
# [({'be': True,
#    'coincidence': True,
#    'combination': True,
#    'components': True,
#    'is': True,
#    'merely': True,
#    'observed': True,
#    'planet': True,
#    'possibility': True,
#    'radiation': True,
#    'result': True,
#    'solid': True,
#    'spectrum': True,
#    'suggests': True,
#    'surface': True,
#    'thermal': True,
#    'very': True},
#   "Synset('radiation.n.02')"),
#  ({'atmosphere': True,
#    'black-body': True,
#    'case': True,
#    'combination': True,
#    'components': True,
#    'definitely': True,
#    'earth': True,
#    'is': True,
#    'jupiter': True,
#    'likely': True,
#    'not': True,
#    'radiation': True,
#    'radiator': True,
#    'reaching': True,
#    'seems': True,
#    'spectrum': True,
#    'thermal': True,
#    'very': True},
#   "Synset('radiation.n.02')"),
#  ({'3': True,
#    'about': True,
#    'agreement': True,
#    'basis': True,
#    'cm': True,
#    'intensity': True,
#    'is': True,
#    'known': True,
#    'mars': True,
#    'observed': True,
#    'predicted': True,
#    'radiation': True,
#    'reasonable': True,
#    'temperature': True,
#    'thermal': True,
#    'twice': True},
#   "Synset('radiation.n.02')"),
#  ({'again': True,
#    'be': True,
#    'consistent': True,
#    'intensity': True,
#    'limited': True,
#    'low': True,
#    'observations': True,
#    'origin': True,
#    'radiation': True,
#    'saturn': True,
#    'seems': True,
#    'thermal': True},
#   "Synset('radiation.n.02')"),
#  ({'attempts': True,
#    'be': True,
#    'diameters': True,
#    'distances': True,
#    'earth': True,
#    'expected': True,
#    'intensity': True,
#    'low': True,
#    'measure': True,
#    'planets': True,
#    'radiation': True,
#    'radio': True,
#    'reaching': True,
#    'reported': True,
#    'small': True,
#    'sources': True,
#    'thermal': True,
#    'very': True},
#   "Synset('radiation.n.02')"),
#  ({'began': True,
#    'beringer': True,
#    'cm': True,
#    'detection': True,
#    'dicke': True,
#    'moon': True,
#    'planets': True,
#    'radiation': True,
#    'study': True,
#    'thermal': True},
#   "Synset('radiation.n.02')"),
#  ({'burke': True,
#    'discussed': True,
#    'gallet': True,
#    'planetary': True,
#    'radiation': True,
#    'sporadic': True,
#    'type': True},
#   "Synset('radiation.n.02')"),
#  ({'cm': True,
#    'drake': True,
#    'ewen': True,
#    'jupiter': True,
#    'mars': True,
#    'mayer': True,
#    'mccullough': True,
#    'observed': True,
#    'origin': True,
#    'presumably': True,
#    'radiation': True,
#    'saturn': True,
#    'sloanaker': True,
#    'steady': True,
#    'thermal': True,
#    'venus': True,
#    'was': True},
#   "Synset('radiation.n.02')"),
#  ({'apparatus': True,
#    'difficult': True,
#    'earth': True,
#    'intensity': True,
#    'low': True,
#    'measurements': True,
#    'planetary': True,
#    'polarization': True,
#    'presently': True,
#    'radiation': True,
#    'remain': True,
#    'sensitivity': True},
#   "Synset('radiation.n.01')"),
#  ({'been': True,
#    'determination': True,
#    'few': True,
#    'measurements': True,
#    'planetary': True,
#    'polarization': True,
#    'radiation': True,
#    'specifically': True},
#   "Synset('radiation.n.01')"),
#  ({'50': True,
#    'altitude': True,
#    'azimuth': True,
#    'change': True,
#    'foot': True,
#    'intensities': True,
#    'jupiter': True,
#    'linearly': True,
#    'local': True,
#    'made': True,
#    'measurements': True,
#    'mounted': True,
#    'part': True,
#    'polarized': True,
#    'radiation': True,
#    'reflector': True,
#    'shown': True,
#    'substantial': True,
#    'systematic': True,
#    'venus': True},
#   "Synset('radiation.n.01')"),
#  ({'available': True,
#    'information': True,
#    'intensity': True,
#    'now': True,
#    'planets': True,
#    'radiation': True,
#    'restricted': True,
#    'result': True,
#    'significant': True,
#    'very': True},
#   "Synset('radiation.n.01')"),
#  ({'apparent': True,
#    'black-body': True,
#    'concept': True,
#    'describe': True,
#    'moon': True,
#    'planets': True,
#    'radiation': True,
#    'received': True,
#    'temperature': True,
#    'used': True},
#   "Synset('radiation.n.01')"),
#  ({'black-body': True,
#    'compared': True,
#    'disk': True,
#    'hypothetical': True,
#    'planet': True,
#    'radiation': True,
#    'received': True,
#    'same': True,
#    'subtends': True,
#    'visible': True},
#   "Synset('radiation.n.01')"),
#  ({'apparent': True,
#    'assumed': True,
#    'black-body': True,
#    'disk': True,
#    'equal': True,
#    'intensity': True,
#    'is': True,
#    'observed': True,
#    'radiation': True,
#    'temperature': True},
#   "Synset('radiation.n.02')"),
#  ({'apparent': True,
#    'black-body': True,
#    'concept': True,
#    'correspond': True,
#    'material': True,
#    'not': True,
#    'only': True,
#    'origin': True,
#    'physical': True,
#    'planet': True,
#    'radiates': True,
#    'radiation': True,
#    'really': True,
#    'specify': True,
#    'temperature': True,
#    'use': True},
#   "Synset('radiation.n.02')"),
#  ({'cause': True,
#    'centimeter': True,
#    'decimeter': True,
#    'errors': True,
#    'expected': True,
#    'extreme': True,
#    'neglecting': True,
#    'not': True,
#    'outbursts': True,
#    'planetary': True,
#    'radiation': True,
#    'range': True,
#    'reflected': True,
#    'sizable': True,
#    'therefore': True,
#    'wave-length': True},
#   "Synset('radiation.n.02')"),
#  ({'agreement': True,
#    'douglass': True,
#    'extra': True,
#    'good': True,
#    'indicated': True,
#    'lines': True,
#    'material': True,
#    'pattern': True,
#    'presence': True,
#    'radiation': True,
#    'taken': True,
#    'was': True},
#   "Synset('radiation.n.01')"),
#  ({'are': True,
#    'closed-circuit': True,
#    'commonly': True,
#    'counters': True,
#    'devices': True,
#    'found': True,
#    'hospital': True,
#    'instruction': True,
#    'internal': True,
#    'paging': True,
#    'practically': True,
#    'radiation': True,
#    'similar': True,
#    'timers': True,
#    'tv': True,
#    'used': True},
#   "Synset('radiation.n.01')"),
#  ({'contained': True,
#    'explored': True,
#    'eye': True,
#    'human': True,
#    'obtainable': True,
#    'papers': True,
#    'presented': True,
#    'radiation': True,
#    'results': True,
#    'ultrasonic': True},
#   "Synset('radiation.n.01')"),
#  ({'4': True,
#    'blocks': True,
#    'bracing': True,
#    'complete': True,
#    'edge': True,
#    'inch': True,
#    'mortar': True,
#    'poured': True,
#    'radiation': True,
#    'shielding': True,
#    'thickness': True,
#    'wall': True},
#   "Synset('radiation.n.01')"),
#  ({'24': True,
#    'absolute': True,
#    'almost': True,
#    'fallout': True,
#    'page': True,
#    'protection': True,
#    'provide': True,
#    'radiation': True,
#    'shelter': True,
#    'shown': True},
#   "Synset('radiation.n.01')"),
#  ({'light': True, 'radiation': True, 'scatters': True, 'somewhat': True},
#   "Synset('radiation.n.01')"),
#  ({'entrance': True,
#    'intensity': True,
#    'radiation': True,
#    'reduce': True,
#    'sharp': True,
#    'shelter': True,
#    'therefore': True,
#    'turns': True},
#   "Synset('radiation.n.01')"),
#  ({'necessary': True,
#    'radiation': True,
#    'radio': True,
#    'reception': True,
#    'shielding': True},
#   "Synset('radiation.n.01')"),
#  ({'1': True,
#    'atomic': True,
#    'burst': True,
#    'explosion': True,
#    'hour': True,
#    'hours': True,
#    'intensity': True,
#    'is': True,
#    'only': True,
#    'percent': True,
#    'radiation': True,
#    'was': True},
#   "Synset('radiation.n.01')"),
#  ({'be': True,
#    'dangerous': True,
#    'extremely': True,
#    'intense': True,
#    'radiation': True,
#    'so': True},
#   "Synset('radiation.n.01')"),
#  ({'are': True,
#    'available': True,
#    'be': True,
#    'best': True,
#    'fallout': True,
#    'home': True,
#    'instruments': True,
#    'locating': True,
#    'offers': True,
#    'portion': True,
#    'protection': True,
#    'radiation': True,
#    'suitable': True,
#    'use': True},
#   "Synset('radiation.n.01')"),
#  ({'available': True,
#    'battery': True,
#    'become': True,
#    'built-in': True,
#    'is': True,
#    'meters': True,
#    'possibility': True,
#    'radiation': True,
#    'radios': True},
#   "Synset('radiation.n.01')"),
#  ({'allow': True,
#    'basement': True,
#    'come': True,
#    'decayed': True,
#    'enough': True,
#    'radiation': True,
#    'shelter': True,
#    'time': True,
#    'use': True,
#    'whole': True},
#   "Synset('radiation.n.01')"),
#  ({'exposure': True,
#    'hold': True,
#    'however': True,
#    'minimum': True,
#    'much': True,
#    'possible': True,
#    'radiation': True,
#    'shelter': True,
#    'spent': True,
#    'time': True},
#   "Synset('radiation.n.01')"),
#  ({'basement': True,
#    'dwelling': True,
#    'fallout': True,
#    'family': True,
#    'natural': True,
#    'provides': True,
#    'radiation': True,
#    'shielding': True,
#    'some': True},
#   "Synset('radiation.n.01')"),
#  ({'about': True,
#    'be': True,
#    'half': True,
#    'is': True,
#    'outside': True,
#    'radiation': True},
#   "Synset('radiation.n.01')"),
#  ({'basement': True,
#    'belowground': True,
#    'cut': True,
#    'fallout': True,
#    'level': True,
#    'one': True,
#    'outside': True,
#    'radiation': True,
#    'tenth': True},
#   "Synset('radiation.n.01')"),
#  ({'arc': True,
#    'column': True,
#    'conduction': True,
#    'heat': True,
#    'molecular': True,
#    'radiation': True,
#    'transfer': True},
#   "Synset('radiation.n.01')"),
#  ({'carbon': True,
#    'covered': True,
#    'inner': True,
#    'radiation': True,
#    'reduce': True,
#    'shield': True,
#    'surface': True},
#   "Synset('radiation.n.01')"),
#  ({'anode': True,
#    'concerned': True,
#    'environmental': True,
#    'exposed': True,
#    'holder': True,
#    'radiation': True,
#    'taken': True,
#    'temperature': True},
#   "Synset('radiation.n.01')"),
#  ({'also': True,
#    'anode': True,
#    'back': True,
#    'be': True,
#    'characteristic': True,
#    'geometry': True,
#    'holder': True,
#    'metal': True,
#    'originating': True,
#    'radiation': True,
#    'reflected': True,
#    'reflection': True,
#    'small': True,
#    'specific': True,
#    'specular': True,
#    'surfaces': True,
#    'surrounding': True},
#   "Synset('radiation.n.01')"),
#  ({'analogously': True,
#    'anode': True,
#    'calculated': True,
#    'computed': True,
#    'equation': True,
#    'fourth': True,
#    'is': True,
#    'loss': True,
#    'mean': True,
#    'powers': True,
#    'radiation': True,
#    'surface': True,
#    'temperatures': True},
#   "Synset('radiation.n.01')"),
#  ({'be': True,
#    'continual': True,
#    'disappeared': True,
#    'effects': True,
#    'is': True,
#    'loss': True,
#    'material': True,
#    'micrometeorites': True,
#    'micrometeoritic': True,
#    'otherwise': True,
#    'radiation': True,
#    'replenishment': True,
#    'space': True},
#   "Synset('radiation.n.01')")]

# %% [markdown]
# We can now train and test a NaiveBayesClassifier.  Here we are going to use the nltk one, but feel free to try out your own developed in earlier labs.

# %%
from nltk.classify.naivebayes import NaiveBayesClassifier

training=get_word_data(training_sentences,"thus")
testing=get_word_data(testing_sentences,"thus")
aclassifier=NaiveBayesClassifier.train(training)

# %%
len(training)
# Out:
# 119

# %%
len(testing)
# Out:
# 12

# %% [markdown]
# ### Exercise 2.1
# Write a function to evaluate the accuracy of your classifier on some test data.
#
# Test it using `testing`

# %%
def evaluate(cls,test_data):
    correct=0
    wrong=0
   
    for doc,label in test_data:
        prediction=cls.classify(doc)
        if prediction==label:
            correct+=1
        else:
            wrong+=1
    if correct+wrong > 0:
      acc=correct/(correct+wrong)
    else:
      acc=1
    print("Accuracy of NB classification on testing data is {} out of {} = {}".format(correct,correct+wrong,acc))

# %%
evaluate(aclassifier,testing)
# Out:
# Accuracy of NB classification on testing data is 7 out of 12 = 0.5833333333333334

# %%
evaluate(aclassifier,training)
# Out:
# Accuracy of NB classification on testing data is 118 out of 119 = 0.9915966386554622

# %% [markdown]
# ### Exercise 2.2 (**EXTENSION**)
# Write some code to determine the precision of each class.  You might want to adapt / reuse the ConfusionMatrix class from Lab_4_1

# %%
class ConfusionMatrix:
  def __init__(self,predictions,goldstandard,classes=("P","N")):
    (self.c1,self.c2)=classes 
    self.TP=0
    self.FP=0
    self.FN=0
    self.TN=0
    for p,g in zip(predictions,goldstandard):
      
      if g==self.c1:
        if p==self.c1:
            self.TP+=1
        else:
            self.FN+=1
      elif p==self.c1:
          self.FP+=1
      else:
          self.TN+=1        
    
  def precision(self):
    #put your code to compute precision here
    if self.TP + self.FP > 0:
      p = self.TP / (self.TP + self.FP)
    else:
      p = 1
    
    return p
  
  def recall(self):
    r=0
    #put your code to compute recall here
    
    return r
  
  def f1(self):
    f1=0
    #put your code to compute f1 here
      
    return f1 
  def display(self):
    print("TP = {}, FN = {}".format(self.TP,self.FN))
    print("FP = {}, TN = {}".format(self.FP, self.TN))

# %%
docs,labels=zip(*testing)
predictions=[aclassifier.classify(doc) for doc in docs]
myCM=ConfusionMatrix(predictions,labels,classes=set(labels))

# %%
myCM.display()
# Out:
# TP = 3, FN = 4
# FP = 1, TN = 4

# %%
myCM.precision()
# Out:
# 0.75

# %%
classes=list(set(labels))
reversed(classes)

# %%
def evaluate_precision(cls,test_data,classes=[]):
    if len(test_data)>0:
      docs,labels=zip(*test_data)
      predictions=[cls.classify(doc) for doc in docs]
      if len(classes)==0:
        classes=list(set(labels))
      print(classes)
      cm1 = ConfusionMatrix(predictions,labels,classes=classes)
      cm1.display()
      print("Precision for sense {} is {}".format(classes[0],cm1.precision()))
      cm2 = ConfusionMatrix(predictions,labels,classes=list(reversed(classes)))
      cm2.display()
      print("Precision for sense {} is {}".format(classes[1],cm2.precision()))
      return (cm1.precision(),cm2.precision())
    else:
      return(1,1)
      
evaluate_precision(aclassifier,testing)
# Out:
# ["Synset('thus.r.02')", "Synset('therefore.r.01')"]
# TP = 3, FN = 4
# FP = 1, TN = 4
# Precision for sense Synset('thus.r.02') is 0.75
# TP = 4, FN = 1
# FP = 4, TN = 3
# Precision for sense Synset('therefore.r.01') is 0.5
# (0.75, 0.5)

# %% [markdown]
# ### Exercise 2.3 (**EXTENSION**)
# Write a function `train_and_test()` which gets the appropriate training and testing data for a given word, builds a classifier and outputs the precision with which each class is predicted

# %%
def train_and_test(word):
    training=get_word_data(training_sentences,word)
    testing=get_word_data(testing_sentences,word)
    print(len(training),len(testing))
    classifier=NaiveBayesClassifier.train(training)
    evaluate(classifier,testing)
    #docs,labels=zip(*testing)
    #print(set(labels))
    train_docs,train_labels=zip(*training)
    print(set(train_labels))
    p1,p2=evaluate_precision(classifier,testing,classes=list(set(train_labels)))
    return (p1,p2)
    
train_and_test("too")
# Out:
# 221 25
# Accuracy of NB classification on testing data is 15 out of 25 = 0.6
# {"Synset('excessively.r.01')", "Synset('besides.r.02')"}
# ["Synset('excessively.r.01')", "Synset('besides.r.02')"]
# TP = 14, FN = 4
# FP = 6, TN = 1
# Precision for sense Synset('excessively.r.01') is 0.7
# TP = 1, FN = 6
# FP = 4, TN = 14
# Precision for sense Synset('besides.r.02') is 0.2
# (0.7, 0.2)

# %% [markdown]
# ### Exercise 2.4 (**EXTENSION**)
# * Run `train_and_test()` on the top 50 candidate words identified earlier in the exercise.
# * Display results in a pandas dataframe
# * Calculate average precision

# %%
allwords=[word for (word,f,s) in find_candidates(find_sense_distributions(training_sentences))]
top50=allwords[:50]

# %%
top50
# Out:
# ['too',
#  'thus',
#  'really',
#  'described',
#  'basis',
#  'months',
#  'caused',
#  'instead',
#  'radiation',
#  'cells',
#  'won',
#  'labor',
#  'agreed',
#  'becoming',
#  'discussion',
#  'asking',
#  'department',
#  'particles',
#  'churches',
#  'destroy',
#  'spend',
#  'extent',
#  'funds',
#  'quickly',
#  'wondered',
#  'neighborhood',
#  'objective',
#  'sleep',
#  'procedure',
#  'containing',
#  'university',
#  'downtown',
#  'listen',
#  'minimum',
#  'concrete',
#  'payment',
#  'flowers',
#  'leaders',
#  'intensity',
#  'skill',
#  'resulted',
#  'sing',
#  'reasonable',
#  'democratic',
#  'situations',
#  'plants',
#  'scientific',
#  'exception',
#  'task',
#  'curve']

# %%
results=[]
for word in top50:
  print(word)
  p1,p2=train_and_test(word)
  results.append((word,p1,p2,(p1+p2)/2))
# Out:
# too
# 221 25
# Accuracy of NB classification on testing data is 15 out of 25 = 0.6
# {"Synset('excessively.r.01')", "Synset('besides.r.02')"}
# ["Synset('excessively.r.01')", "Synset('besides.r.02')"]
# TP = 14, FN = 4
# FP = 6, TN = 1
# Precision for sense Synset('excessively.r.01') is 0.7
# TP = 1, FN = 6
# FP = 4, TN = 14
# Precision for sense Synset('besides.r.02') is 0.2
# thus
# 119 12
# Accuracy of NB classification on testing data is 7 out of 12 = 0.5833333333333334
# {"Synset('thus.r.02')", "Synset('therefore.r.01')"}
# ["Synset('thus.r.02')", "Synset('therefore.r.01')"]
# TP = 3, FN = 4
# FP = 1, TN = 4
# Precision for sense Synset('thus.r.02') is 0.75
# TP = 4, FN = 1
# FP = 4, TN = 3
# Precision for sense Synset('therefore.r.01') is 0.5
# really
# 88 13
# Accuracy of NB classification on testing data is 6 out of 13 = 0.46153846153846156
# {"Synset('actually.r.01')", "Synset('truly.r.01')"}
# ["Synset('actually.r.01')", "Synset('truly.r.01')"]
# TP = 1, FN = 3
# FP = 4, TN = 5
# Precision for sense Synset('actually.r.01') is 0.2
# TP = 5, FN = 4
# FP = 3, TN = 1
# Precision for sense Synset('truly.r.01') is 0.625
# described
# 60 20
# Accuracy of NB classification on testing data is 14 out of 20 = 0.7
# {"Synset('describe.v.01')", "Synset('report.v.01')"}
# ["Synset('describe.v.01')", "Synset('report.v.01')"]
# TP = 7, FN = 1
# FP = 5, TN = 7
# Precision for sense Synset('describe.v.01') is 0.5833333333333334
# TP = 7, FN = 5
# FP = 1, TN = 7
# Precision for sense Synset('report.v.01') is 0.875
# basis
# 54 9
# Accuracy of NB classification on testing data is 5 out of 9 = 0.5555555555555556
# {"Synset('footing.n.02')", "Synset('basis.n.02')"}
# ["Synset('footing.n.02')", "Synset('basis.n.02')"]
# TP = 4, FN = 1
# FP = 3, TN = 1
# Precision for sense Synset('footing.n.02') is 0.5714285714285714
# TP = 1, FN = 3
# FP = 1, TN = 4
# Precision for sense Synset('basis.n.02') is 0.5
# months
# 53 3
# Accuracy of NB classification on testing data is 0 out of 3 = 0.0
# {"Synset('calendar_month.n.01')", "Synset('month.n.02')"}
# ["Synset('calendar_month.n.01')", "Synset('month.n.02')"]
# TP = 0, FN = 3
# FP = 0, TN = 0
# Precision for sense Synset('calendar_month.n.01') is 1
# TP = 0, FN = 0
# FP = 3, TN = 0
# Precision for sense Synset('month.n.02') is 0.0
# caused
# 48 13
# Accuracy of NB classification on testing data is 11 out of 13 = 0.8461538461538461
# {"Synset('induce.v.02')", "Synset('cause.v.01')"}
# ["Synset('induce.v.02')", "Synset('cause.v.01')"]
# TP = 0, FN = 0
# FP = 2, TN = 11
# Precision for sense Synset('induce.v.02') is 0.0
# TP = 11, FN = 2
# FP = 0, TN = 0
# Precision for sense Synset('cause.v.01') is 1.0
# instead
# 47 9
# Accuracy of NB classification on testing data is 7 out of 9 = 0.7777777777777778
# {"Synset('rather.r.01')", "Synset('alternatively.r.01')"}
# ["Synset('rather.r.01')", "Synset('alternatively.r.01')"]
# TP = 1, FN = 1
# FP = 1, TN = 6
# Precision for sense Synset('rather.r.01') is 0.5
# TP = 6, FN = 1
# FP = 1, TN = 1
# Precision for sense Synset('alternatively.r.01') is 0.8571428571428571
# radiation
# 40 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('radiation.n.02')", "Synset('radiation.n.01')"}
# cells
# 37 23
# Accuracy of NB classification on testing data is 9 out of 23 = 0.391304347826087
# {"Synset('cell.n.01')", "Synset('cell.n.02')"}
# ["Synset('cell.n.01')", "Synset('cell.n.02')"]
# TP = 7, FN = 7
# FP = 7, TN = 2
# Precision for sense Synset('cell.n.01') is 0.5
# TP = 2, FN = 7
# FP = 7, TN = 7
# Precision for sense Synset('cell.n.02') is 0.2222222222222222
# won
# 41 11
# Accuracy of NB classification on testing data is 9 out of 11 = 0.8181818181818182
# {"Synset('win.v.01')", "Synset('acquire.v.05')"}
# ["Synset('win.v.01')", "Synset('acquire.v.05')"]
# TP = 9, FN = 0
# FP = 2, TN = 0
# Precision for sense Synset('win.v.01') is 0.8181818181818182
# TP = 0, FN = 2
# FP = 0, TN = 9
# Precision for sense Synset('acquire.v.05') is 1
# labor
# 36 1
# Accuracy of NB classification on testing data is 1 out of 1 = 1.0
# {"Synset('labor.n.02')", "Synset('labor.n.01')"}
# ["Synset('labor.n.02')", "Synset('labor.n.01')"]
# TP = 1, FN = 0
# FP = 0, TN = 0
# Precision for sense Synset('labor.n.02') is 1.0
# TP = 0, FN = 0
# FP = 0, TN = 1
# Precision for sense Synset('labor.n.01') is 1
# agreed
# 36 7
# Accuracy of NB classification on testing data is 6 out of 7 = 0.8571428571428571
# {"Synset('agree.v.01')", "Synset('agree.v.02')"}
# ["Synset('agree.v.01')", "Synset('agree.v.02')"]
# TP = 6, FN = 0
# FP = 1, TN = 0
# Precision for sense Synset('agree.v.01') is 0.8571428571428571
# TP = 0, FN = 1
# FP = 0, TN = 6
# Precision for sense Synset('agree.v.02') is 1
# becoming
# 37 4
# Accuracy of NB classification on testing data is 3 out of 4 = 0.75
# {"Synset('become.v.02')", "Synset('become.v.01')"}
# ["Synset('become.v.02')", "Synset('become.v.01')"]
# TP = 0, FN = 1
# FP = 0, TN = 3
# Precision for sense Synset('become.v.02') is 1
# TP = 3, FN = 0
# FP = 1, TN = 0
# Precision for sense Synset('become.v.01') is 0.75
# discussion
# 35 5
# Accuracy of NB classification on testing data is 1 out of 5 = 0.2
# {"Synset('discussion.n.02')", "Synset('discussion.n.01')"}
# ["Synset('discussion.n.02')", "Synset('discussion.n.01')"]
# TP = 0, FN = 2
# FP = 2, TN = 1
# Precision for sense Synset('discussion.n.02') is 0.0
# TP = 1, FN = 2
# FP = 2, TN = 0
# Precision for sense Synset('discussion.n.01') is 0.3333333333333333
# asking
# 35 5
# Accuracy of NB classification on testing data is 5 out of 5 = 1.0
# {"Synset('ask.v.01')", "Synset('ask.v.02')"}
# ["Synset('ask.v.01')", "Synset('ask.v.02')"]
# TP = 1, FN = 0
# FP = 0, TN = 4
# Precision for sense Synset('ask.v.01') is 1.0
# TP = 4, FN = 0
# FP = 0, TN = 1
# Precision for sense Synset('ask.v.02') is 1.0
# department
# 33 2
# Accuracy of NB classification on testing data is 1 out of 2 = 0.5
# {"Synset('group.n.01')", "Synset('department.n.01')"}
# ["Synset('group.n.01')", "Synset('department.n.01')"]
# TP = 0, FN = 0
# FP = 1, TN = 1
# Precision for sense Synset('group.n.01') is 0.0
# TP = 1, FN = 1
# FP = 0, TN = 0
# Precision for sense Synset('department.n.01') is 1.0
# particles
# 34 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('particle.n.02')", "Synset('atom.n.02')"}
# churches
# 31 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('church.n.01')", "Synset('church.n.02')"}
# destroy
# 33 3
# Accuracy of NB classification on testing data is 2 out of 3 = 0.6666666666666666
# {"Synset('destroy.v.02')", "Synset('destroy.v.01')"}
# ["Synset('destroy.v.02')", "Synset('destroy.v.01')"]
# TP = 0, FN = 0
# FP = 0, TN = 3
# Precision for sense Synset('destroy.v.02') is 1
# TP = 2, FN = 0
# FP = 1, TN = 0
# Precision for sense Synset('destroy.v.01') is 0.6666666666666666
# spend
# 32 12
# Accuracy of NB classification on testing data is 9 out of 12 = 0.75
# {"Synset('spend.v.02')", "Synset('spend.v.01')"}
# ["Synset('spend.v.02')", "Synset('spend.v.01')"]
# TP = 1, FN = 1
# FP = 2, TN = 8
# Precision for sense Synset('spend.v.02') is 0.3333333333333333
# TP = 8, FN = 2
# FP = 1, TN = 1
# Precision for sense Synset('spend.v.01') is 0.8888888888888888
# extent
# 32 6
# Accuracy of NB classification on testing data is 4 out of 6 = 0.6666666666666666
# {"Synset('extent.n.01')", "Synset('extent.n.02')"}
# ["Synset('extent.n.01')", "Synset('extent.n.02')"]
# TP = 1, FN = 2
# FP = 0, TN = 3
# Precision for sense Synset('extent.n.01') is 1.0
# TP = 3, FN = 0
# FP = 2, TN = 1
# Precision for sense Synset('extent.n.02') is 0.6
# funds
# 30 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('fund.n.01')", "Synset('funds.n.01')"}
# quickly
# 30 6
# Accuracy of NB classification on testing data is 5 out of 6 = 0.8333333333333334
# {"Synset('promptly.r.01')", "Synset('quickly.r.01')"}
# ["Synset('promptly.r.01')", "Synset('quickly.r.01')"]
# TP = 1, FN = 1
# FP = 0, TN = 4
# Precision for sense Synset('promptly.r.01') is 1.0
# TP = 4, FN = 0
# FP = 1, TN = 1
# Precision for sense Synset('quickly.r.01') is 0.8
# wondered
# 29 8
# Accuracy of NB classification on testing data is 5 out of 8 = 0.625
# {"Synset('wonder.v.01')", "Synset('wonder.v.02')"}
# ["Synset('wonder.v.01')", "Synset('wonder.v.02')"]
# TP = 4, FN = 0
# FP = 3, TN = 1
# Precision for sense Synset('wonder.v.01') is 0.5714285714285714
# TP = 1, FN = 3
# FP = 0, TN = 4
# Precision for sense Synset('wonder.v.02') is 1.0
# neighborhood
# 28 2
# Accuracy of NB classification on testing data is 1 out of 2 = 0.5
# {"Synset('vicinity.n.01')", "Synset('neighborhood.n.02')"}
# ["Synset('vicinity.n.01')", "Synset('neighborhood.n.02')"]
# TP = 1, FN = 1
# FP = 0, TN = 0
# Precision for sense Synset('vicinity.n.01') is 1.0
# TP = 0, FN = 0
# FP = 1, TN = 1
# Precision for sense Synset('neighborhood.n.02') is 0.0
# objective
# 25 3
# Accuracy of NB classification on testing data is 1 out of 3 = 0.3333333333333333
# {"Synset('aim.n.02')", "Synset('objective.a.01')"}
# ["Synset('aim.n.02')", "Synset('objective.a.01')"]
# TP = 1, FN = 1
# FP = 1, TN = 0
# Precision for sense Synset('aim.n.02') is 0.5
# TP = 0, FN = 1
# FP = 1, TN = 1
# Precision for sense Synset('objective.a.01') is 0.0
# sleep
# 25 7
# Accuracy of NB classification on testing data is 2 out of 7 = 0.2857142857142857
# {"Synset('sleep.v.01')", "Synset('sleep.n.01')"}
# ["Synset('sleep.v.01')", "Synset('sleep.n.01')"]
# TP = 1, FN = 0
# FP = 5, TN = 1
# Precision for sense Synset('sleep.v.01') is 0.16666666666666666
# TP = 1, FN = 5
# FP = 0, TN = 1
# Precision for sense Synset('sleep.n.01') is 1.0
# procedure
# 26 7
# Accuracy of NB classification on testing data is 4 out of 7 = 0.5714285714285714
# {"Synset('operation.n.07')", "Synset('procedure.n.01')"}
# ["Synset('operation.n.07')", "Synset('procedure.n.01')"]
# TP = 0, FN = 1
# FP = 2, TN = 4
# Precision for sense Synset('operation.n.07') is 0.0
# TP = 4, FN = 2
# FP = 1, TN = 0
# Precision for sense Synset('procedure.n.01') is 0.8
# containing
# 24 12
# Accuracy of NB classification on testing data is 11 out of 12 = 0.9166666666666666
# {"Synset('hold.v.11')", "Synset('incorporate.v.02')"}
# ["Synset('hold.v.11')", "Synset('incorporate.v.02')"]
# TP = 0, FN = 0
# FP = 1, TN = 11
# Precision for sense Synset('hold.v.11') is 0.0
# TP = 11, FN = 1
# FP = 0, TN = 0
# Precision for sense Synset('incorporate.v.02') is 1.0
# university
# 24 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('university.n.01')", "Synset('university.n.02')"}
# downtown
# 23 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('business_district.n.01')", "Synset('downtown.a.01')"}
# listen
# 23 7
# Accuracy of NB classification on testing data is 4 out of 7 = 0.5714285714285714
# {"Synset('listen.v.01')", "Synset('listen.v.02')"}
# ["Synset('listen.v.01')", "Synset('listen.v.02')"]
# TP = 4, FN = 0
# FP = 3, TN = 0
# Precision for sense Synset('listen.v.01') is 0.5714285714285714
# TP = 0, FN = 3
# FP = 0, TN = 4
# Precision for sense Synset('listen.v.02') is 1
# minimum
# 22 7
# Accuracy of NB classification on testing data is 5 out of 7 = 0.7142857142857143
# {"Synset('minimal.a.01')", "Synset('minimum.n.01')"}
# ["Synset('minimal.a.01')", "Synset('minimum.n.01')"]
# TP = 5, FN = 2
# FP = 0, TN = 0
# Precision for sense Synset('minimal.a.01') is 1.0
# TP = 0, FN = 0
# FP = 2, TN = 5
# Precision for sense Synset('minimum.n.01') is 0.0
# concrete
# 24 1
# Accuracy of NB classification on testing data is 1 out of 1 = 1.0
# {"Synset('concrete.a.01')", "Synset('concrete.n.01')"}
# ["Synset('concrete.a.01')", "Synset('concrete.n.01')"]
# TP = 1, FN = 0
# FP = 0, TN = 0
# Precision for sense Synset('concrete.a.01') is 1.0
# TP = 0, FN = 0
# FP = 0, TN = 1
# Precision for sense Synset('concrete.n.01') is 1
# payment
# 19 1
# Accuracy of NB classification on testing data is 0 out of 1 = 0.0
# {"Synset('payment.n.02')", "Synset('payment.n.01')"}
# ["Synset('payment.n.02')", "Synset('payment.n.01')"]
# TP = 0, FN = 1
# FP = 0, TN = 0
# Precision for sense Synset('payment.n.02') is 1
# TP = 0, FN = 0
# FP = 1, TN = 0
# Precision for sense Synset('payment.n.01') is 0.0
# flowers
# 23 8
# Accuracy of NB classification on testing data is 4 out of 8 = 0.5
# {"Synset('flower.n.01')", "Synset('flower.n.02')"}
# ["Synset('flower.n.01')", "Synset('flower.n.02')"]
# TP = 4, FN = 4
# FP = 0, TN = 0
# Precision for sense Synset('flower.n.01') is 1.0
# TP = 0, FN = 0
# FP = 4, TN = 4
# Precision for sense Synset('flower.n.02') is 0.0
# leaders
# 22 1
# Accuracy of NB classification on testing data is 0 out of 1 = 0.0
# {"Synset('leadership.n.02')", "Synset('leader.n.01')"}
# ["Synset('leadership.n.02')", "Synset('leader.n.01')"]
# TP = 0, FN = 0
# FP = 1, TN = 0
# Precision for sense Synset('leadership.n.02') is 0.0
# TP = 0, FN = 1
# FP = 0, TN = 0
# Precision for sense Synset('leader.n.01') is 1
# intensity
# 21 13
# Accuracy of NB classification on testing data is 11 out of 13 = 0.8461538461538461
# {"Synset('intensity.n.01')", "Synset('intensity.n.02')"}
# ["Synset('intensity.n.01')", "Synset('intensity.n.02')"]
# TP = 10, FN = 1
# FP = 1, TN = 1
# Precision for sense Synset('intensity.n.01') is 0.9090909090909091
# TP = 1, FN = 1
# FP = 1, TN = 10
# Precision for sense Synset('intensity.n.02') is 0.5
# skill
# 21 1
# Accuracy of NB classification on testing data is 1 out of 1 = 1.0
# {"Synset('skill.n.02')", "Synset('skill.n.01')"}
# ["Synset('skill.n.02')", "Synset('skill.n.01')"]
# TP = 0, FN = 0
# FP = 0, TN = 1
# Precision for sense Synset('skill.n.02') is 1
# TP = 1, FN = 0
# FP = 0, TN = 0
# Precision for sense Synset('skill.n.01') is 1.0
# resulted
# 22 5
# Accuracy of NB classification on testing data is 3 out of 5 = 0.6
# {"Synset('leave.v.07')", "Synset('result.v.01')"}
# ["Synset('leave.v.07')", "Synset('result.v.01')"]
# TP = 2, FN = 0
# FP = 2, TN = 1
# Precision for sense Synset('leave.v.07') is 0.5
# TP = 1, FN = 2
# FP = 0, TN = 2
# Precision for sense Synset('result.v.01') is 1.0
# sing
# 21 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('sing.v.01')", "Synset('sing.v.02')"}
# reasonable
# 21 9
# Accuracy of NB classification on testing data is 2 out of 9 = 0.2222222222222222
# {"Synset('fair.s.02')", "Synset('reasonable.a.01')"}
# ["Synset('fair.s.02')", "Synset('reasonable.a.01')"]
# TP = 2, FN = 3
# FP = 4, TN = 0
# Precision for sense Synset('fair.s.02') is 0.3333333333333333
# TP = 0, FN = 4
# FP = 3, TN = 2
# Precision for sense Synset('reasonable.a.01') is 0.0
# democratic
# 20 0
# Accuracy of NB classification on testing data is 0 out of 0 = 1
# {"Synset('democratic.a.01')", "Synset('democratic.a.02')"}
# situations
# 21 2
# Accuracy of NB classification on testing data is 2 out of 2 = 1.0
# {"Synset('situation.n.01')", "Synset('situation.n.02')"}
# ["Synset('situation.n.01')", "Synset('situation.n.02')"]
# TP = 1, FN = 0
# FP = 0, TN = 1
# Precision for sense Synset('situation.n.01') is 1.0
# TP = 1, FN = 0
# FP = 0, TN = 1
# Precision for sense Synset('situation.n.02') is 1.0
# plants
# 21 15
# Accuracy of NB classification on testing data is 10 out of 15 = 0.6666666666666666
# {"Synset('plant.n.02')", "Synset('plant.n.01')"}
# ["Synset('plant.n.02')", "Synset('plant.n.01')"]
# TP = 9, FN = 4
# FP = 1, TN = 1
# Precision for sense Synset('plant.n.02') is 0.9
# TP = 1, FN = 1
# FP = 4, TN = 9
# Precision for sense Synset('plant.n.01') is 0.2
# scientific
# 21 3
# Accuracy of NB classification on testing data is 2 out of 3 = 0.6666666666666666
# {"Synset('scientific.a.01')", "Synset('scientific.a.02')"}
# ["Synset('scientific.a.01')", "Synset('scientific.a.02')"]
# TP = 1, FN = 1
# FP = 0, TN = 1
# Precision for sense Synset('scientific.a.01') is 1.0
# TP = 1, FN = 0
# FP = 1, TN = 1
# Precision for sense Synset('scientific.a.02') is 0.5
# exception
# 20 2
# Accuracy of NB classification on testing data is 1 out of 2 = 0.5
# {"Synset('exception.n.01')", "Synset('exception.n.02')"}
# ["Synset('exception.n.01')", "Synset('exception.n.02')"]
# TP = 1, FN = 1
# FP = 0, TN = 0
# Precision for sense Synset('exception.n.01') is 1.0
# TP = 0, FN = 0
# FP = 1, TN = 1
# Precision for sense Synset('exception.n.02') is 0.0
# task
# 20 3
# Accuracy of NB classification on testing data is 1 out of 3 = 0.3333333333333333
# {"Synset('job.n.02')", "Synset('undertaking.n.01')"}
# ["Synset('job.n.02')", "Synset('undertaking.n.01')"]
# TP = 0, FN = 0
# FP = 2, TN = 1
# Precision for sense Synset('job.n.02') is 0.0
# TP = 1, FN = 2
# FP = 0, TN = 0
# Precision for sense Synset('undertaking.n.01') is 1.0
# curve
# 14 1
# Accuracy of NB classification on testing data is 0 out of 1 = 0.0
# {"Synset('curve.n.02')", "Synset('curve.n.01')"}
# ["Synset('curve.n.02')", "Synset('curve.n.01')"]
# TP = 0, FN = 0
# FP = 0, TN = 1
# Precision for sense Synset('curve.n.02') is 1
# TP = 0, FN = 0
# FP = 1, TN = 0
# Precision for sense Synset('curve.n.01') is 0.0

# %%
results
# Out:
# [('too', 0.7, 0.2, 0.44999999999999996),
#  ('thus', 0.75, 0.5, 0.625),
#  ('really', 0.2, 0.625, 0.4125),
#  ('described', 0.5833333333333334, 0.875, 0.7291666666666667),
#  ('basis', 0.5714285714285714, 0.5, 0.5357142857142857),
#  ('months', 1, 0.0, 0.5),
#  ('caused', 0.0, 1.0, 0.5),
#  ('instead', 0.5, 0.8571428571428571, 0.6785714285714286),
#  ('radiation', 1, 1, 1.0),
#  ('cells', 0.5, 0.2222222222222222, 0.3611111111111111),
#  ('won', 0.8181818181818182, 1, 0.9090909090909092),
#  ('labor', 1.0, 1, 1.0),
#  ('agreed', 0.8571428571428571, 1, 0.9285714285714286),
#  ('becoming', 1, 0.75, 0.875),
#  ('discussion', 0.0, 0.3333333333333333, 0.16666666666666666),
#  ('asking', 1.0, 1.0, 1.0),
#  ('department', 0.0, 1.0, 0.5),
#  ('particles', 1, 1, 1.0),
#  ('churches', 1, 1, 1.0),
#  ('destroy', 1, 0.6666666666666666, 0.8333333333333333),
#  ('spend', 0.3333333333333333, 0.8888888888888888, 0.611111111111111),
#  ('extent', 1.0, 0.6, 0.8),
#  ('funds', 1, 1, 1.0),
#  ('quickly', 1.0, 0.8, 0.9),
#  ('wondered', 0.5714285714285714, 1.0, 0.7857142857142857),
#  ('neighborhood', 1.0, 0.0, 0.5),
#  ('objective', 0.5, 0.0, 0.25),
#  ('sleep', 0.16666666666666666, 1.0, 0.5833333333333334),
#  ('procedure', 0.0, 0.8, 0.4),
#  ('containing', 0.0, 1.0, 0.5),
#  ('university', 1, 1, 1.0),
#  ('downtown', 1, 1, 1.0),
#  ('listen', 0.5714285714285714, 1, 0.7857142857142857),
#  ('minimum', 1.0, 0.0, 0.5),
#  ('concrete', 1.0, 1, 1.0),
#  ('payment', 1, 0.0, 0.5),
#  ('flowers', 1.0, 0.0, 0.5),
#  ('leaders', 0.0, 1, 0.5),
#  ('intensity', 0.9090909090909091, 0.5, 0.7045454545454546),
#  ('skill', 1, 1.0, 1.0),
#  ('resulted', 0.5, 1.0, 0.75),
#  ('sing', 1, 1, 1.0),
#  ('reasonable', 0.3333333333333333, 0.0, 0.16666666666666666),
#  ('democratic', 1, 1, 1.0),
#  ('situations', 1.0, 1.0, 1.0),
#  ('plants', 0.9, 0.2, 0.55),
#  ('scientific', 1.0, 0.5, 0.75),
#  ('exception', 1.0, 0.0, 0.5),
#  ('task', 0.0, 1.0, 0.5),
#  ('curve', 1, 0.0, 0.5)]

# %%
import pandas as pd
df=pd.DataFrame(results,columns=['word','sense 1 precision','sense 2 precision','average precision'])
display(df)
# Out:
#             word  sense 1 precision  sense 2 precision  average precision
# 0            too           0.700000           0.200000           0.450000
# 1           thus           0.750000           0.500000           0.625000
# 2         really           0.200000           0.625000           0.412500
# 3      described           0.583333           0.875000           0.729167
# 4          basis           0.571429           0.500000           0.535714
# 5         months           1.000000           0.000000           0.500000
# 6         caused           0.000000           1.000000           0.500000
# 7        instead           0.500000           0.857143           0.678571
# 8      radiation           1.000000           1.000000           1.000000
# 9          cells           0.500000           0.222222           0.361111
# 10           won           0.818182           1.000000           0.909091
# 11         labor           1.000000           1.000000           1.000000
# 12        agreed           0.857143           1.000000           0.928571
# 13      becoming           1.000000           0.750000           0.875000
# 14    discussion           0.000000           0.333333           0.166667
# 15        asking           1.000000           1.000000           1.000000
# 16    department           0.000000           1.000000           0.500000
# 17     particles           1.000000           1.000000           1.000000
# 18      churches           1.000000           1.000000           1.000000
# 19       destroy           1.000000           0.666667           0.833333
# 20         spend           0.333333           0.888889           0.611111
# 21        extent           1.000000           0.600000           0.800000
# 22         funds           1.000000           1.000000           1.000000
# 23       quickly           1.000000           0.800000           0.900000
# 24      wondered           0.571429           1.000000           0.785714
# 25  neighborhood           1.000000           0.000000           0.500000
# 26     objective           0.500000           0.000000           0.250000
# 27         sleep           0.166667           1.000000           0.583333
# 28     procedure           0.000000           0.800000           0.400000
# 29    containing           0.000000           1.000000           0.500000
# 30    university           1.000000           1.000000           1.000000
# 31      downtown           1.000000           1.000000           1.000000
# 32        listen           0.571429           1.000000           0.785714
# 33       minimum           1.000000           0.000000           0.500000
# 34      concrete           1.000000           1.000000           1.000000
# 35       payment           1.000000           0.000000           0.500000
# 36       flowers           1.000000           0.000000           0.500000
# 37       leaders           0.000000           1.000000           0.500000
# 38     intensity           0.909091           0.500000           0.704545
# 39         skill           1.000000           1.000000           1.000000
# 40      resulted           0.500000           1.000000           0.750000
# 41          sing           1.000000           1.000000           1.000000
# 42    reasonable           0.333333           0.000000           0.166667
# 43    democratic           1.000000           1.000000           1.000000
# 44    situations           1.000000           1.000000           1.000000
# 45        plants           0.900000           0.200000           0.550000
# 46    scientific           1.000000           0.500000           0.750000
# 47     exception           1.000000           0.000000           0.500000
# 48          task           0.000000           1.000000           0.500000
# 49         curve           1.000000           0.000000           0.500000

# %%
df.describe()
# Out:
#        sense 1 precision  sense 2 precision  average precision
# count          50.000000          50.000000          50.000000
# mean            0.705307           0.676365           0.690836
# std             0.373347           0.396284           0.249866
# min             0.000000           0.000000           0.166667
# 25%             0.500000           0.375000           0.500000
# 50%             0.954545           0.881944           0.691558
# 75%             1.000000           1.000000           0.982143
# max             1.000000           1.000000           1.000000
