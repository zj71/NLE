# %% [markdown]
# # Week 4 (Part 2): Document Similarity
#
# In some applications, it may be difficult to define the classes that we want to use in classification ahead of time.  Or, classes might be made up various subclasses (which differ in terms of the vocabulary used).  In both of these cases (and others), it might be more appropriate to think about **document similarity**.  For a new document, can we find the most similar document in our collection?
#
# ### Preliminaries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#utils has functions that we have worked on in previous weeks.

import sys
sys.path.append('/content/drive/My Drive/NLE Notebooks/Week4LabsSolutions/')
from utils import *
# Out:
# Sussex NLTK root directory is /content/drive/My Drive/NLE Notebooks/resources

# %% [markdown]
# Now lets get a document collection.  Actually, lets get two collections and store them in a dictionary for easy access.

# %%
from sussex_nltk.corpus_readers import ReutersCorpusReader

rcr = ReutersCorpusReader()    #Create a new reader

collectionsize=10 #the number of documents in each collection
collections={"finance":[],"sport":[]}

for key in collections.keys():
    generator=rcr.category(key).raw()
    while len(collections[key])<collectionsize:
        collections[key].append(next(generator))

# %% [markdown]
# We now need a function which will tokenise documents and construct a *bag-of-words* document representation.  Combining some of the functionality we have been working over the past few weeks (which we have imported from utils.py), we could use something like this

# %%
def make_bow(somestring):
    rep=word_tokenize(somestring)
    rep=normalise(rep)
    rep=stem(rep)
    rep=filter_stopwords(rep)
    dict_rep={}
    for token in rep:
        dict_rep[token]=dict_rep.get(token,0)+1
    return(dict_rep)

# %% [markdown]
# We can apply `make_bow()` to all of the documents in our collections

# %%
bow_collections={key:[make_bow(doc) for doc in collection] for key,collection in collections.items()}

# %% [markdown]
# Let's have a look at the first document in the finance collection.

# %%
print(bow_collections["finance"][0])
# Out:
# {'navistar': 16, 'close': 4, 'foundri': 12, 'take': 2, 'charg': 2, 'intern': 2, 'indianapoli': 8, 'cast': 2, 'employ': 1, 'num': 10, 'peopl': 1, 'late': 2, 'local': 3, 'union': 6, 'member': 3, 'reject': 2, 'compani': 8, 'propos': 4, 'truck': 4, 'school': 2, 'bu': 1, 'manufactur': 1, 'said': 8, 'tuesday': 1, 'move': 1, 'follow': 1, 'ratif': 1, 'extens': 1, 'master': 1, 'contract': 2, 'percent': 2, 'vote': 1, 'unit': 1, 'auto': 1, 'worker': 4, 'uaw': 5, 'announc': 2, 'sunday': 1, 'left': 1, 'open': 3, 'possibl': 2, 'could': 3, 'remain': 1, 'seek': 2, 'agreement': 5, 'came': 1, 'back': 2, 'say': 3, 'like': 1, 'talk': 2, 'one': 1, 'time': 2, 'alway': 1, 'work': 4, 'toward': 1, 'chairman': 1, 'john': 1, 'horn': 1, 'told': 1, 'report': 1, 'lock': 1, 'door': 2, 'jack': 1, 'laskowski': 2, 'vice': 1, 'presid': 1, 'ad': 2, 'confer': 1, 'call': 1, 'held': 1, 'jointli': 1, 'think': 1, 'know': 1, 'long': 1, 'sure': 1, 'short': 1, 'period': 1, 'offici': 4, 'gave': 1, 'detail': 1, 'except': 1, 'basic': 1, 'wage': 2, 'benefit': 2, 'would': 1, 'chang': 3, 'employe': 3, 'springfield': 7, 'ohio': 1, 'plant': 3, 'ratifi': 1, 'pact': 1, 'allow': 2, 'make': 2, 'product': 3, 'reduc': 1, 'forc': 3, 'leadership': 1, 'stood': 1, 'recogn': 1, 'go': 2, 'carri': 1, 'messag': 1, 'membership': 1, 'opposit': 1, 'happen': 1, 'larri': 1, 'gigerich': 1, 'senior': 1, 'advis': 1, 'econom': 1, 'develop': 1, 'mayor': 1, 'stephen': 1, 'goldsmith': 1, 'citi': 1, 'encourag': 2, 'keep': 1, 'side': 1, 'ha': 1, 'annual': 1, 'payrol': 1, 'million': 1, 'exclud': 1, 'typic': 1, 'year': 2, 'old': 1, 'high': 1, 'graduat': 1, 'experi': 1, 'level': 1, 'higher': 1, 'competit': 3, 'howev': 1, 'longer': 1, 'stay': 1, 'without': 1, 'new': 2, 'labor': 2, 'particularli': 1, 'face': 1, 'futur': 1, 'latin': 1, 'america': 1, 'cost': 1, 'significantli': 1, 'lower': 1, 'engin': 1, 'plan': 2, 'unspecifi': 1, 'fourth': 1, 'quarter': 1, 'repres': 1, 'fort': 1, 'wayn': 1, 'ind': 1, 'melros': 1, 'park': 1, 'locat': 1, 'approv': 1, 'proceed': 1, 'previous': 1, 'focu': 1, 'assembl': 1, 'exclus': 1, 'chatham': 1, 'ontario': 1, 'focus': 1, 'also': 1, 'introduc': 1, 'build': 2, 'promis': 1, 'made': 1, 'give': 1, 'exact': 1, 'estim': 1, 'much': 1, 'depend': 1, 'upon': 1, 'success': 1, 'stock': 2, 'rose': 1, 'end': 1, 'york': 1, 'exchang': 1}

# %% [markdown]
# ## Measuring Similarity
# We are going to use the cosine measure to determine how similar two documents are.  This can be defined in terms of the dot products of vectors:
#
# \begin{eqnarray*}
# \mbox{sim}_{\mbox{cosine}}(A,B) = \frac{A.B}{\sqrt{A.A \times B.B}}
# \end{eqnarray*}
#
# where the dot product of two vectors, A and B, is defined as:
#
# \begin{eqnarray*}
# A.B = \sum_{\mbox{f}} \mbox{weight}(A,f)\times \mbox{weight}(B,f)
# \end{eqnarray*}
#
# and $\mbox{weight}(X,f)$ tells us the value associated with feature $f$ in the vector representation of $X$
#
# ### Exercise 1.1
# * Write a function `dot` which takes two documents (represented as dictionaries) and returns their dot product
# * Test it out on the first two documents in the finance collection.  You should get the answer 206

# %%
def dot(docA,docB):
    the_sum=0
    for (key,value) in docA.items():
        the_sum+=value*docB.get(key,0)
    return the_sum

testA=bow_collections['finance'][0]
testB=bow_collections['finance'][1]
dot(testA, testB)
# Out:
# 206

# %% [markdown]
# ### Exercise 1.2
# * Write a function `cos_sim` which takes two documents (represented as dictionaries) and returns their cosine similarity.
# * Your function should make 3 calls to the `dot` function you have already defined
# * If you test it out on the first two documents in the finance collection you should get 0.24 (to 2S.F.)

# %%
import math

def cos_sim(docA,docB):
    sim=dot(docA,docB)/(math.sqrt(dot(docA,docA)*dot(docB,docB)))
    return sim

cos_sim(testA,testB)
# Out:
# 0.2389942359865197

# %% [markdown]
# ### Exercise 1.3
# * Write some code that will compute the similarity of every document in a collection with every document in another collection
# * Write code to compute the average similarity of two collections
# * Compute (and display) the average similarity of
#     * the finance collection to the finance collection
#     * the sport collection to the sport collection
#     * the finance collection to the sport collection
#     * the sport collection to the finance collection

# %%
def average_similarity(collectionA,collectionB):
    
    totalsim=0
    
    for docA in collectionA:
        for docB in collectionB:
            totalsim+=cos_sim(docA,docB)
    return totalsim/(len(collectionA)*len(collectionB))

for key1 in bow_collections.keys():
    for key2 in bow_collections.keys():
        sim=average_similarity(bow_collections[key1],bow_collections[key2])
        print("The average similarity of {} to {} is {}".format(key1,key2,sim))
# Out:
# The average similarity of finance to finance is 0.3332921405718554
# The average similarity of finance to sport is 0.238305878745487
# The average similarity of sport to finance is 0.23830587874548698
# The average similarity of sport to sport is 0.3540280872838635

# %% [markdown]
# ## Beyond Frequency
# Frequency of a word in a document does not make a very good weight because some words occur very frequently in all documents.  If two rare words occur in both of our pair of documents, that should add more to their perceived similarity than if two common words occur in both of our pair of documents.
#
# ### TF-IDF
# A commonly used weight is tf-idf which stands for **term frequency, inverse document frequency**
#
# \begin{eqnarray*}
# \mbox{tf-idf}(D_i,f) = tf(D_i,f) \times idf(D_i,f)
# \end{eqnarray*}
#
# where $tf(D_i,f)$ is simply the frequency of feature f in document $D_i$
# and
#
# \begin{eqnarray*}
# idf(D_i,f) = log \frac{N}{df(f)}
# \end{eqnarray*}
#
# where $N$ is the total number of documents and $\mbox{df}(f)$ is the number of documents containing $f$:
#
# \begin{eqnarray*}
# df(f)=|\{i|\mbox{freq}(D_i,f)>0\}|
# \end{eqnarray*}
#
# The code below will take a list of documents (represented as dictionaries) and compute the document frequency for each feature.  Test it out on one of the collections of documents.

# %%
def doc_freq(doclist):
    df={}
    for doc in doclist:
        for feat in doc.keys():
            df[feat]=df.get(feat,0)+1
            
    return df

# %%
doc_freq(bow_collections['finance'])
# Out:
# {'abraod': 1,
#  'abroad': 2,
#  'absolut': 1,
#  'accord': 1,
#  'account': 1,
#  'activ': 1,
#  'ad': 3,
#  'address': 1,
#  'administr': 4,
#  'advis': 1,
#  'affair': 1,
#  'agenc': 2,
#  'ago': 2,
#  'agre': 3,
#  'agreement': 4,
#  'agricultur': 1,
#  'aid': 2,
#  'albani': 1,
#  'alcohol': 1,
#  'alleg': 1,
#  'allow': 4,
#  'also': 4,
#  'altern': 2,
#  'alway': 1,
#  'amend': 3,
#  'america': 1,
#  'american': 3,
#  'among': 1,
#  'amount': 3,
#  'ani': 1,
#  'announc': 1,
#  'annual': 2,
#  'anoth': 1,
#  'applianc': 1,
#  'approach': 1,
#  'appropri': 1,
#  'approv': 2,
#  'april': 1,
#  'argu': 3,
#  'arizona': 1,
#  'armistic': 1,
#  'asid': 1,
#  'assembl': 1,
#  'assist': 1,
#  'atom': 1,
#  'attorney': 1,
#  'aug': 1,
#  'australia': 1,
#  'auth': 1,
#  'author': 1,
#  'auto': 1,
#  'automat': 1,
#  'averag': 1,
#  'aviat': 1,
#  'awar': 1,
#  'away': 2,
#  'b': 2,
#  'back': 2,
#  'balanc': 1,
#  'baltic': 1,
#  'baltimor': 1,
#  'ban': 1,
#  'banana': 1,
#  'banc': 1,
#  'bank': 2,
#  'bargain': 1,
#  'barrag': 1,
#  'basic': 1,
#  'basin': 1,
#  'battl': 1,
#  'battleground': 1,
#  'becam': 1,
#  'becaus': 3,
#  'becom': 1,
#  'becuas': 1,
#  'befor': 1,
#  'behaviour': 1,
#  'belch': 1,
#  'benefit': 1,
#  'better': 2,
#  'biden': 1,
#  'bill': 3,
#  'billion': 3,
#  'bipartisan': 1,
#  'blast': 1,
#  'bln': 1,
#  'bob': 1,
#  'bomb': 1,
#  'bond': 2,
#  'boost': 1,
#  'bosworth': 2,
#  'bratislava': 1,
#  'broke': 1,
#  'broken': 1,
#  'brought': 1,
#  'bu': 1,
#  'budget': 3,
#  'build': 3,
#  'built': 1,
#  'bulk': 1,
#  'cafe': 1,
#  'cairo': 1,
#  'calcul': 1,
#  'calendar': 1,
#  'california': 1,
#  'call': 1,
#  'cambodia': 1,
#  'came': 1,
#  'campaign': 1,
#  'canada': 1,
#  'capit': 1,
#  'capitalist': 1,
#  'carey': 1,
#  'caribbean': 1,
#  'carri': 1,
#  'cascad': 1,
#  'cast': 1,
#  'castro': 1,
#  'catalyst': 1,
#  'cbi': 1,
#  'central': 2,
#  'ceremoni': 1,
#  'certif': 1,
#  'certifi': 1,
#  'chairman': 3,
#  'chanc': 1,
#  'chang': 3,
#  'charg': 1,
#  'chase': 1,
#  'chatham': 1,
#  'chg': 1,
#  'chief': 2,
#  'chile': 1,
#  'citi': 1,
#  'clean': 1,
#  'clinton': 3,
#  'close': 1,
#  'cloth': 1,
#  'cobb': 1,
#  'cochran': 1,
#  'cold': 1,
#  'come': 3,
#  'commerci': 1,
#  'committe': 3,
#  'commod': 1,
#  'commun': 1,
#  'communist': 1,
#  'compani': 4,
#  'compar': 1,
#  'competit': 3,
#  'compromis': 1,
#  'concept': 1,
#  'concern': 1,
#  'concert': 1,
#  'concret': 1,
#  'conduct': 1,
#  'confer': 2,
#  'confetti': 1,
#  'confront': 1,
#  'congo': 1,
#  'congress': 2,
#  'consid': 1,
#  'consortium': 1,
#  'construct': 3,
#  'consum': 1,
#  'contain': 1,
#  'conting': 1,
#  'continu': 1,
#  'contract': 1,
#  'contractor': 1,
#  'control': 1,
#  'cooper': 2,
#  'core': 1,
#  'corpor': 1,
#  'corrupt': 1,
#  'cost': 4,
#  'could': 3,
#  'countri': 3,
#  'coupl': 1,
#  'creation': 1,
#  'credibl': 1,
#  'crisi': 1,
#  'crop': 1,
#  'cross': 1,
#  'csd': 2,
#  'cti': 1,
#  'cuba': 1,
#  'cultur': 1,
#  'curb': 1,
#  'currenc': 2,
#  'current': 1,
#  'cut': 1,
#  'dain': 1,
#  'dan': 1,
#  'date': 1,
#  'day': 1,
#  'debat': 2,
#  'dec': 1,
#  'decad': 1,
#  'declin': 1,
#  'deem': 1,
#  'defeat': 1,
#  'delawar': 1,
#  'deliv': 1,
#  'deliveri': 1,
#  'demand': 1,
#  'democraci': 1,
#  'democrat': 3,
#  'demonstr': 1,
#  'denton': 1,
#  'denuclearis': 1,
#  'depart': 1,
#  'depend': 3,
#  'deposit': 1,
#  'deputi': 1,
#  'desk': 1,
#  'detail': 1,
#  'determin': 1,
#  'develop': 4,
#  'diplomat': 1,
#  'direct': 1,
#  'director': 1,
#  'discount': 1,
#  'dismantl': 1,
#  'dist': 1,
#  'district': 1,
#  'divert': 1,
#  'doe': 3,
#  'dollar': 1,
#  'domest': 2,
#  'door': 1,
#  'drink': 1,
#  'drug': 3,
#  'dure': 2,
#  'earlier': 1,
#  'earn': 1,
#  'east': 1,
#  'eastern': 1,
#  'econom': 3,
#  'educ': 2,
#  'effort': 4,
#  'egypt': 1,
#  'elect': 2,
#  'employ': 1,
#  'employe': 1,
#  'encourag': 2,
#  'end': 4,
#  'energi': 2,
#  'enforc': 1,
#  'engin': 1,
#  'enough': 1,
#  'ensur': 1,
#  'entir': 1,
#  'entitl': 1,
#  'environment': 1,
#  'equip': 1,
#  'error': 1,
#  'establish': 1,
#  'estim': 2,
#  'europ': 1,
#  'european': 2,
#  'eventu': 1,
#  'exact': 1,
#  'except': 1,
#  'exchang': 2,
#  'exclud': 1,
#  'exclus': 1,
#  'execut': 1,
#  'expand': 1,
#  'expans': 2,
#  'expect': 2,
#  'expenditur': 1,
#  'expens': 1,
#  'experi': 1,
#  'experiment': 1,
#  'exploit': 1,
#  'export': 3,
#  'extens': 1,
#  'fac': 1,
#  'face': 2,
#  'facil': 1,
#  'fail': 1,
#  'fairli': 1,
#  'fall': 1,
#  'famili': 1,
#  'farmer': 1,
#  'fast': 1,
#  'fate': 1,
#  'feder': 2,
#  'feel': 1,
#  'fight': 2,
#  'figur': 1,
#  'fin': 2,
#  'financ': 2,
#  'financi': 1,
#  'finland': 1,
#  'fire': 1,
#  'firework': 1,
#  'first': 1,
#  'fiscal': 2,
#  'fissil': 1,
#  'floor': 1,
#  'florida': 1,
#  'focu': 1,
#  'focus': 1,
#  'follow': 4,
#  'food': 1,
#  'foodstuff': 1,
#  'forc': 1,
#  'foreign': 2,
#  'forex': 1,
#  'form': 1,
#  'former': 2,
#  'fort': 1,
#  'foundri': 1,
#  'fourth': 1,
#  'free': 3,
#  'freedom': 1,
#  'freeli': 1,
#  'freez': 1,
#  'frenship': 1,
#  'friday': 1,
#  'fuel': 1,
#  'fulfil': 1,
#  'fund': 2,
#  'furnitur': 1,
#  'futur': 1,
#  'fy': 1,
#  'gain': 1,
#  'gave': 1,
#  'gear': 1,
#  'gener': 2,
#  'geneva': 1,
#  'get': 3,
#  'gigerich': 1,
#  'give': 2,
#  'given': 1,
#  'glickman': 1,
#  'glove': 1,
#  'go': 3,
#  'goal': 1,
#  'goldsmith': 1,
#  'good': 2,
#  'got': 1,
#  'govern': 2,
#  'graduat': 1,
#  'graham': 1,
#  'granburi': 1,
#  'greater': 1,
#  'green': 1,
#  'gross': 1,
#  'ground': 1,
#  'group': 3,
#  'grower': 1,
#  'gut': 1,
#  'ha': 5,
#  'half': 1,
#  'halt': 1,
#  'hampshir': 1,
#  'hancock': 1,
#  'happen': 1,
#  'hard': 1,
#  'hardest': 1,
#  'healthcar': 1,
#  'heavili': 1,
#  'held': 1,
#  'help': 2,
#  'herbert': 1,
#  'hi': 2,
#  'hidden': 1,
#  'high': 2,
#  'higher': 2,
#  'hill': 1,
#  'hillsid': 1,
#  'histor': 1,
#  'hlth': 1,
#  'hold': 1,
#  'hope': 2,
#  'horn': 1,
#  'hotel': 1,
#  'hous': 4,
#  'household': 1,
#  'howev': 2,
#  'human': 1,
#  'hutu': 1,
#  'iaea': 1,
#  'ideal': 1,
#  'ifa': 1,
#  'illicit': 1,
#  'impact': 1,
#  'import': 3,
#  'impoverish': 1,
#  'includ': 4,
#  'incom': 1,
#  'increas': 1,
#  'ind': 1,
#  'index': 1,
#  'indianapoli': 1,
#  'indic': 1,
#  'indonesia': 1,
#  'indust': 1,
#  'industri': 1,
#  'inflat': 1,
#  'inform': 1,
#  'initi': 3,
#  'injur': 1,
#  'inspect': 1,
#  'instead': 1,
#  'insur': 1,
#  'interest': 3,
#  'intern': 3,
#  'introduc': 1,
#  'invest': 3,
#  'investig': 1,
#  'iran': 1,
#  'isd': 1,
#  'israel': 1,
#  'issu': 4,
#  'issuer': 1,
#  'jack': 1,
#  'jan': 1,
#  'japan': 1,
#  'job': 2,
#  'jobless': 1,
#  'joe': 1,
#  'joel': 1,
#  'john': 3,
#  'jointli': 1,
#  'jordan': 1,
#  'journalist': 1,
#  'juli': 2,
#  'june': 1,
#  'kabila': 1,
#  'kedo': 1,
#  'keep': 2,
#  'kennedal': 1,
#  'kentucki': 1,
#  'key': 2,
#  'kill': 1,
#  'kilo': 1,
#  'know': 1,
#  'korea': 2,
#  'korean': 2,
#  'kumho': 1,
#  'labor': 2,
#  'landmark': 1,
#  'largest': 1,
#  'larri': 1,
#  'laskowski': 1,
#  'last': 3,
#  'late': 1,
#  'later': 1,
#  'latin': 1,
#  'launch': 1,
#  'laurent': 1,
#  'law': 1,
#  'lawmak': 1,
#  'lead': 1,
#  'leadership': 1,
#  'led': 1,
#  'left': 1,
#  'legisl': 1,
#  'leisur': 1,
#  'less': 3,
#  'letter': 2,
#  'level': 1,
#  'life': 1,
#  'like': 2,
#  'loan': 1,
#  'local': 1,
#  'locat': 1,
#  'lock': 2,
#  'lombard': 1,
#  'long': 1,
#  'longer': 1,
#  'loser': 1,
#  'lot': 1,
#  'lower': 1,
#  'lubbock': 1,
#  'made': 2,
#  'mainten': 1,
#  'major': 1,
#  'make': 2,
#  'manag': 1,
#  'mani': 1,
#  'manufactur': 2,
#  'mar': 1,
#  'mark': 1,
#  'marker': 1,
#  'market': 1,
#  'mass': 2,
#  'massachusett': 1,
#  'master': 1,
#  'materi': 1,
#  'matter': 1,
#  'may': 3,
#  'mayor': 1,
#  'mccain': 1,
#  'mcconnel': 1,
#  'md': 1,
#  'meanwhil': 1,
#  'measur': 2,
#  'meet': 1,
#  'melros': 1,
#  'member': 3,
#  'membership': 1,
#  'messag': 2,
#  'mexico': 2,
#  'middl': 1,
#  'might': 2,
#  'militari': 1,
#  'miller': 1,
#  'million': 6,
#  'mississippi': 1,
#  'mitch': 1,
#  'mln': 1,
#  'modesto': 1,
#  'money': 2,
#  'month': 4,
#  'monthli': 1,
#  'morgan': 1,
#  'moscow': 1,
#  'move': 2,
#  'much': 1,
#  'municip': 1,
#  'must': 1,
#  'na': 1,
#  'nafta': 2,
#  'nation': 3,
#  'navistar': 1,
#  'nb': 1,
#  'need': 2,
#  'negoti': 2,
#  'net': 2,
#  'new': 4,
#  'news': 1,
#  'newsdesk': 1,
#  'newsroom': 1,
#  'next': 3,
#  'nine': 2,
#  'nomin': 1,
#  'north': 4,
#  'northeastern': 1,
#  'note': 2,
#  'noth': 1,
#  'nuclear': 2,
#  'num': 9,
#  'nuveen': 1,
#  'obligaiton': 1,
#  'occur': 1,
#  'octob': 1,
#  'offic': 1,
#  'offici': 3,
#  'offset': 1,
#  'often': 1,
#  'ohio': 2,
#  'old': 1,
#  'omit': 1,
#  'ommiss': 1,
#  'one': 4,
#  'onli': 1,
#  'ontario': 1,
#  'open': 2,
#  'oper': 2,
#  'oppon': 1,
#  'oppos': 2,
#  'opposit': 2,
#  'orang': 2,
#  'order': 1,
#  'oregon': 1,
#  'organ': 2,
#  'organis': 2,
#  'orlando': 1,
#  'output': 1,
#  'overal': 1,
#  'packag': 2,
#  'pact': 2,
#  'painewebb': 2,
#  'panel': 2,
#  'parcel': 1,
#  'park': 1,
#  'part': 1,
#  'parti': 1,
#  'particularli': 2,
#  'passag': 1,
#  'past': 2,
#  'pay': 1,
#  'payrol': 1,
#  'pct': 1,
#  'peac': 2,
#  'pend': 1,
#  'peninsula': 1,
#  'peopl': 2,
#  'percent': 5,
#  'percentag': 1,
#  'period': 1,
#  'pink': 1,
#  'place': 1,
#  'plan': 2,
#  'plant': 1,
#  'pledg': 1,
#  'plutonium': 1,
#  'pnc': 1,
#  'polici': 1,
#  'polit': 1,
#  'portfolio': 1,
#  'possibl': 1,
#  'prais': 1,
#  'preferenti': 1,
#  'preserv': 1,
#  'presid': 3,
#  'previous': 1,
#  'price': 1,
#  'proceed': 1,
#  'process': 1,
#  'produc': 1,
#  'product': 5,
#  'programm': 2,
#  'project': 1,
#  'promis': 2,
#  'propos': 5,
#  'protect': 1,
#  'provid': 1,
#  'provis': 2,
#  'puff': 1,
#  'put': 2,
#  'pv': 1,
#  'pyongyang': 1,
#  'qualifi': 1,
#  'quarter': 1,
#  'quarterli': 1,
#  'rate': 1,
#  'ratif': 1,
#  'ratifi': 1,
#  'reach': 2,
#  'reactor': 2,
#  'real': 1,
#  'realis': 1,
#  'receiv': 1,
#  'recent': 1,
#  'recipi': 1,
#  'reclus': 1,
#  'recogn': 1,
#  'recommend': 1,
#  'reconcili': 2,
#  'recreat': 1,
#  'redev': 1,
#  'reduc': 2,
#  'reduct': 1,
#  'reform': 1,
#  'refus': 1,
#  'regard': 1,
#  'regist': 1,
#  'regul': 1,
#  'reject': 2,
#  'relat': 1,
#  'releas': 1,
#  'religi': 1,
#  'reloc': 1,
#  'remain': 1,
#  'renew': 2,
#  'report': 3,
#  'repres': 3,
#  'republ': 2,
#  'republican': 4,
#  'request': 2,
#  'rescu': 1,
#  'reserv': 1,
#  'respons': 2,
#  'restaur': 1,
#  'restrict': 2,
#  'retail': 1,
#  'return': 2,
#  'rev': 1,
#  'revenu': 1,
#  'revers': 1,
#  'review': 1,
#  'revis': 1,
#  'right': 2,
#  'roar': 1,
#  'ron': 1,
#  'roosevelt': 1,
#  'rose': 1,
#  'rule': 1,
#  'russia': 1,
#  'said': 8,
#  'sale': 2,
#  'satisfi': 1,
#  'save': 1,
#  'say': 2,
#  'sch': 1,
#  'school': 2,
#  'schroeder': 1,
#  'sebastopol': 1,
#  'secretari': 1,
#  'secretli': 1,
#  'sector': 1,
#  'secur': 2,
#  'securitieswk': 1,
#  'seek': 1,
#  'sell': 1,
#  'senat': 3,
#  'send': 2,
#  'senior': 2,
#  'sent': 1,
#  'seoul': 1,
#  'seri': 1,
#  'serv': 1,
#  'servic': 2,
#  'set': 1,
#  'settl': 1,
#  'settlement': 2,
#  'seven': 1,
#  'shoe': 1,
#  'short': 1,
#  'show': 1,
#  'side': 2,
#  'sign': 1,
#  'significantli': 1,
#  'sim': 1,
#  'sinc': 2,
#  'skk': 1,
#  'slovak': 1,
#  'slovakia': 1,
#  'smoke': 2,
#  'soft': 1,
#  'someth': 1,
#  'sometim': 1,
#  'south': 2,
#  'southwest': 1,
#  'soviet': 1,
#  'spark': 1,
#  'special': 1,
#  'speech': 1,
#  'spend': 2,
#  'spring': 1,
#  'springfield': 1,
#  'squar': 1,
#  'sr': 1,
#  'stanc': 1,
#  'stand': 1,
#  'stanley': 1,
#  'start': 3,
#  'state': 6,
#  'stay': 1,
#  'stephen': 2,
#  'still': 1,
#  'stock': 2,
#  'stood': 1,
#  'stop': 1,
#  'streamer': 1,
#  'street': 1,
#  'strike': 1,
#  'strong': 1,
#  'struck': 1,
#  'subcommitte': 2,
#  'subject': 1,
#  'success': 1,
#  'sulphur': 1,
#  'sunday': 1,
#  'suppli': 1,
#  'support': 2,
#  'sure': 1,
#  'suspect': 1,
#  'symbol': 1,
#  'take': 1,
#  'talk': 1,
#  'target': 1,
#  'tariff': 1,
#  'tax': 1,
#  'teamster': 1,
#  'tent': 1,
#  'terrorist': 1,
#  'texa': 1,
#  'thad': 1,
#  'thi': 4,
#  'think': 1,
#  'three': 1,
#  'throw': 1,
#  'thu': 1,
#  'thursday': 3,
#  'time': 2,
#  'tobacco': 2,
#  'tokyo': 1,
#  'told': 5,
#  'tonn': 1,
#  'total': 1,
#  'tough': 1,
#  'toward': 2,
#  'town': 1,
#  'track': 1,
#  'trade': 4,
#  'traffick': 1,
#  'transfer': 1,
#  'transport': 1,
#  'tri': 1,
#  'trigger': 1,
#  'troop': 1,
#  'truck': 1,
#  'true': 1,
#  'tuesday': 3,
#  'two': 4,
#  'typic': 1,
#  'uaw': 1,
#  'uesd': 1,
#  'ukrain': 1,
#  'uncertain': 1,
#  'unemploy': 1,
#  'unfair': 1,
#  'unfairli': 1,
#  'union': 5,
#  'unit': 4,
#  'unspecifi': 1,
#  'updat': 2,
#  'upon': 1,
#  'urg': 1,
#  'usda': 1,
#  'use': 3,
#  'usual': 1,
#  'util': 1,
#  'varieti': 1,
#  'variou': 1,
#  'vice': 1,
#  'view': 2,
#  'villag': 1,
#  'violat': 1,
#  'voic': 1,
#  'vote': 4,
#  'vow': 1,
#  'wa': 4,
#  'wage': 2,
#  'want': 1,
#  'war': 1,
#  'warn': 1,
#  'washington': 4,
#  'watchdog': 1,
#  'watertown': 1,
#  'wayn': 1,
#  'weapon': 1,
#  'week': 2,
#  'went': 1,
#  'west': 1,
#  'western': 1,
#  'westland': 1,
#  'whether': 2,
#  'white': 2,
#  'win': 1,
#  'wit': 1,
#  'without': 2,
#  'wk': 1,
#  'woodland': 1,
#  'worcest': 1,
#  'work': 4,
#  'worker': 2,
#  'workforc': 1,
#  'world': 1,
#  'would': 5,
#  'wto': 1,
#  'yakima': 1,
#  'year': 4,
#  'yellow': 1,
#  'york': 1,
#  'yr': 1,
#  'zealand': 1}

# %% [markdown]
# ### Exercise 2.1
# * Write a function which will compute the idf values for features given a list of documents
# * Use it to compute idf values for features given:
#     * the finance collection of documents
#     * the sports collection of documents
#     * the combination of the finance and sports collections

# %%
def idf(doclist):
    N=len(doclist)
    return {feat:math.log(N/v) for feat,v in doc_freq(doclist).items()}

# %%
finance_idf=idf(bow_collections['finance'])
sports_idf=idf(bow_collections['sport'])
combined_idf=idf(bow_collections['sport']+bow_collections['finance'])

# %% [markdown]
# ### Exercise 2.2
# * Write a function `convert_to_tfidf` that takes two arguments:
#     * a list of documents (represented as dictionaries {feat:freq})
#     * a dictionary containing idf values
# * and outputs a list of documents with tfidf weights (i.e., dictionaries {feat:tfidf})

# %%
def convert_to_tfidf(docs,idfvalues):
    converted=[{f:v*idfvalues.get(f,0) for f,v in doc.items()} for doc in docs]
    return converted

# %%
convert_to_tfidf(bow_collections['finance'],finance_idf)
# Out:
# [{'ad': 2.4079456086518722,
#   'advis': 2.302585092994046,
#   'agreement': 4.5814536593707755,
#   'allow': 1.8325814637483102,
#   'also': 0.9162907318741551,
#   'alway': 2.302585092994046,
#   'america': 2.302585092994046,
#   'announc': 4.605170185988092,
#   'annual': 1.6094379124341003,
#   'approv': 1.6094379124341003,
#   'assembl': 2.302585092994046,
#   'auto': 2.302585092994046,
#   'back': 3.2188758248682006,
#   'basic': 2.302585092994046,
#   'benefit': 4.605170185988092,
#   'bu': 2.302585092994046,
#   'build': 2.4079456086518722,
#   'call': 2.302585092994046,
#   'came': 2.302585092994046,
#   'carri': 2.302585092994046,
#   'cast': 4.605170185988092,
#   'chairman': 1.2039728043259361,
#   'chang': 3.6119184129778086,
#   'charg': 4.605170185988092,
#   'chatham': 2.302585092994046,
#   'citi': 2.302585092994046,
#   'close': 9.210340371976184,
#   'compani': 7.330325854993241,
#   'competit': 3.6119184129778086,
#   'confer': 1.6094379124341003,
#   'contract': 4.605170185988092,
#   'cost': 0.9162907318741551,
#   'could': 3.6119184129778086,
#   'depend': 1.2039728043259361,
#   'detail': 2.302585092994046,
#   'develop': 0.9162907318741551,
#   'door': 4.605170185988092,
#   'econom': 1.2039728043259361,
#   'employ': 2.302585092994046,
#   'employe': 6.907755278982138,
#   'encourag': 3.2188758248682006,
#   'end': 0.9162907318741551,
#   'engin': 2.302585092994046,
#   'estim': 1.6094379124341003,
#   'exact': 2.302585092994046,
#   'except': 2.302585092994046,
#   'exchang': 1.6094379124341003,
#   'exclud': 2.302585092994046,
#   'exclus': 2.302585092994046,
#   'experi': 2.302585092994046,
#   'extens': 2.302585092994046,
#   'face': 1.6094379124341003,
#   'focu': 2.302585092994046,
#   'focus': 2.302585092994046,
#   'follow': 0.9162907318741551,
#   'forc': 6.907755278982138,
#   'fort': 2.302585092994046,
#   'foundri': 27.63102111592855,
#   'fourth': 2.302585092994046,
#   'futur': 2.302585092994046,
#   'gave': 2.302585092994046,
#   'gigerich': 2.302585092994046,
#   'give': 1.6094379124341003,
#   'go': 2.4079456086518722,
#   'goldsmith': 2.302585092994046,
#   'graduat': 2.302585092994046,
#   'ha': 0.6931471805599453,
#   'happen': 2.302585092994046,
#   'held': 2.302585092994046,
#   'high': 1.6094379124341003,
#   'higher': 1.6094379124341003,
#   'horn': 2.302585092994046,
#   'howev': 1.6094379124341003,
#   'ind': 2.302585092994046,
#   'indianapoli': 18.420680743952367,
#   'intern': 2.4079456086518722,
#   'introduc': 2.302585092994046,
#   'jack': 2.302585092994046,
#   'john': 1.2039728043259361,
#   'jointli': 2.302585092994046,
#   'keep': 1.6094379124341003,
#   'know': 2.302585092994046,
#   'labor': 3.2188758248682006,
#   'larri': 2.302585092994046,
#   'laskowski': 4.605170185988092,
#   'late': 4.605170185988092,
#   'latin': 2.302585092994046,
#   'leadership': 2.302585092994046,
#   'left': 2.302585092994046,
#   'level': 2.302585092994046,
#   'like': 1.6094379124341003,
#   'local': 6.907755278982138,
#   'locat': 2.302585092994046,
#   'lock': 1.6094379124341003,
#   'long': 2.302585092994046,
#   'longer': 2.302585092994046,
#   'lower': 2.302585092994046,
#   'made': 1.6094379124341003,
#   'make': 3.2188758248682006,
#   'manufactur': 1.6094379124341003,
#   'master': 2.302585092994046,
#   'mayor': 2.302585092994046,
#   'melros': 2.302585092994046,
#   'member': 3.6119184129778086,
#   'membership': 2.302585092994046,
#   'messag': 1.6094379124341003,
#   'million': 0.5108256237659907,
#   'move': 1.6094379124341003,
#   'much': 2.302585092994046,
#   'navistar': 36.841361487904734,
#   'new': 1.8325814637483102,
#   'num': 1.0536051565782636,
#   'offici': 4.8158912173037445,
#   'ohio': 1.6094379124341003,
#   'old': 2.302585092994046,
#   'one': 0.9162907318741551,
#   'ontario': 2.302585092994046,
#   'open': 4.828313737302301,
#   'opposit': 1.6094379124341003,
#   'pact': 1.6094379124341003,
#   'park': 2.302585092994046,
#   'particularli': 1.6094379124341003,
#   'payrol': 2.302585092994046,
#   'peopl': 1.6094379124341003,
#   'percent': 1.3862943611198906,
#   'period': 2.302585092994046,
#   'plan': 3.2188758248682006,
#   'plant': 6.907755278982138,
#   'possibl': 4.605170185988092,
#   'presid': 1.2039728043259361,
#   'previous': 2.302585092994046,
#   'proceed': 2.302585092994046,
#   'product': 2.0794415416798357,
#   'promis': 1.6094379124341003,
#   'propos': 2.772588722239781,
#   'quarter': 2.302585092994046,
#   'ratif': 2.302585092994046,
#   'ratifi': 2.302585092994046,
#   'job': 4.828313737302301,
#   'labor': 3.2188758248682006,
#   'largest': 2.302585092994046,
#   'launch': 2.302585092994046,
#   'legisl': 16.11809565095832,
#   'like': 1.6094379124341003,
#   'loser': 2.302585092994046,
#   'major': 2.302585092994046,
#   'market': 2.302585092994046,
#   'mexico': 1.6094379124341003,
#   'month': 0.9162907318741551,
#   'move': 1.6094379124341003,
#   'nafta': 6.437751649736401,
#   'nation': 1.2039728043259361,
#   'need': 1.6094379124341003,
#   'negoti': 6.437751649736401,
#   'new': 0.9162907318741551,
#   'news': 2.302585092994046,
#   'next': 3.6119184129778086,
#   'north': 0.9162907318741551,
#   'num': 0.31608154697347907,
#   'offici': 3.6119184129778086,
#   'one': 0.9162907318741551,
#   'onli': 2.302585092994046,
#   'open': 1.6094379124341003,
#   'oppos': 1.6094379124341003,
#   'organ': 1.6094379124341003,
#   'packag': 1.6094379124341003,
#   'parcel': 2.302585092994046,
#   'part': 4.605170185988092,
#   'parti': 2.302585092994046,
#   'passag': 2.302585092994046,
#   'place': 4.605170185988092,
#   'presid': 2.4079456086518722,
#   'propos': 1.3862943611198906,
#   'reach': 1.6094379124341003,
#   'renew': 1.6094379124341003,
#   'republican': 1.8325814637483102,
#   'return': 1.6094379124341003,
#   'right': 1.6094379124341003,
#   'ron': 2.302585092994046,
#   'said': 1.1157177565710488,
#   'say': 1.6094379124341003,
#   'send': 1.6094379124341003,
#   'servic': 3.2188758248682006,
#   'settl': 2.302585092994046,
#   'settlement': 1.6094379124341003,
#   'side': 1.6094379124341003,
#   'sinc': 1.6094379124341003,
#   'start': 1.2039728043259361,
#   'stop': 2.302585092994046,
#   'strike': 6.907755278982138,
#   'support': 3.2188758248682006,
#   'teamster': 4.605170185988092,
#   'tent': 4.605170185988092,
#   'thi': 0.9162907318741551,
#   'throw': 2.302585092994046,
#   'told': 0.6931471805599453,
#   'track': 9.210340371976184,
#   'trade': 8.246616586867397,
#   'tuesday': 1.2039728043259361,
#   'two': 0.9162907318741551,
#   'union': 2.0794415416798357,
#   'unit': 0.9162907318741551,
#   'view': 1.6094379124341003,
#   'vote': 0.9162907318741551,
#   'vow': 2.302585092994046,
#   'wa': 1.8325814637483102,
#   'week': 1.6094379124341003,
#   'whether': 1.6094379124341003,
#   'win': 4.605170185988092,
#   'without': 1.6094379124341003,
#   'work': 0.9162907318741551,
#   'worker': 11.266065387038703,
#   'would': 1.3862943611198906,
#   'year': 1.8325814637483102},
#  {'abroad': 1.6094379124341003,
#   'absolut': 2.302585092994046,
#   'account': 11.51292546497023,
#   'administr': 0.9162907318741551,
#   'ago': 1.6094379124341003,
#   'alcohol': 2.302585092994046,
#   'amount': 1.2039728043259361,
#   'applianc': 2.302585092994046,
#   'april': 4.605170185988092,
#   'aug': 2.302585092994046,
#   'averag': 4.605170185988092,
#   'balanc': 18.420680743952367,
#   'bank': 4.828313737302301,
#   'bln': 11.51292546497023,
#   'bratislava': 2.302585092994046,
#   'budget': 1.2039728043259361,
#   'cafe': 2.302585092994046,
#   'calcul': 2.302585092994046,
#   'capit': 6.907755278982138,
#   'central': 1.6094379124341003,
#   'chang': 40.93507534708183,
#   'chg': 2.302585092994046,
#   'cloth': 2.302585092994046,
#   'commerci': 2.302585092994046,
#   'construct': 1.2039728043259361,
#   'consum': 2.302585092994046,
#   'creation': 2.302585092994046,
#   'cultur': 2.302585092994046,
#   'currenc': 3.2188758248682006,
#   'current': 6.907755278982138,
#   'dec': 6.907755278982138,
#   'demand': 6.907755278982138,
#   'deposit': 6.907755278982138,
#   'direct': 2.302585092994046,
#   'discount': 2.302585092994046,
#   'dollar': 2.302585092994046,
#   'domest': 1.6094379124341003,
#   'drink': 2.302585092994046,
#   'educ': 1.6094379124341003,
#   'energi': 1.6094379124341003,
#   'entir': 2.302585092994046,
#   'error': 2.302585092994046,
#   'exchang': 1.6094379124341003,
#   'expans': 1.6094379124341003,
#   'expenditur': 2.302585092994046,
#   'export': 2.4079456086518722,
#   'figur': 6.907755278982138,
#   'fin': 1.6094379124341003,
#   'financi': 2.302585092994046,
#   'follow': 0.9162907318741551,
#   'foodstuff': 2.302585092994046,
#   'foreign': 3.2188758248682006,
#   'forex': 2.302585092994046,
#   'former': 1.6094379124341003,
#   'fuel': 2.302585092994046,
#   'furnitur': 2.302585092994046,
#   'fy': 6.907755278982138,
#   'good': 1.6094379124341003,
#   'gross': 4.605170185988092,
#   'healthcar': 2.302585092994046,
#   'hotel': 2.302585092994046,
#   'household': 6.907755278982138,
#   'import': 2.4079456086518722,
#   'incom': 2.302585092994046,
#   'index': 4.605170185988092,
#   'indic': 4.605170185988092,
#   'indust': 2.302585092994046,
#   'industri': 2.302585092994046,
#   'inflat': 2.302585092994046,
#   'interest': 1.2039728043259361,
#   'invest': 6.01986402162968,
#   'jan': 4.605170185988092,
#   'jobless': 2.302585092994046,
#   'juli': 9.656627474604601,
#   'june': 16.11809565095832,
#   'key': 1.6094379124341003,
#   'last': 1.2039728043259361,
#   'leisur': 2.302585092994046,
#   'lombard': 2.302585092994046,
#   'mainten': 2.302585092994046,
#   'mar': 2.302585092994046,
#   'may': 8.427809630281553,
#   'measur': 1.6094379124341003,
#   'million': 0.5108256237659907,
#   'mln': 2.302585092994046,
#   'money': 1.6094379124341003,
#   'month': 1.8325814637483102,
#   'monthli': 2.302585092994046,
#   'nb': 4.605170185988092,
#   'net': 3.2188758248682006,
#   'newsroom': 2.302585092994046,
#   'nomin': 4.605170185988092,
#   'note': 3.2188758248682006,
#   'num': 26.129407883140935,
#   'ommiss': 2.302585092994046,
#   'output': 4.605170185988092,
#   'overal': 2.302585092994046,
#   'pct': 75.98530806880352,
#   'percent': 0.6931471805599453,
#   'percentag': 2.302585092994046,
#   'portfolio': 2.302585092994046,
#   'price': 2.302585092994046,
#   'produc': 2.302585092994046,
#   'product': 1.3862943611198906,
#   'pv': 2.302585092994046,
#   'quarterli': 2.302585092994046,
#   'rate': 9.210340371976184,
#   'real': 9.210340371976184,
#   'reserv': 6.907755278982138,
#   'restaur': 2.302585092994046,
#   'retail': 2.302585092994046,
#   'revenu': 2.302585092994046,
#   'revis': 4.605170185988092,
#   'sale': 1.6094379124341003,
#   'puff': 2.302585092994046,
#   'put': 3.2188758248682006,
#   'pyongyang': 6.907755278982138,
#   'reactor': 11.266065387038703,
#   'realis': 2.302585092994046,
#   'reclus': 2.302585092994046,
#   'reconcili': 1.6094379124341003,
#   'releas': 2.302585092994046,
#   'report': 1.2039728043259361,
#   'repres': 1.2039728043259361,
#   'republ': 1.6094379124341003,
#   'rescu': 2.302585092994046,
#   'respons': 1.6094379124341003,
#   'return': 1.6094379124341003,
#   'roar': 2.302585092994046,
#   'said': 2.008291961827888,
#   'satisfi': 2.302585092994046,
#   'secretli': 2.302585092994046,
#   'secur': 4.828313737302301,
#   'sell': 2.302585092994046,
#   'seoul': 9.210340371976184,
#   'serv': 2.302585092994046,
#   'seven': 2.302585092994046,
#   'sign': 2.302585092994046,
#   'sinc': 3.2188758248682006,
#   'smoke': 1.6094379124341003,
#   'south': 6.437751649736401,
#   'special': 2.302585092994046,
#   'start': 1.2039728043259361,
#   'state': 2.043302495063963,
#   'stephen': 1.6094379124341003,
#   'streamer': 2.302585092994046,
#   'suspect': 6.907755278982138,
#   'symbol': 4.605170185988092,
#   'terrorist': 2.302585092994046,
#   'thi': 0.9162907318741551,
#   'tokyo': 2.302585092994046,
#   'told': 0.6931471805599453,
#   'tonn': 2.302585092994046,
#   'town': 2.302585092994046,
#   'tri': 2.302585092994046,
#   'trigger': 2.302585092994046,
#   'tuesday': 3.6119184129778086,
#   'two': 2.7488721956224653,
#   'union': 1.3862943611198906,
#   'unit': 1.8325814637483102,
#   'use': 1.2039728043259361,
#   'view': 1.6094379124341003,
#   'wa': 2.7488721956224653,
#   'war': 4.605170185988092,
#   'washington': 1.8325814637483102,
#   'watchdog': 2.302585092994046,
#   'weapon': 2.302585092994046,
#   'went': 2.302585092994046,
#   'west': 2.302585092994046,
#   'western': 2.302585092994046,
#   'white': 1.6094379124341003,
#   'wit': 4.605170185988092,
#   'would': 1.3862943611198906,
#   'year': 1.8325814637483102,
#   'yellow': 2.302585092994046,
#   'zealand': 2.302585092994046},
#  {'ad': 1.2039728043259361,
#   'agenc': 3.2188758248682006,
#   'albani': 2.302585092994046,
#   'amount': 3.6119184129778086,
#   'auth': 6.907755278982138,
#   'aviat': 2.302585092994046,
#   'b': 1.6094379124341003,
#   'baltimor': 2.302585092994046,
#   'ban': 4.605170185988092,
#   'banc': 4.605170185988092,
#   'bosworth': 1.6094379124341003,
#   'calendar': 4.605170185988092,
#   'california': 2.302585092994046,
#   'chase': 2.302585092994046,
#   'cobb': 2.302585092994046,
#   'competit': 1.2039728043259361,
#   'csd': 1.6094379124341003,
#   'cti': 13.815510557964275,
#   'dain': 2.302585092994046,
#   'date': 4.605170185988092,
#   'denton': 2.302585092994046,
#   'dist': 2.302585092994046,
#   'educ': 1.6094379124341003,
#   'fac': 4.605170185988092,
#   'fin': 1.6094379124341003,
#   'first': 4.605170185988092,
#   'follow': 0.9162907318741551,
#   'frenship': 4.605170185988092,
#   'go': 9.631782434607489,
#   'granburi': 2.302585092994046,
#   'greater': 2.302585092994046,
#   'group': 1.2039728043259361,
#   'mass': 1.6094379124341003,
#   'mcconnel': 6.907755278982138,
#   'meet': 2.302585092994046,
#   'member': 1.2039728043259361,
#   'messag': 1.6094379124341003,
#   'middl': 2.302585092994046,
#   'militari': 2.302585092994046,
#   'million': 3.0649537425959443,
#   'mitch': 2.302585092994046,
#   'money': 1.6094379124341003,
#   'month': 1.8325814637483102,
#   'moscow': 2.302585092994046,
#   'next': 1.2039728043259361,
#   'nine': 1.6094379124341003,
#   'north': 0.9162907318741551,
#   'nuclear': 3.2188758248682006,
#   'num': 1.791128766183048,
#   'occur': 2.302585092994046,
#   'oper': 3.2188758248682006,
#   'opposit': 1.6094379124341003,
#   'organis': 1.6094379124341003,
#   'packag': 1.6094379124341003,
#   'panel': 1.6094379124341003,
#   'past': 1.6094379124341003,
#   'peac': 1.6094379124341003,
#   'percent': 1.3862943611198906,
#   'plan': 1.6094379124341003,
#   'polici': 2.302585092994046,
#   'prais': 2.302585092994046,
#   'presid': 3.6119184129778086,
#   'process': 2.302585092994046,
#   'programm': 1.6094379124341003,
#   'propos': 0.6931471805599453,
#   'provid': 2.302585092994046,
#   'provis': 1.6094379124341003,
#   'qualifi': 2.302585092994046,
#   'reactor': 1.6094379124341003,
#   'receiv': 2.302585092994046,
#   'recipi': 2.302585092994046,
#   'reform': 2.302585092994046,
#   'refus': 2.302585092994046,
#   'regard': 2.302585092994046,
#   'reject': 1.6094379124341003,
#   'relat': 2.302585092994046,
#   'religi': 2.302585092994046,
#   'renew': 1.6094379124341003,
#   'republ': 1.6094379124341003,
#   'republican': 0.9162907318741551,
#   'request': 3.2188758248682006,
#   'respons': 1.6094379124341003,
#   'restrict': 1.6094379124341003,
#   'revers': 2.302585092994046,
#   'review': 2.302585092994046,
#   'right': 1.6094379124341003,
#   'russia': 6.907755278982138,
#   'said': 0.6694306539426294,
#   'senat': 10.835755238933425,
#   'send': 3.2188758248682006,
#   'senior': 1.6094379124341003,
#   'set': 4.605170185988092,
#   'show': 2.302585092994046,
#   'someth': 2.302585092994046,
#   'south': 1.6094379124341003,
#   'soviet': 2.302585092994046,
#   'spend': 1.6094379124341003,
#   'start': 1.2039728043259361,
#   'state': 1.5324768712979722,
#   'still': 2.302585092994046,
#   'strong': 4.605170185988092,
#   'subcommitte': 1.6094379124341003,
#   'support': 1.6094379124341003,
#   'thi': 0.9162907318741551,
#   'thu': 2.302585092994046,
#   'thursday': 1.2039728043259361,
#   'told': 0.6931471805599453,
#   'trade': 0.9162907318741551,
#   'troop': 2.302585092994046,
#   'two': 0.9162907318741551,
#   'ukrain': 2.302585092994046,
#   'union': 0.6931471805599453,
#   'use': 3.6119184129778086,
#   'usual': 2.302585092994046,
#   'varieti': 2.302585092994046,
#   'violat': 2.302585092994046,
#   'vote': 2.7488721956224653,
#   'wa': 3.6651629274966204,
#   'warn': 2.302585092994046,
#   'washington': 0.9162907318741551,
#   'whether': 1.6094379124341003,
#   'white': 1.6094379124341003,
#   'work': 0.9162907318741551,
#   'would': 2.0794415416798357,
#   'year': 3.6651629274966204},
#  {'accord': 2.302585092994046,
#   'address': 2.302585092994046,
#   'agreement': 1.8325814637483102,
#   'also': 0.9162907318741551,
#   'american': 2.4079456086518722,
#   'arizona': 2.302585092994046,
#   'away': 1.6094379124341003,
#   'banana': 4.605170185988092,
#   'basin': 4.605170185988092,
#   'becaus': 3.6119184129778086,
#   'becom': 2.302585092994046,
#   'bill': 1.2039728043259361,
#   'bob': 2.302585092994046,
#   'budget': 1.2039728043259361,
#   'caribbean': 20.723265836946414,
#   'cbi': 2.302585092994046,
#   'committe': 1.2039728043259361,
#   'compani': 1.8325814637483102,
#   'compar': 2.302585092994046,
#   'competit': 1.2039728043259361,
#   'consid': 2.302585092994046,
#   'countri': 3.6119184129778086,
#   'coupl': 2.302585092994046,
#   'democrat': 1.2039728043259361,
#   'depend': 1.2039728043259361,
#   'divert': 2.302585092994046,
#   'drug': 1.2039728043259361,
#   'encourag': 1.6094379124341003,
#   'european': 1.6094379124341003,
#   'expens': 2.302585092994046,
#   'export': 1.2039728043259361,
#   'financ': 1.6094379124341003,
#   'florida': 2.302585092994046,
#   'free': 1.2039728043259361,
#   'good': 3.2188758248682006,
#   'graham': 4.605170185988092,
#   'ha': 1.3862943611198906,
#   'high': 1.6094379124341003,
#   'higher': 1.6094379124341003,
#   'hous': 0.9162907318741551,
#   'illicit': 2.302585092994046,
#   'impact': 2.302585092994046,
#   'import': 2.4079456086518722,
#   'includ': 0.9162907318741551,
#   'initi': 1.2039728043259361,
#   'invest': 2.4079456086518722,
#   'job': 1.6094379124341003,
#   'john': 1.2039728043259361,
#   'less': 1.2039728043259361,
#   'letter': 3.2188758248682006,
#   'manufactur': 1.6094379124341003,
#   'matter': 2.302585092994046,
#   'may': 1.2039728043259361,
#   'mccain': 4.605170185988092,
#   'mexico': 6.437751649736401,
#   'might': 1.6094379124341003,
#   'nafta': 4.828313737302301,
#   'nation': 2.4079456086518722,
#   'newsdesk': 2.302585092994046,
#   'north': 0.9162907318741551,
#   'offset': 2.302585092994046,
#   'oper': 1.6094379124341003,
#   'order': 2.302585092994046,
#   'organ': 1.6094379124341003,
#   'particularli': 1.6094379124341003,
#   'preferenti': 2.302585092994046,
#   'product': 0.6931471805599453,
#   'propos': 0.6931471805599453,
#   'recent': 2.302585092994046,
#   'reconcili': 1.6094379124341003,
#   'reduc': 3.2188758248682006,
#   'reduct': 2.302585092994046,
#   'reloc': 2.302585092994046,
#   'repres': 1.2039728043259361,
#   'republican': 0.9162907318741551,
#   'restrict': 1.6094379124341003,
#   'rule': 2.302585092994046,
#   'said': 1.5620048591994684,
#   'senat': 7.223836825955617,
#   'state': 0.5108256237659907,
#   'struck': 2.302585092994046,
#   'tariff': 11.51292546497023,
#   'thursday': 1.2039728043259361,
#   'toward': 1.6094379124341003,
#   'trade': 4.5814536593707755,
#   'traffick': 2.302585092994046,
#   'two': 0.9162907318741551,
#   'unfair': 2.302585092994046,
#   'unfairli': 2.302585092994046,
#   'union': 0.6931471805599453,
#   'unit': 0.9162907318741551,
#   'washington': 0.9162907318741551,
#   'world': 2.302585092994046,
#   'wto': 4.605170185988092},
#  {'bond': 1.6094379124341003,
#   'central': 3.2188758248682006,
#   'cost': 0.9162907318741551,
#   'cross': 2.302585092994046,
#   'csd': 3.2188758248682006,
#   'district': 2.302585092994046,
#   'interest': 1.2039728043259361,
#   'million': 0.5108256237659907,
#   'net': 1.6094379124341003,
#   'num': 0.31608154697347907,
#   'percent': 0.6931471805599453,
#   'roosevelt': 4.605170185988092,
#   'said': 0.22314355131420976,
#   'school': 1.6094379124341003,
#   'squar': 4.605170185988092},
#  {'b': 1.6094379124341003,
#   'bond': 1.6094379124341003,
#   'cost': 0.9162907318741551,
#   'elect': 1.6094379124341003,
#   'gener': 1.6094379124341003,
#   'interest': 1.2039728043259361,
#   'million': 0.5108256237659907,
#   'num': 0.31608154697347907,
#   'obligaiton': 2.302585092994046,
#   'painewebb': 3.2188758248682006,
#   'percent': 0.6931471805599453,
#   'said': 0.22314355131420976,
#   'sebastopol': 4.605170185988092,
#   'seri': 2.302585092994046,
#   'true': 2.302585092994046,
#   'uesd': 4.605170185988092},
#  {'activ': 2.302585092994046,
#   'administr': 1.8325814637483102,
#   'agricultur': 9.210340371976184,
#   'aid': 3.2188758248682006,
#   'altern': 1.6094379124341003,
#   'amend': 1.2039728043259361,
#   'appropri': 4.605170185988092,
#   'argu': 1.2039728043259361,
#   'attorney': 2.302585092994046,
#   'better': 1.6094379124341003,
#   'bill': 3.6119184129778086,
#   'billion': 1.2039728043259361,
#   'chairman': 1.2039728043259361,
#   'chanc': 2.302585092994046,
#   'chief': 1.6094379124341003,
#   'clinton': 1.2039728043259361,
#   'cochran': 2.302585092994046,
#   'come': 1.2039728043259361,
#   'committe': 1.2039728043259361,
#   'commod': 2.302585092994046,
#   'compani': 1.8325814637483102,
#   'concern': 2.302585092994046,
#   'congress': 3.2188758248682006,
#   'contain': 2.302585092994046,
#   'crop': 4.605170185988092,
#   'curb': 2.302585092994046,
#   'dan': 2.302585092994046,
#   'debat': 1.6094379124341003,
#   'defeat': 2.302585092994046,
#   'demonstr': 2.302585092994046,
#   'desk': 2.302585092994046,
#   'doe': 1.2039728043259361,
#   'drug': 1.2039728043259361,
#   'dure': 3.2188758248682006,
#   'earlier': 2.302585092994046,
#   'effort': 0.9162907318741551,
#   'end': 0.9162907318741551,
#   'enforc': 4.605170185988092,
#   'expect': 1.6094379124341003,
#   'face': 1.6094379124341003,
#   'fall': 2.302585092994046,
#   'farmer': 2.302585092994046,
#   'fate': 2.302585092994046,
#   'feder': 3.2188758248682006,
#   'feel': 2.302585092994046,
#   'fiscal': 1.6094379124341003,
#   'floor': 2.302585092994046,
#   'follow': 0.9162907318741551,
#   'food': 2.302585092994046,
#   'friday': 2.302585092994046,
#   'fund': 3.2188758248682006,
#   'gener': 1.6094379124341003,
#   'glickman': 4.605170185988092,
#   'govern': 1.6094379124341003,
#   'group': 1.2039728043259361,
#   'grower': 2.302585092994046,
#   'ha': 0.6931471805599453,
#   'hardest': 2.302585092994046,
#   'heavili': 2.302585092994046,
#   'hi': 1.6094379124341003,
#   'hous': 4.5814536593707755,
#   'howev': 3.2188758248682006,
#   'initi': 1.2039728043259361,
#   'injur': 2.302585092994046,
#   'instead': 2.302585092994046,
#   'insur': 4.605170185988092,
#   'invest': 1.2039728043259361,
#   'issu': 0.9162907318741551,
#   'keep': 1.6094379124341003,
#   'last': 1.2039728043259361,
#   'lawmak': 2.302585092994046,
#   'less': 1.2039728043259361,
#   'letter': 1.6094379124341003,
#   'mani': 2.302585092994046,
#   'marker': 2.302585092994046,
#   'may': 1.2039728043259361,
#   'meanwhil': 2.302585092994046,
#   'measur': 1.6094379124341003,
#   'member': 2.4079456086518722,
#   'million': 1.0216512475319814,
#   'mississippi': 2.302585092994046,
#   'month': 0.9162907318741551,
#   'noth': 2.302585092994046,
#   'num': 0.7375236096047845,
#   'often': 2.302585092994046,
#   'oppon': 2.302585092994046,
#   'oppos': 1.6094379124341003,
#   'pact': 1.6094379124341003,
#   'panel': 1.6094379124341003,
#   'pend': 2.302585092994046,
#   'product': 0.6931471805599453,
#   'propos': 0.6931471805599453,
#   'protect': 2.302585092994046,
#   'provis': 1.6094379124341003,
#   'put': 1.6094379124341003,
#   'reach': 1.6094379124341003,
#   'recommend': 2.302585092994046,
#   'regist': 2.302585092994046,
#   'regul': 2.302585092994046,
#   'report': 1.2039728043259361,
#   'republican': 1.8325814637483102,
#   'request': 1.6094379124341003,
#   'said': 0.8925742052568391,
#   'secretari': 2.302585092994046,
#   'senat': 1.2039728043259361,
#   'sent': 2.302585092994046,
#   'settlement': 3.2188758248682006,
#   'smoke': 3.2188758248682006,
#   'sometim': 2.302585092994046,
#   'speech': 2.302585092994046,
#   'spend': 3.2188758248682006,
#   'stanc': 2.302585092994046,
#   'stand': 2.302585092994046,
#   'state': 1.0216512475319814,
#   'subcommitte': 1.6094379124341003,
#   'thad': 2.302585092994046,
#   'thi': 0.9162907318741551,
#   'thursday': 3.6119184129778086,
#   'tobacco': 12.875503299472802,
#   'told': 0.6931471805599453,
#   'tough': 2.302585092994046,
#   'uncertain': 2.302585092994046,
#   'urg': 2.302585092994046,
#   'usda': 2.302585092994046,
#   'voic': 2.302585092994046,
#   'vote': 1.8325814637483102,
#   'wa': 0.9162907318741551,
#   'want': 4.605170185988092,
#   'washington': 0.9162907318741551,
#   'week': 1.6094379124341003,
#   'work': 0.9162907318741551,
#   'would': 1.3862943611198906}]

# %% [markdown]
# ### Exercise 2.3
# * Convert both of your document collections so that the weights are tfidf values rather than frequencies.  Which idf_values should you use in each case?
# * Recompute the average similarity between each collection of documents (as in Ex 1.3).
# * What do you notice?
# * As an extension, try increasing the sizes of the collections.  What do you notice now?

# %%
tfidf_collections={key:convert_to_tfidf(docs,combined_idf) for key,docs in bow_collections.items()}

for key1 in tfidf_collections.keys():
    for key2 in tfidf_collections.keys():
        sim=average_similarity(tfidf_collections[key1],tfidf_collections[key2])
        print("The average similarity of {} to {} is {}".format(key1,key2,sim))
# Out:
# The average similarity of finance to finance is 0.13306536902069344
# The average similarity of finance to sport is 0.014572920713006709
# The average similarity of sport to finance is 0.014572920713006707
# The average similarity of sport to sport is 0.14805216431292612
